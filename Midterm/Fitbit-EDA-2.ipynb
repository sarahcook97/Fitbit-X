# %%
import pandas as pd 
import numpy as np
import datetime
import math
import matplotlib.pyplot as plt #default library for making plots
import seaborn as sns           #use to make nicer plots
import matplotlib

# %%
#mod_data is Adele's modified data --> not raw data downloaded from fitbit
#data from multiple sources have been copied and pasted into an Excel sheet

mod_data = pd.read_csv("All Fitbit Data.csv") 
mod_data.head()
# Out:
#   Activities       Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4  \
# 0       Date  Calories Burned      Steps   Distance     Floors
# 1     9/1/17            2,520     18,402       7.79         59
# 2     9/2/17            2,857     27,273      11.62         70
# 3     9/3/17            2,212     15,794       6.68         16
# 4     9/4/17            2,843     28,438       12.1        125
#
#           Unnamed: 5              Unnamed: 6             Unnamed: 7  \
# 0  Minutes Sedentary  Minutes Lightly Active  Minutes Fairly Active
# 1                438                     301                    107
# 2                644                     355                    111
# 3                657                     249                     76
# 4                475                     351                    100
#
#             Unnamed: 8         Unnamed: 9
# 0  Minutes Very Active  Activity Calories
# 1                   27              1,553
# 2                   48              1,954
# 3                    4              1,151
# 4                   55              1,951

# %%
import datetime
import calendar

def day_of_week(unmodified_date): 
    date = unmodified_date.split('/')  #split unmodified date into a list of strings
    
    date[2] = '20' + date[2]    #fixes date syntax in order to use datetime function
    if len(date[0]) == 1:       #changes dates to mm-dd-yyyy format in order to use .weekday()
        date[0] = '0' + date[0] 
    if len(date[1]) == 1:
        date[1] = '0' + date[1]
    date = '-'.join(date)
    
    return datetime.datetime.strptime(date, '%m-%d-%Y').weekday() # returns day of week as a number

# %%
#relabeled the column names
mod_data = mod_data.rename(columns=dict(zip(mod_data.columns, mod_data.loc[0, :].tolist()))).drop(0)
mod_data['Day of Week'] = mod_data['Date'].apply(day_of_week)

# %%
mod_data.head()
# Out:
#      Date Calories Burned   Steps Distance Floors Minutes Sedentary  \
# 1  9/1/17           2,520  18,402     7.79     59               438
# 2  9/2/17           2,857  27,273    11.62     70               644
# 3  9/3/17           2,212  15,794     6.68     16               657
# 4  9/4/17           2,843  28,438     12.1    125               475
# 5  9/5/17           1,980  12,233     5.18     34               720
#
#   Minutes Lightly Active Minutes Fairly Active Minutes Very Active  \
# 1                    301                   107                  27
# 2                    355                   111                  48
# 3                    249                    76                   4
# 4                    351                   100                  55
# 5                    160                    37                  36
#
#   Activity Calories  Day of Week
# 1             1,553            4
# 2             1,954            5
# 3             1,151            6
# 4             1,951            0
# 5               843            1

# %%
#How do we extract and combine the data from multiple json files?

# %%
#Example of how to load one of the json files onto jupyter notebook.

import json

with open("json_test_files/heart_rate-2017-05-30.json", 'r') as f:
    data = json.load(f)
df = pd.DataFrame(data)
df.head()
# Out:
#             dateTime                          value
# 0  05/30/17 17:49:31   {'bpm': 70, 'confidence': 0}
# 1  05/30/17 17:49:41  {'bpm': 110, 'confidence': 0}
# 2  05/30/17 17:49:46  {'bpm': 114, 'confidence': 0}
# 3  05/30/17 17:49:51  {'bpm': 110, 'confidence': 0}
# 4  05/30/17 17:50:00  {'bpm': 110, 'confidence': 0}

# %%
import os

# path_to_json = 'json_test_files/'    #need to figure out how to find name of folder in the future
path_to_json = 'Adele_files/'
json_files = [pos_json for pos_json in os.listdir(path_to_json) if pos_json.endswith('.json')\
              and not pos_json.startswith('badge')]
json_files
# Out:
# ['time_in_heart_rate_zones-2018-06-06.json',
#  'time_in_heart_rate_zones-2017-10-05.json',
#  'time_in_heart_rate_zones-2018-08-18.json',
#  'heart_rate-2017-06-19.json',
#  'heart_rate-2018-12-27.json',
#  'time_in_heart_rate_zones-2019-02-01.json',
#  'distance-2018-12-20.json',
#  'heart_rate-2018-02-27.json',
#  'heart_rate-2017-08-07.json',
#  'demographic_vo2_max-2018-12-30.json',
#  'time_in_heart_rate_zones-2017-11-28.json',
#  'time_in_heart_rate_zones-2018-05-16.json',
#  'time_in_heart_rate_zones-2019-01-11.json',
#  'altitude-2019-02-18.json',
#  'time_in_heart_rate_zones-2018-02-12.json',
#  'time_in_heart_rate_zones-2018-12-12.json',
#  'steps-2018-03-25.json',
#  'sedentary_minutes-2018-04-24.json',
#  'heart_rate-2017-10-30.json',
#  'time_in_heart_rate_zones-2018-01-02.json',
#  'heart_rate-2019-03-19.json',
#  'heart_rate-2019-01-24.json',
#  'time_in_heart_rate_zones-2018-11-02.json',
#  'time_in_heart_rate_zones-2017-07-01.json',
#  'moderately_active_minutes-2019-02-18.json',
#  'heart_rate-2018-05-23.json',
#  'distance-2018-05-24.json',
#  'heart_rate-2019-02-22.json',
#  'time_in_heart_rate_zones-2018-12-04.json',
#  'time_in_heart_rate_zones-2017-08-24.json',
#  'time_in_heart_rate_zones-2018-02-04.json',
#  'heart_rate-2017-10-26.json',
#  'heart_rate-2018-06-25.json',
#  'heart_rate-2018-04-18.json',
#  'time_in_heart_rate_zones-2017-07-17.json',
#  'time_in_heart_rate_zones-2018-11-14.json',
#  'time_in_heart_rate_zones-2018-03-29.json',
#  'time_in_heart_rate_zones-2018-01-14.json',
#  'lightly_active_minutes-2018-12-20.json',
#  'time_in_heart_rate_zones-2017-09-09.json',
#  'very_active_minutes-2017-06-28.json',
#  'heart_rate-2018-07-08.json',
#  'heart_rate-2018-09-16.json',
#  'lightly_active_minutes-2018-05-24.json',
#  'time_in_heart_rate_zones-2017-10-13.json',
#  'time_in_heart_rate_zones-2018-06-10.json',
#  'heart_rate-2017-08-11.json',
#  'steps-2019-03-20.json',
#  'time_in_heart_rate_zones-2019-02-17.json',
#  'heart_rate-2018-12-31.json',
#  'time_in_heart_rate_zones-2018-09-23.json',
#  'heart_rate-2018-01-21.json',
#  'heart_rate-2017-07-22.json',
#  'heart_rate-2018-11-21.json',
#  'time_in_heart_rate_zones-2019-01-07.json',
#  'heart_rate-2018-08-17.json',
#  'heart_rate-2018-06-09.json',
#  'sedentary_minutes-2018-06-23.json',
#  'time_in_heart_rate_zones-2018-02-28.json',
#  'time_in_heart_rate_zones-2017-08-08.json',
#  'time_in_heart_rate_zones-2017-06-16.json',
#  'time_in_heart_rate_zones-2018-12-28.json',
#  'time_in_heart_rate_zones-2018-10-15.json',
#  'sedentary_minutes-2017-03-30.json',
#  'heart_rate-2017-11-27.json',
#  'heart_rate-2018-07-24.json',
#  'heart_rate-2018-05-19.json',
#  'distance-2018-07-23.json',
#  'time_in_heart_rate_zones-2017-09-25.json',
#  'time_in_heart_rate_zones-2018-03-05.json',
#  'heart_rate-2019-03-23.json',
#  'sleep-2017-11-25.json',
#  'moderately_active_minutes-2017-10-26.json',
#  'distance-2019-01-19.json',
#  'heart_rate-2017-06-23.json',
#  'heart_rate-2018-10-20.json',
#  'time_in_heart_rate_zones-2018-04-01.json',
#  'time_in_heart_rate_zones-2017-12-02.json',
#  'time_in_heart_rate_zones-2018-08-22.json',
#  'time_in_heart_rate_zones-2019-03-16.json',
#  'heart_rate-2017-09-10.json',
#  'heart_rate-2018-03-30.json',
#  'time_in_heart_rate_zones-2017-11-12.json',
#  'time_in_heart_rate_zones-2018-07-11.json',
#  'altitude-2017-10-26.json',
#  'lightly_active_minutes-2019-01-19.json',
#  'sleep-2016-12-30.json',
#  'exercise-1100.json',
#  'lightly_active_minutes-2018-07-23.json',
#  'time_in_heart_rate_zones-2017-12-14.json',
#  'time_in_heart_rate_zones-2017-10-29.json',
#  'time_in_heart_rate_zones-2018-04-17.json',
#  'heart_rate-2018-03-26.json',
#  'heart_rate-2017-09-06.json',
#  'heart_rate-2017-07-18.json',
#  'time_in_heart_rate_zones-2018-09-19.json',
#  'time_in_heart_rate_zones-2018-07-07.json',
#  'time_in_heart_rate_zones-2017-11-04.json',
#  'heart_rate-2017-12-21.json',
#  'heart_rate-2018-04-22.json',
#  'heart_rate-2018-08-01.json',
#  'heart_rate-2019-02-18.json',
#  'calories-2017-02-28.json',
#  'time_in_heart_rate_zones-2018-10-03.json',
#  'heart_rate-2019-01-08.json',
#  'time_in_heart_rate_zones-2018-03-13.json',
#  'moderately_active_minutes-2017-08-27.json',
#  'time_in_heart_rate_zones-2018-07-27.json',
#  'time_in_heart_rate_zones-2017-11-24.json',
#  'heart_rate-2018-03-06.json',
#  'heart_rate-2017-09-26.json',
#  'time_in_heart_rate_zones-2019-03-20.json',
#  'time_in_heart_rate_zones-2018-08-14.json',
#  'moderately_active_minutes-2017-05-29.json',
#  'time_in_heart_rate_zones-2017-10-09.json',
#  'exercise-200.json',
#  'heart_rate-2018-10-16.json',
#  'heart_rate-2017-06-15.json',
#  'altitude-2017-08-27.json',
#  'time_in_heart_rate_zones-2017-05-30.json',
#  'heart_rate-2019-01-28.json',
#  'heart_rate-2019-03-15.json',
#  'time_in_heart_rate_zones-2017-09-13.json',
#  'heart_rate-2018-07-12.json',
#  'heart_rate-2017-11-11.json',
#  'time_in_heart_rate_zones-2018-10-23.json',
#  'time_in_heart_rate_zones-2017-06-20.json',
#  'altitude-2017-05-29.json',
#  'heart_rate-2017-12-01.json',
#  'heart_rate-2018-04-02.json',
#  'heart_rate-2018-08-21.json',
#  'time_in_heart_rate_zones-2017-09-05.json',
#  'time_in_heart_rate_zones-2018-01-18.json',
#  'time_in_heart_rate_zones-2018-03-25.json',
#  'heart_rate-2019-03-03.json',
#  'time_in_heart_rate_zones-2018-11-18.json',
#  'heart_rate-2017-11-07.json',
#  'heart_rate-2018-07-04.json',
#  'time_in_heart_rate_zones-2018-02-08.json',
#  'time_in_heart_rate_zones-2017-08-28.json',
#  'time_in_heart_rate_zones-2018-12-08.json',
#  'heart_rate-2018-04-14.json',
#  'heart_rate-2018-06-29.json',
#  'heart_rate-2017-12-17.json',
#  'calories-2018-01-24.json',
#  'time_in_heart_rate_zones-2018-07-31.json',
#  'heart_rate-2017-09-30.json',
#  'heart_rate-2018-03-10.json',
#  'time_in_heart_rate_zones-2018-04-21.json',
#  'time_in_heart_rate_zones-2017-12-22.json',
#  'very_active_minutes-2019-01-19.json',
#  'time_in_heart_rate_zones-2018-08-02.json',
#  'heart_rate-2017-06-03.json',
#  'very_active_minutes-2018-07-23.json',
#  'heart_rate-2018-05-15.json',
#  'heart_rate-2018-07-28.json',
#  'heart_rate-2019-01-12.json',
#  'sleep-2017-01-29.json',
#  'time_in_heart_rate_zones-2018-03-09.json',
#  'time_in_heart_rate_zones-2017-09-29.json',
#  'heart_rate-2017-10-06.json',
#  'heart_rate-2018-06-05.json',
#  'heart_rate-2019-02-02.json',
#  'time_in_heart_rate_zones-2018-10-19.json',
#  'time_in_heart_rate_zones-2018-12-24.json',
#  'time_in_heart_rate_zones-2017-08-04.json',
#  'time_in_heart_rate_zones-2018-02-24.json',
#  'heart_rate-2018-01-01.json',
#  'sedentary_minutes-2017-07-28.json',
#  'heart_rate-2017-07-02.json',
#  'heart_rate-2018-11-01.json',
#  'time_in_heart_rate_zones-2019-01-27.json',
#  'time_in_heart_rate_zones-2018-09-03.json',
#  'time_in_heart_rate_zones-2018-05-20.json',
#  'heart_rate-2017-08-31.json',
#  'heart_rate-2018-02-11.json',
#  'distance-2017-06-28.json',
#  'heart_rate-2018-12-11.json',
#  'time_in_heart_rate_zones-2018-06-30.json',
#  'time_in_heart_rate_zones-2019-01-31.json',
#  'heart_rate-2018-11-17.json',
#  'heart_rate-2017-07-14.json',
#  'heart_rate-2018-01-17.json',
#  'time_in_heart_rate_zones-2017-11-08.json',
#  'steps-2018-08-22.json',
#  'time_in_heart_rate_zones-2018-09-15.json',
#  'heart_rate-2018-12-07.json',
#  'time_in_heart_rate_zones-2019-02-21.json',
#  'very_active_minutes-2018-05-24.json',
#  'heart_rate-2018-02-07.json',
#  'heart_rate-2017-08-27.json',
#  'time_in_heart_rate_zones-2018-06-26.json',
#  'time_in_heart_rate_zones-2017-10-25.json',
#  'time_in_heart_rate_zones-2017-12-18.json',
#  'moderately_active_minutes-2017-09-26.json',
#  'heart_rate-2018-09-20.json',
#  'heart_rate-2018-05-03.json',
#  'very_active_minutes-2018-12-20.json',
#  'lightly_active_minutes-2017-06-28.json',
#  'time_in_heart_rate_zones-2018-01-22.json',
#  'heart_rate-2019-01-04.json',
#  'time_in_heart_rate_zones-2018-11-22.json',
#  'time_in_heart_rate_zones-2017-07-21.json',
#  'heart_rate-2018-06-13.json',
#  'heart_rate-2017-10-10.json',
#  'time_in_heart_rate_zones-2017-08-12.json',
#  'heart_rate-2019-02-14.json',
#  'altitude-2017-09-26.json',
#  'heart_rate-2018-06-12.json',
#  'heart_rate-2017-10-11.json',
#  'calories-2017-12-25.json',
#  'time_in_heart_rate_zones-2017-08-13.json',
#  'heart_rate-2019-02-15.json',
#  'heart_rate-2018-09-21.json',
#  'heart_rate-2018-05-02.json',
#  'time_in_heart_rate_zones-2018-01-23.json',
#  'altitude-2017-04-29.json',
#  'time_in_heart_rate_zones-2018-11-23.json',
#  'heart_rate-2019-01-05.json',
#  'time_in_heart_rate_zones-2017-07-20.json',
#  'time_in_heart_rate_zones-2019-02-20.json',
#  'heart_rate-2018-12-06.json',
#  'heart_rate-2018-02-06.json',
#  'heart_rate-2017-08-26.json',
#  'time_in_heart_rate_zones-2018-06-27.json',
#  'time_in_heart_rate_zones-2017-12-19.json',
#  'time_in_heart_rate_zones-2017-10-24.json',
#  'heart_rate-2018-11-16.json',
#  'time_in_heart_rate_zones-2019-01-30.json',
#  'heart_rate-2017-07-15.json',
#  'heart_rate-2018-01-16.json',
#  'time_in_heart_rate_zones-2017-11-09.json',
#  'moderately_active_minutes-2017-04-29.json',
#  'time_in_heart_rate_zones-2018-09-14.json',
#  'very_active_minutes-2017-03-30.json',
#  'heart_rate-2017-08-30.json',
#  'heart_rate-2018-02-10.json',
#  'heart_rate-2018-12-10.json',
#  'very_active_minutes-2018-06-23.json',
#  'heart_rate-2017-07-03.json',
#  'time_in_heart_rate_zones-2019-01-26.json',
#  'time_in_heart_rate_zones-2018-09-02.json',
#  'time_in_heart_rate_zones-2018-05-21.json',
#  'heart_rate-2017-10-07.json',
#  'heart_rate-2018-06-04.json',
#  'time_in_heart_rate_zones-2018-12-25.json',
#  'time_in_heart_rate_zones-2018-10-18.json',
#  'heart_rate-2019-02-03.json',
#  'time_in_heart_rate_zones-2017-08-05.json',
#  'time_in_heart_rate_zones-2018-02-25.json',
#  'heart_rate-2018-07-29.json',
#  'heart_rate-2018-05-14.json',
#  'heart_rate-2019-01-13.json',
#  'time_in_heart_rate_zones-2018-03-08.json',
#  'time_in_heart_rate_zones-2017-09-28.json',
#  'time_in_heart_rate_zones-2018-04-20.json',
#  'steps-2017-01-29.json',
#  'time_in_heart_rate_zones-2017-12-23.json',
#  'time_in_heart_rate_zones-2018-08-03.json',
#  'heart_rate-2017-06-02.json',
#  'sedentary_minutes-2017-06-28.json',
#  'heart_rate-2018-10-01.json',
#  'time_in_heart_rate_zones-2018-07-30.json',
#  'distance-2017-07-28.json',
#  'heart_rate-2018-03-11.json',
#  'time_in_heart_rate_zones-2018-02-09.json',
#  'time_in_heart_rate_zones-2017-08-29.json',
#  'time_in_heart_rate_zones-2018-12-09.json',
#  'heart_rate-2018-06-28.json',
#  'heart_rate-2018-04-15.json',
#  'heart_rate-2017-12-16.json',
#  'time_in_heart_rate_zones-2017-09-04.json',
#  'time_in_heart_rate_zones-2018-03-24.json',
#  'time_in_heart_rate_zones-2018-01-19.json',
#  'time_in_heart_rate_zones-2018-11-19.json',
#  'heart_rate-2019-03-02.json',
#  'heart_rate-2017-11-06.json',
#  'heart_rate-2018-07-05.json',
#  'time_in_heart_rate_zones-2018-10-22.json',
#  'time_in_heart_rate_zones-2017-06-21.json',
#  'sleep-2018-08-22.json',
#  'lightly_active_minutes-2017-07-28.json',
#  'moderately_active_minutes-2018-09-21.json',
#  'heart_rate-2018-04-03.json',
#  'heart_rate-2018-08-20.json',
#  'time_in_heart_rate_zones-2017-05-31.json',
#  'heart_rate-2019-03-14.json',
#  'heart_rate-2019-01-29.json',
#  'time_in_heart_rate_zones-2017-09-12.json',
#  'heart_rate-2018-07-13.json',
#  'heart_rate-2017-11-10.json',
#  'time_in_heart_rate_zones-2018-08-15.json',
#  'altitude-2018-09-21.json',
#  'time_in_heart_rate_zones-2017-10-08.json',
#  'calories-2018-02-23.json',
#  'heart_rate-2018-10-17.json',
#  'heart_rate-2017-06-14.json',
#  'time_in_heart_rate_zones-2018-07-26.json',
#  'time_in_heart_rate_zones-2017-11-25.json',
#  'heart_rate-2018-03-07.json',
#  'heart_rate-2017-09-27.json',
#  'very_active_minutes-2018-04-24.json',
#  'time_in_heart_rate_zones-2019-03-21.json',
#  'sedentary_minutes-2018-05-24.json',
#  'heart_rate-2017-11-30.json',
#  'heart_rate-2019-01-09.json',
#  'time_in_heart_rate_zones-2018-03-12.json',
#  'distance-2018-04-24.json',
#  'heart_rate-2017-12-20.json',
#  'heart_rate-2018-04-23.json',
#  'time_in_heart_rate_zones-2018-10-02.json',
#  'heart_rate-2019-02-19.json',
#  'time_in_heart_rate_zones-2017-06-01.json',
#  'heart_rate-2018-03-27.json',
#  'heart_rate-2017-09-07.json',
#  'heart_rate-2017-07-19.json',
#  'time_in_heart_rate_zones-2019-03-01.json',
#  'sleep-2018-03-25.json',
#  'time_in_heart_rate_zones-2018-09-18.json',
#  'time_in_heart_rate_zones-2018-07-06.json',
#  'time_in_heart_rate_zones-2017-11-05.json',
#  'sedentary_minutes-2018-12-20.json',
#  'time_in_heart_rate_zones-2017-10-28.json',
#  'time_in_heart_rate_zones-2017-12-15.json',
#  'time_in_heart_rate_zones-2018-04-16.json',
#  'time_in_heart_rate_zones-2019-03-17.json',
#  'heart_rate-2017-09-11.json',
#  'heart_rate-2018-03-31.json',
#  'time_in_heart_rate_zones-2017-11-13.json',
#  'time_in_heart_rate_zones-2018-07-10.json',
#  'lightly_active_minutes-2018-04-24.json',
#  'heart_rate-2017-06-22.json',
#  'heart_rate-2018-10-21.json',
#  'moderately_active_minutes-2018-11-20.json',
#  'time_in_heart_rate_zones-2017-12-03.json',
#  'time_in_heart_rate_zones-2018-08-23.json',
#  'heart_rate-2017-11-26.json',
#  'sleep-2019-03-20.json',
#  'heart_rate-2018-05-18.json',
#  'heart_rate-2018-07-25.json',
#  'time_in_heart_rate_zones-2017-09-24.json',
#  'time_in_heart_rate_zones-2018-03-04.json',
#  'heart_rate-2019-03-22.json',
#  'heart_rate-2018-08-16.json',
#  'heart_rate-2018-06-08.json',
#  'very_active_minutes-2017-07-28.json',
#  'time_in_heart_rate_zones-2017-08-09.json',
#  'altitude-2018-11-20.json',
#  'time_in_heart_rate_zones-2017-06-17.json',
#  'time_in_heart_rate_zones-2018-10-14.json',
#  'time_in_heart_rate_zones-2018-12-29.json',
#  'time_in_heart_rate_zones-2018-09-22.json',
#  'time_in_heart_rate_zones-2018-05-01.json',
#  'moderately_active_minutes-2018-10-21.json',
#  'heart_rate-2018-01-20.json',
#  'heart_rate-2017-07-23.json',
#  'time_in_heart_rate_zones-2019-01-06.json',
#  'heart_rate-2018-11-20.json',
#  'steps-2017-11-25.json',
#  'time_in_heart_rate_zones-2017-10-12.json',
#  'time_in_heart_rate_zones-2018-06-11.json',
#  'heart_rate-2017-08-10.json',
#  'heart_rate-2018-12-30.json',
#  'time_in_heart_rate_zones-2019-02-16.json',
#  'exercise-1300.json',
#  'time_in_heart_rate_zones-2017-07-16.json',
#  'sedentary_minutes-2019-01-19.json',
#  'time_in_heart_rate_zones-2018-11-15.json',
#  'altitude-2018-10-21.json',
#  'time_in_heart_rate_zones-2018-01-15.json',
#  'time_in_heart_rate_zones-2018-03-28.json',
#  'time_in_heart_rate_zones-2017-09-08.json',
#  'sedentary_minutes-2018-07-23.json',
#  'heart_rate-2018-07-09.json',
#  'distance-2017-03-30.json',
#  'heart_rate-2018-09-17.json',
#  'time_in_heart_rate_zones-2018-12-05.json',
#  'heart_rate-2019-02-23.json',
#  'time_in_heart_rate_zones-2017-08-25.json',
#  'time_in_heart_rate_zones-2018-02-05.json',
#  'distance-2018-06-23.json',
#  'heart_rate-2017-10-27.json',
#  'heart_rate-2018-04-19.json',
#  'heart_rate-2018-06-24.json',
#  'time_in_heart_rate_zones-2018-01-03.json',
#  'time_in_heart_rate_zones-2018-11-03.json',
#  'heart_rate-2019-01-25.json',
#  'heart_rate-2019-03-18.json',
#  'heart_rate-2018-09-01.json',
#  'steps-2016-12-30.json',
#  'heart_rate-2018-05-22.json',
#  'time_in_heart_rate_zones-2018-02-13.json',
#  'time_in_heart_rate_zones-2018-12-13.json',
#  'heart_rate-2017-10-31.json',
#  'time_in_heart_rate_zones-2017-11-29.json',
#  'time_in_heart_rate_zones-2018-05-17.json',
#  'lightly_active_minutes-2018-06-23.json',
#  'time_in_heart_rate_zones-2019-01-10.json',
#  'time_in_heart_rate_zones-2018-06-07.json',
#  'lightly_active_minutes-2017-03-30.json',
#  'time_in_heart_rate_zones-2017-10-04.json',
#  'time_in_heart_rate_zones-2018-08-19.json',
#  'heart_rate-2017-06-18.json',
#  'heart_rate-2018-12-26.json',
#  'heart_rate-2018-02-26.json',
#  'heart_rate-2017-08-06.json',
#  'time_in_heart_rate_zones-2017-11-22.json',
#  'steps-2017-02-28.json',
#  'time_in_heart_rate_zones-2018-07-21.json',
#  'time_in_heart_rate_zones-2019-03-26.json',
#  'sedentary_minutes-2017-05-29.json',
#  'heart_rate-2017-09-20.json',
#  'time_in_heart_rate_zones-2018-08-12.json',
#  'distance-2017-04-29.json',
#  'heart_rate-2017-06-13.json',
#  'heart_rate-2018-10-10.json',
#  'sedentary_minutes-2017-08-27.json',
#  'time_in_heart_rate_zones-2017-09-15.json',
#  'time_in_heart_rate_zones-2018-01-08.json',
#  'time_in_heart_rate_zones-2018-11-08.json',
#  'heart_rate-2019-03-13.json',
#  'heart_rate-2017-11-17.json',
#  'heart_rate-2018-05-29.json',
#  'heart_rate-2018-07-14.json',
#  'time_in_heart_rate_zones-2018-02-18.json',
#  'time_in_heart_rate_zones-2017-06-26.json',
#  'time_in_heart_rate_zones-2018-10-25.json',
#  'time_in_heart_rate_zones-2018-12-18.json',
#  'heart_rate-2018-08-27.json',
#  'heart_rate-2018-04-04.json',
#  'heart_rate-2017-12-07.json',
#  'heart_rate-2019-03-05.json',
#  'lightly_active_minutes-2017-04-29.json',
#  'time_in_heart_rate_zones-2018-03-23.json',
#  'time_in_heart_rate_zones-2017-09-03.json',
#  'heart_rate-2018-07-02.json',
#  'heart_rate-2017-11-01.json',
#  'very_active_minutes-2018-10-21.json',
#  'heart_rate-2019-02-28.json',
#  'time_in_heart_rate_zones-2017-06-30.json',
#  'heart_rate-2017-12-11.json',
#  'heart_rate-2018-04-12.json',
#  'heart_rate-2018-08-31.json',
#  'time_in_heart_rate_zones-2018-09-29.json',
#  'heart_rate-2018-03-16.json',
#  'heart_rate-2017-07-28.json',
#  'time_in_heart_rate_zones-2019-03-30.json',
#  'heart_rate-2019-04-01.json',
#  'time_in_heart_rate_zones-2018-08-04.json',
#  'time_in_heart_rate_zones-2017-10-19.json',
#  'time_in_heart_rate_zones-2017-12-24.json',
#  'time_in_heart_rate_zones-2018-04-27.json',
#  'heart_rate-2018-10-06.json',
#  'heart_rate-2017-06-05.json',
#  'heart_rate-2018-09-30.json',
#  'calories-2019-03-20.json',
#  'heart_rate-2018-05-13.json',
#  'heart_rate-2019-01-14.json',
#  'heart_rate-2019-03-29.json',
#  'time_in_heart_rate_zones-2017-07-31.json',
#  'very_active_minutes-2018-11-20.json',
#  'heart_rate-2018-06-03.json',
#  'altitude-2017-07-28.json',
#  'time_in_heart_rate_zones-2018-02-22.json',
#  'time_in_heart_rate_zones-2017-08-02.json',
#  'heart_rate-2019-02-04.json',
#  'time_in_heart_rate_zones-2018-12-22.json',
#  'exercise-400.json',
#  'heart_rate-2018-11-07.json',
#  'time_in_heart_rate_zones-2019-01-21.json',
#  'heart_rate-2017-07-04.json',
#  'heart_rate-2018-01-07.json',
#  'time_in_heart_rate_zones-2017-11-18.json',
#  'time_in_heart_rate_zones-2018-05-26.json',
#  'time_in_heart_rate_zones-2018-09-05.json',
#  'heart_rate-2017-06-29.json',
#  'heart_rate-2018-12-17.json',
#  'heart_rate-2018-02-17.json',
#  'lightly_active_minutes-2018-09-21.json',
#  'moderately_active_minutes-2017-07-28.json',
#  'time_in_heart_rate_zones-2017-12-08.json',
#  'time_in_heart_rate_zones-2018-08-28.json',
#  'heart_rate-2018-01-11.json',
#  'sedentary_minutes-2017-09-26.json',
#  'heart_rate-2017-07-12.json',
#  'heart_rate-2018-11-11.json',
#  'time_in_heart_rate_zones-2018-09-13.json',
#  'time_in_heart_rate_zones-2018-05-30.json',
#  'exercise-800.json',
#  'calories-2018-03-25.json',
#  'heart_rate-2017-08-21.json',
#  'heart_rate-2018-02-01.json',
#  'heart_rate-2018-12-01.json',
#  'time_in_heart_rate_zones-2019-02-27.json',
#  'time_in_heart_rate_zones-2017-10-23.json',
#  'time_in_heart_rate_zones-2018-06-20.json',
#  'heart_rate-2018-05-05.json',
#  'heart_rate-2018-09-26.json',
#  'distance-2018-09-21.json',
#  'time_in_heart_rate_zones-2017-07-27.json',
#  'heart_rate-2019-01-02.json',
#  'time_in_heart_rate_zones-2018-11-24.json',
#  'time_in_heart_rate_zones-2018-01-24.json',
#  'time_in_heart_rate_zones-2018-03-19.json',
#  'heart_rate-2017-10-16.json',
#  'heart_rate-2018-04-28.json',
#  'heart_rate-2018-06-15.json',
#  'time_in_heart_rate_zones-2018-10-09.json',
#  'heart_rate-2019-02-12.json',
#  'time_in_heart_rate_zones-2017-08-14.json',
#  'sleep-2018-02-23.json',
#  'time_in_heart_rate_zones-2017-10-03.json',
#  'heart_rate-2017-08-01.json',
#  'heart_rate-2018-02-21.json',
#  'very_active_minutes-2018-09-21.json',
#  'heart_rate-2018-12-21.json',
#  'time_in_heart_rate_zones-2019-02-07.json',
#  'altitude-2018-04-24.json',
#  'time_in_heart_rate_zones-2018-05-10.json',
#  'heart_rate-2018-01-31.json',
#  'time_in_heart_rate_zones-2019-01-17.json',
#  'time_in_heart_rate_zones-2018-12-14.json',
#  'time_in_heart_rate_zones-2018-10-29.json',
#  'sedentary_minutes-2019-02-18.json',
#  'calories-2018-08-22.json',
#  'lightly_active_minutes-2018-11-20.json',
#  'time_in_heart_rate_zones-2018-02-14.json',
#  'heart_rate-2018-04-08.json',
#  'time_in_heart_rate_zones-2017-07-07.json',
#  'moderately_active_minutes-2018-04-24.json',
#  'heart_rate-2019-01-22.json',
#  'time_in_heart_rate_zones-2018-11-04.json',
#  'time_in_heart_rate_zones-2018-01-04.json',
#  'time_in_heart_rate_zones-2017-09-19.json',
#  'heart_rate-2018-07-18.json',
#  'heart_rate-2018-05-25.json',
#  'heart_rate-2018-09-06.json',
#  'time_in_heart_rate_zones-2018-02-02.json',
#  'time_in_heart_rate_zones-2017-08-22.json',
#  'heart_rate-2019-02-24.json',
#  'time_in_heart_rate_zones-2018-12-02.json',
#  'heart_rate-2018-06-23.json',
#  'heart_rate-2017-10-20.json',
#  'time_in_heart_rate_zones-2018-01-12.json',
#  'time_in_heart_rate_zones-2018-11-12.json',
#  'heart_rate-2019-03-09.json',
#  'time_in_heart_rate_zones-2017-07-11.json',
#  'heart_rate-2018-09-10.json',
#  'time_in_heart_rate_zones-2018-06-16.json',
#  'time_in_heart_rate_zones-2017-12-28.json',
#  'time_in_heart_rate_zones-2017-10-15.json',
#  'time_in_heart_rate_zones-2018-08-08.json',
#  'heart_rate-2017-06-09.json',
#  'time_in_heart_rate_zones-2019-02-11.json',
#  'heart_rate-2017-08-17.json',
#  'exercise-1700.json',
#  'time_in_heart_rate_zones-2018-05-06.json',
#  'time_in_heart_rate_zones-2018-09-25.json',
#  'distance-2018-11-20.json',
#  'heart_rate-2018-11-27.json',
#  'time_in_heart_rate_zones-2019-01-01.json',
#  'heart_rate-2017-07-24.json',
#  'heart_rate-2018-01-27.json',
#  'heart_rate-2017-12-31.json',
#  'sedentary_minutes-2017-10-26.json',
#  'heart_rate-2018-08-11.json',
#  'steps-2018-01-24.json',
#  'time_in_heart_rate_zones-2018-10-13.json',
#  'heart_rate-2019-02-08.json',
#  'time_in_heart_rate_zones-2017-06-10.json',
#  'moderately_active_minutes-2017-03-30.json',
#  'heart_rate-2018-07-22.json',
#  'heart_rate-2017-11-21.json',
#  'heart_rate-2019-03-25.json',
#  'heart_rate-2019-01-18.json',
#  'moderately_active_minutes-2018-06-23.json',
#  'time_in_heart_rate_zones-2018-03-03.json',
#  'time_in_heart_rate_zones-2017-09-23.json',
#  'heart_rate-2018-10-26.json',
#  'heart_rate-2017-06-25.json',
#  'distance-2018-10-21.json',
#  'time_in_heart_rate_zones-2018-08-24.json',
#  'time_in_heart_rate_zones-2017-12-04.json',
#  'time_in_heart_rate_zones-2018-04-07.json',
#  'altitude-2017-03-30.json',
#  'heart_rate-2017-09-16.json',
#  'heart_rate-2017-07-08.json',
#  'time_in_heart_rate_zones-2019-03-10.json',
#  'time_in_heart_rate_zones-2018-09-09.json',
#  'altitude-2018-06-23.json',
#  'time_in_heart_rate_zones-2018-07-17.json',
#  'time_in_heart_rate_zones-2017-11-14.json',
#  'heart_rate-2018-10-30.json',
#  'time_in_heart_rate_zones-2018-04-11.json',
#  'time_in_heart_rate_zones-2017-12-12.json',
#  'time_in_heart_rate_zones-2019-03-06.json',
#  'heart_rate-2018-03-20.json',
#  'time_in_heart_rate_zones-2017-11-02.json',
#  'time_in_heart_rate_zones-2018-07-01.json',
#  'heart_rate-2018-08-07.json',
#  'heart_rate-2018-06-19.json',
#  'heart_rate-2018-04-24.json',
#  'heart_rate-2017-12-27.json',
#  'time_in_heart_rate_zones-2017-08-18.json',
#  'time_in_heart_rate_zones-2017-06-06.json',
#  'sleep-2017-12-25.json',
#  'time_in_heart_rate_zones-2018-10-05.json',
#  'resting_heart_rate-2016-12-30.json',
#  'very_active_minutes-2017-04-29.json',
#  'heart_rate-2018-05-09.json',
#  'lightly_active_minutes-2018-10-21.json',
#  'time_in_heart_rate_zones-2018-03-15.json',
#  'time_in_heart_rate_zones-2018-01-28.json',
#  'time_in_heart_rate_zones-2018-11-28.json',
#  'demographic_vo2_max-2017-12-30.json',
#  'heart_rate-2018-05-08.json',
#  'altitude-2018-12-20.json',
#  'time_in_heart_rate_zones-2018-01-29.json',
#  'time_in_heart_rate_zones-2018-03-14.json',
#  'time_in_heart_rate_zones-2018-11-29.json',
#  'steps-2018-02-23.json',
#  'very_active_minutes-2017-09-26.json',
#  'heart_rate-2018-08-06.json',
#  'heart_rate-2018-04-25.json',
#  'heart_rate-2018-06-18.json',
#  'heart_rate-2017-12-26.json',
#  'exercise-1500.json',
#  'time_in_heart_rate_zones-2017-08-19.json',
#  'distance-2019-02-18.json',
#  'time_in_heart_rate_zones-2017-06-07.json',
#  'time_in_heart_rate_zones-2018-10-04.json',
#  'moderately_active_minutes-2018-05-24.json',
#  'time_in_heart_rate_zones-2019-03-07.json',
#  'heart_rate-2017-09-01.json',
#  'heart_rate-2018-03-21.json',
#  'time_in_heart_rate_zones-2017-11-03.json',
#  'moderately_active_minutes-2018-12-20.json',
#  'heart_rate-2018-10-31.json',
#  'time_in_heart_rate_zones-2018-04-10.json',
#  'time_in_heart_rate_zones-2017-12-13.json',
#  'altitude-2018-05-24.json',
#  'lightly_active_minutes-2019-02-18.json',
#  'heart_rate-2017-09-17.json',
#  'heart_rate-2017-07-09.json',
#  'sedentary_minutes-2018-11-20.json',
#  'time_in_heart_rate_zones-2019-03-11.json',
#  'time_in_heart_rate_zones-2018-09-08.json',
#  'time_in_heart_rate_zones-2018-07-16.json',
#  'time_in_heart_rate_zones-2017-11-15.json',
#  'heart_rate-2018-10-27.json',
#  'heart_rate-2017-06-24.json',
#  'time_in_heart_rate_zones-2018-08-25.json',
#  'time_in_heart_rate_zones-2017-12-05.json',
#  'time_in_heart_rate_zones-2018-04-06.json',
#  'heart_rate-2018-07-23.json',
#  'heart_rate-2017-11-20.json',
#  'heart_rate-2019-01-19.json',
#  'calories-2017-01-29.json',
#  'heart_rate-2019-03-24.json',
#  'time_in_heart_rate_zones-2018-03-02.json',
#  'time_in_heart_rate_zones-2017-09-22.json',
#  'heart_rate-2017-12-30.json',
#  'heart_rate-2018-08-10.json',
#  'heart_rate-2019-02-09.json',
#  'time_in_heart_rate_zones-2018-10-12.json',
#  'time_in_heart_rate_zones-2017-06-11.json',
#  'time_in_heart_rate_zones-2018-05-07.json',
#  'time_in_heart_rate_zones-2018-09-24.json',
#  'sleep-2018-01-24.json',
#  'heart_rate-2018-11-26.json',
#  'heart_rate-2017-07-25.json',
#  'heart_rate-2018-01-26.json',
#  'time_in_heart_rate_zones-2018-06-17.json',
#  'time_in_heart_rate_zones-2017-10-14.json',
#  'time_in_heart_rate_zones-2017-12-29.json',
#  'altitude-2018-07-23.json',
#  'time_in_heart_rate_zones-2018-08-09.json',
#  'heart_rate-2017-06-08.json',
#  'sedentary_minutes-2018-10-21.json',
#  'time_in_heart_rate_zones-2019-02-10.json',
#  'altitude-2019-01-19.json',
#  'heart_rate-2017-08-16.json',
#  'time_in_heart_rate_zones-2018-01-13.json',
#  'heart_rate-2019-03-08.json',
#  'time_in_heart_rate_zones-2018-11-13.json',
#  'time_in_heart_rate_zones-2017-07-10.json',
#  'heart_rate-2018-09-11.json',
#  'time_in_heart_rate_zones-2018-02-03.json',
#  'time_in_heart_rate_zones-2017-08-23.json',
#  'time_in_heart_rate_zones-2018-12-03.json',
#  'moderately_active_minutes-2018-07-23.json',
#  'heart_rate-2019-02-25.json',
#  'distance-2017-10-26.json',
#  'moderately_active_minutes-2019-01-19.json',
#  'heart_rate-2018-06-22.json',
#  'heart_rate-2017-10-21.json',
#  'time_in_heart_rate_zones-2017-07-06.json',
#  'time_in_heart_rate_zones-2018-11-05.json',
#  'heart_rate-2019-01-23.json',
#  'time_in_heart_rate_zones-2018-01-05.json',
#  'time_in_heart_rate_zones-2017-09-18.json',
#  'heart_rate-2018-05-24.json',
#  'heart_rate-2018-07-19.json',
#  'heart_rate-2018-09-07.json',
#  'very_active_minutes-2017-08-27.json',
#  'time_in_heart_rate_zones-2018-10-28.json',
#  'time_in_heart_rate_zones-2018-12-15.json',
#  'time_in_heart_rate_zones-2018-02-15.json',
#  'heart_rate-2018-04-09.json',
#  'very_active_minutes-2017-05-29.json',
#  'steps-2017-12-25.json',
#  'lightly_active_minutes-2017-10-26.json',
#  'time_in_heart_rate_zones-2018-05-11.json',
#  'heart_rate-2018-01-30.json',
#  'heart_rate-2018-11-30.json',
#  'time_in_heart_rate_zones-2019-01-16.json',
#  'time_in_heart_rate_zones-2017-10-02.json',
#  'time_in_heart_rate_zones-2018-06-01.json',
#  'heart_rate-2018-02-20.json',
#  'time_in_heart_rate_zones-2019-02-06.json',
#  'heart_rate-2018-12-20.json',
#  'heart_rate-2017-10-17.json',
#  'heart_rate-2018-06-14.json',
#  'heart_rate-2018-04-29.json',
#  'heart_rate-2019-02-13.json',
#  'time_in_heart_rate_zones-2018-10-08.json',
#  'time_in_heart_rate_zones-2017-08-15.json',
#  'sleep-2017-02-28.json',
#  'heart_rate-2018-05-04.json',
#  'heart_rate-2018-09-27.json',
#  'time_in_heart_rate_zones-2017-07-26.json',
#  'time_in_heart_rate_zones-2018-11-25.json',
#  'heart_rate-2019-01-03.json',
#  'time_in_heart_rate_zones-2018-03-18.json',
#  'time_in_heart_rate_zones-2018-01-25.json',
#  'heart_rate-2017-08-20.json',
#  'distance-2017-08-27.json',
#  'time_in_heart_rate_zones-2019-02-26.json',
#  'calories-2016-12-30.json',
#  'sedentary_minutes-2017-04-29.json',
#  'time_in_heart_rate_zones-2017-10-22.json',
#  'time_in_heart_rate_zones-2018-06-21.json',
#  'heart_rate-2018-01-10.json',
#  'heart_rate-2017-07-13.json',
#  'heart_rate-2018-11-10.json',
#  'distance-2017-05-29.json',
#  'time_in_heart_rate_zones-2018-09-12.json',
#  'time_in_heart_rate_zones-2018-05-31.json',
#  'heart_rate-2017-06-28.json',
#  'heart_rate-2018-12-16.json',
#  'heart_rate-2018-02-16.json',
#  'time_in_heart_rate_zones-2017-12-09.json',
#  'time_in_heart_rate_zones-2018-08-29.json',
#  'very_active_minutes-2017-10-26.json',
#  'time_in_heart_rate_zones-2019-01-20.json',
#  'heart_rate-2018-11-06.json',
#  'heart_rate-2017-07-05.json',
#  'heart_rate-2018-01-06.json',
#  'time_in_heart_rate_zones-2017-11-19.json',
#  'time_in_heart_rate_zones-2018-05-27.json',
#  'time_in_heart_rate_zones-2018-09-04.json',
#  'heart_rate-2018-06-02.json',
#  'heart_rate-2017-10-01.json',
#  'time_in_heart_rate_zones-2018-02-23.json',
#  'lightly_active_minutes-2017-05-29.json',
#  'time_in_heart_rate_zones-2017-08-03.json',
#  'time_in_heart_rate_zones-2018-12-23.json',
#  'heart_rate-2019-02-05.json',
#  'heart_rate-2018-05-12.json',
#  'calories-2017-11-25.json',
#  'lightly_active_minutes-2017-08-27.json',
#  'heart_rate-2019-03-28.json',
#  'heart_rate-2019-01-15.json',
#  'time_in_heart_rate_zones-2017-07-30.json',
#  'time_in_heart_rate_zones-2018-08-05.json',
#  'time_in_heart_rate_zones-2017-12-25.json',
#  'time_in_heart_rate_zones-2017-10-18.json',
#  'time_in_heart_rate_zones-2018-04-26.json',
#  'heart_rate-2018-10-07.json',
#  'heart_rate-2017-06-04.json',
#  'time_in_heart_rate_zones-2018-09-28.json',
#  'moderately_active_minutes-2017-06-28.json',
#  'heart_rate-2018-03-17.json',
#  'heart_rate-2017-07-29.json',
#  'time_in_heart_rate_zones-2019-03-31.json',
#  'lightly_active_minutes-2017-09-26.json',
#  'heart_rate-2017-12-10.json',
#  'heart_rate-2018-04-13.json',
#  'heart_rate-2018-08-30.json',
#  'heart_rate-2019-03-04.json',
#  'time_in_heart_rate_zones-2018-03-22.json',
#  'time_in_heart_rate_zones-2017-09-02.json',
#  'altitude-2017-06-28.json',
#  'heart_rate-2018-07-03.json',
#  'time_in_heart_rate_zones-2018-02-19.json',
#  'time_in_heart_rate_zones-2017-06-27.json',
#  'time_in_heart_rate_zones-2018-12-19.json',
#  'time_in_heart_rate_zones-2018-10-24.json',
#  'exercise-600.json',
#  'heart_rate-2018-08-26.json',
#  'heart_rate-2018-04-05.json',
#  'heart_rate-2017-12-06.json',
#  'time_in_heart_rate_zones-2017-09-14.json',
#  'time_in_heart_rate_zones-2018-01-09.json',
#  'heart_rate-2019-03-12.json',
#  'time_in_heart_rate_zones-2018-11-09.json',
#  'sedentary_minutes-2018-09-21.json',
#  'heart_rate-2017-11-16.json',
#  'heart_rate-2018-07-15.json',
#  'heart_rate-2018-05-28.json',
#  'time_in_heart_rate_zones-2018-04-30.json',
#  'time_in_heart_rate_zones-2018-08-13.json',
#  'heart_rate-2017-06-12.json',
#  'heart_rate-2018-10-11.json',
#  'very_active_minutes-2019-02-18.json',
#  'time_in_heart_rate_zones-2017-11-23.json',
#  'time_in_heart_rate_zones-2018-07-20.json',
#  'time_in_heart_rate_zones-2019-03-27.json',
#  'run_vo2_max-2016-12-30.json',
#  'distance-2017-09-26.json',
#  'heart_rate-2017-09-21.json',
#  'heart_rate-2018-03-01.json',
#  'time_in_heart_rate_zones-2017-08-16.json',
#  'heart_rate-2019-02-10.json',
#  'time_in_heart_rate_zones-2017-06-08.json',
#  'heart_rate-2018-08-09.json',
#  'heart_rate-2017-12-29.json',
#  'heart_rate-2017-10-14.json',
#  'heart_rate-2018-06-17.json',
#  'time_in_heart_rate_zones-2018-01-26.json',
#  'time_in_heart_rate_zones-2017-07-25.json',
#  'time_in_heart_rate_zones-2018-11-26.json',
#  'heart_rate-2018-09-24.json',
#  'heart_rate-2018-05-07.json',
#  'time_in_heart_rate_zones-2017-10-21.json',
#  'time_in_heart_rate_zones-2018-06-22.json',
#  'time_in_heart_rate_zones-2019-02-25.json',
#  'heart_rate-2018-12-03.json',
#  'heart_rate-2017-08-23.json',
#  'heart_rate-2018-02-03.json',
#  'time_in_heart_rate_zones-2018-09-11.json',
#  'heart_rate-2017-07-10.json',
#  'heart_rate-2018-11-13.json',
#  'time_in_heart_rate_zones-2019-03-08.json',
#  'heart_rate-2018-01-13.json',
#  'calories-2018-10-21.json',
#  'time_in_heart_rate_zones-2018-04-09.json',
#  'heart_rate-2018-02-15.json',
#  'heart_rate-2018-12-15.json',
#  'heart_rate-2018-10-28.json',
#  'time_in_heart_rate_zones-2018-09-07.json',
#  'time_in_heart_rate_zones-2018-07-19.json',
#  'time_in_heart_rate_zones-2018-05-24.json',
#  'heart_rate-2017-09-18.json',
#  'heart_rate-2018-01-05.json',
#  'time_in_heart_rate_zones-2019-01-23.json',
#  'heart_rate-2018-11-05.json',
#  'heart_rate-2017-07-06.json',
#  'time_in_heart_rate_zones-2018-12-20.json',
#  'heart_rate-2019-02-06.json',
#  'time_in_heart_rate_zones-2018-02-20.json',
#  'heart_rate-2018-06-01.json',
#  'heart_rate-2017-10-02.json',
#  'heart_rate-2019-01-16.json',
#  'time_in_heart_rate_zones-2018-11-30.json',
#  'time_in_heart_rate_zones-2018-01-30.json',
#  'heart_rate-2018-05-11.json',
#  'heart_rate-2018-10-04.json',
#  'heart_rate-2017-06-07.json',
#  'heart_rate-2017-08-19.json',
#  'time_in_heart_rate_zones-2017-12-26.json',
#  'time_in_heart_rate_zones-2018-06-18.json',
#  'time_in_heart_rate_zones-2018-04-25.json',
#  'very_active_minutes-2019-03-20.json',
#  'time_in_heart_rate_zones-2018-08-06.json',
#  'heart_rate-2018-11-29.json',
#  'heart_rate-2018-03-14.json',
#  'heart_rate-2018-01-29.json',
#  'sleep-2017-07-28.json',
#  'time_in_heart_rate_zones-2018-05-08.json',
#  'lightly_active_minutes-2018-08-22.json',
#  'calories-2018-11-20.json',
#  'heart_rate-2017-12-13.json',
#  'heart_rate-2018-04-10.json',
#  'exercise-300.json',
#  'time_in_heart_rate_zones-2018-10-31.json',
#  'sedentary_minutes-2017-01-29.json',
#  'heart_rate-2017-11-03.json',
#  'time_in_heart_rate_zones-2018-03-21.json',
#  'steps-2017-06-28.json',
#  'time_in_heart_rate_zones-2017-09-01.json',
#  'heart_rate-2019-03-07.json',
#  'heart_rate-2018-04-06.json',
#  'heart_rate-2017-12-05.json',
#  'distance-2018-08-22.json',
#  'very_active_minutes-2018-03-25.json',
#  'heart_rate-2018-08-25.json',
#  'time_in_heart_rate_zones-2017-06-24.json',
#  'time_in_heart_rate_zones-2018-10-27.json',
#  'heart_rate-2017-11-15.json',
#  'heart_rate-2018-07-16.json',
#  'heart_rate-2018-09-08.json',
#  'heart_rate-2019-03-11.json',
#  'time_in_heart_rate_zones-2017-07-09.json',
#  'time_in_heart_rate_zones-2017-09-17.json',
#  'heart_rate-2017-06-11.json',
#  'heart_rate-2018-10-12.json',
#  'time_in_heart_rate_zones-2019-02-09.json',
#  'time_in_heart_rate_zones-2018-08-10.json',
#  'time_in_heart_rate_zones-2017-12-30.json',
#  'heart_rate-2017-09-22.json',
#  'heart_rate-2018-03-02.json',
#  'time_in_heart_rate_zones-2019-03-24.json',
#  'time_in_heart_rate_zones-2019-01-19.json',
#  'time_in_heart_rate_zones-2017-11-20.json',
#  'time_in_heart_rate_zones-2018-07-23.json',
#  'altitude-2018-02-23.json',
#  'heart_rate-2019-03-31.json',
#  'time_in_heart_rate_zones-2017-07-29.json',
#  'calories-2018-09-21.json',
#  'steps-2018-12-20.json',
#  'time_in_heart_rate_zones-2018-03-17.json',
#  'heart_rate-2018-09-28.json',
#  'sleep-2018-04-24.json',
#  'time_in_heart_rate_zones-2017-06-04.json',
#  'time_in_heart_rate_zones-2018-10-07.json',
#  'heart_rate-2018-04-26.json',
#  'heart_rate-2017-10-18.json',
#  'heart_rate-2017-12-25.json',
#  'heart_rate-2018-08-05.json',
#  'moderately_active_minutes-2018-02-23.json',
#  'time_in_heart_rate_zones-2018-07-03.json',
#  'distance-2018-03-25.json',
#  'very_active_minutes-2018-08-22.json',
#  'heart_rate-2017-09-02.json',
#  'heart_rate-2018-03-22.json',
#  'time_in_heart_rate_zones-2019-03-04.json',
#  'time_in_heart_rate_zones-2018-08-30.json',
#  'steps-2018-05-24.json',
#  'time_in_heart_rate_zones-2018-04-13.json',
#  'time_in_heart_rate_zones-2017-12-10.json',
#  'lightly_active_minutes-2019-03-20.json',
#  'time_in_heart_rate_zones-2018-05-28.json',
#  'time_in_heart_rate_zones-2018-07-15.json',
#  'time_in_heart_rate_zones-2017-11-16.json',
#  'heart_rate-2018-11-09.json',
#  'time_in_heart_rate_zones-2019-03-12.json',
#  'heart_rate-2018-01-09.json',
#  'heart_rate-2017-09-14.json',
#  'time_in_heart_rate_zones-2017-12-06.json',
#  'time_in_heart_rate_zones-2018-04-05.json',
#  'time_in_heart_rate_zones-2018-08-26.json',
#  'heart_rate-2018-10-24.json',
#  'heart_rate-2018-12-19.json',
#  'heart_rate-2017-06-27.json',
#  'heart_rate-2018-02-19.json',
#  'time_in_heart_rate_zones-2018-03-01.json',
#  'time_in_heart_rate_zones-2017-09-21.json',
#  'heart_rate-2019-03-27.json',
#  'distance-2019-03-20.json',
#  'heart_rate-2018-07-20.json',
#  'heart_rate-2017-11-23.json',
#  'time_in_heart_rate_zones-2018-10-11.json',
#  'time_in_heart_rate_zones-2017-06-12.json',
#  'lightly_active_minutes-2018-03-25.json',
#  'heart_rate-2018-08-13.json',
#  'heart_rate-2018-04-30.json',
#  'exercise-1000.json',
#  'heart_rate-2018-01-25.json',
#  'heart_rate-2018-03-18.json',
#  'time_in_heart_rate_zones-2019-01-03.json',
#  'heart_rate-2018-11-25.json',
#  'heart_rate-2017-07-26.json',
#  'time_in_heart_rate_zones-2018-09-27.json',
#  'time_in_heart_rate_zones-2018-05-04.json',
#  'steps-2019-01-19.json',
#  'heart_rate-2017-08-15.json',
#  'heart_rate-2018-10-08.json',
#  'time_in_heart_rate_zones-2019-02-13.json',
#  'steps-2018-07-23.json',
#  'time_in_heart_rate_zones-2018-04-29.json',
#  'time_in_heart_rate_zones-2018-06-14.json',
#  'time_in_heart_rate_zones-2017-10-17.json',
#  'sedentary_minutes-2017-11-25.json',
#  'heart_rate-2018-05-31.json',
#  'heart_rate-2018-09-12.json',
#  'time_in_heart_rate_zones-2018-11-10.json',
#  'time_in_heart_rate_zones-2017-07-13.json',
#  'time_in_heart_rate_zones-2018-01-10.json',
#  'sleep-2017-03-30.json',
#  'heart_rate-2018-06-21.json',
#  'heart_rate-2017-10-22.json',
#  'sleep-2018-06-23.json',
#  'heart_rate-2019-02-26.json',
#  'time_in_heart_rate_zones-2017-08-20.json',
#  'heart_rate-2018-09-04.json',
#  'heart_rate-2018-05-27.json',
#  'heart_rate-2017-11-19.json',
#  'time_in_heart_rate_zones-2018-01-06.json',
#  'moderately_active_minutes-2017-12-25.json',
#  ...]

# %%
#Extracts first three objects of a string.
def first_3_letters(string):
    return string[0:3]

#Takes in a list of strings, extracts the first three objects of each string, and returns a list of unique values from
#the extracted values.
def unique_first_3(alist): 
    result = []
    for i in alist:
        result.append(first_3_letters(i))
    return list(set(result))

#Takes in a list of filenames and groups them according to the first three letters of the filename.
def group_files(list_files):
    starts = unique_first_3(list_files)
    copy_json_files = list_files
    
    grouped_files = [[] for i in range(len(starts))]
    for i in range(len(starts)):
        for j in range(len(list_files)):
            if (starts[i] == first_3_letters(copy_json_files[j])):
                grouped_files[i].append(copy_json_files[j])
    return grouped_files

# %%
json_files
# Out:
# ['time_in_heart_rate_zones-2018-06-06.json',
#  'time_in_heart_rate_zones-2017-10-05.json',
#  'time_in_heart_rate_zones-2018-08-18.json',
#  'heart_rate-2017-06-19.json',
#  'heart_rate-2018-12-27.json',
#  'time_in_heart_rate_zones-2019-02-01.json',
#  'distance-2018-12-20.json',
#  'heart_rate-2018-02-27.json',
#  'heart_rate-2017-08-07.json',
#  'demographic_vo2_max-2018-12-30.json',
#  'time_in_heart_rate_zones-2017-11-28.json',
#  'time_in_heart_rate_zones-2018-05-16.json',
#  'time_in_heart_rate_zones-2019-01-11.json',
#  'altitude-2019-02-18.json',
#  'time_in_heart_rate_zones-2018-02-12.json',
#  'time_in_heart_rate_zones-2018-12-12.json',
#  'steps-2018-03-25.json',
#  'sedentary_minutes-2018-04-24.json',
#  'heart_rate-2017-10-30.json',
#  'time_in_heart_rate_zones-2018-01-02.json',
#  'heart_rate-2019-03-19.json',
#  'heart_rate-2019-01-24.json',
#  'time_in_heart_rate_zones-2018-11-02.json',
#  'time_in_heart_rate_zones-2017-07-01.json',
#  'moderately_active_minutes-2019-02-18.json',
#  'heart_rate-2018-05-23.json',
#  'distance-2018-05-24.json',
#  'heart_rate-2019-02-22.json',
#  'time_in_heart_rate_zones-2018-12-04.json',
#  'time_in_heart_rate_zones-2017-08-24.json',
#  'time_in_heart_rate_zones-2018-02-04.json',
#  'heart_rate-2017-10-26.json',
#  'heart_rate-2018-06-25.json',
#  'heart_rate-2018-04-18.json',
#  'time_in_heart_rate_zones-2017-07-17.json',
#  'time_in_heart_rate_zones-2018-11-14.json',
#  'time_in_heart_rate_zones-2018-03-29.json',
#  'time_in_heart_rate_zones-2018-01-14.json',
#  'lightly_active_minutes-2018-12-20.json',
#  'time_in_heart_rate_zones-2017-09-09.json',
#  'very_active_minutes-2017-06-28.json',
#  'heart_rate-2018-07-08.json',
#  'heart_rate-2018-09-16.json',
#  'lightly_active_minutes-2018-05-24.json',
#  'time_in_heart_rate_zones-2017-10-13.json',
#  'time_in_heart_rate_zones-2018-06-10.json',
#  'heart_rate-2017-08-11.json',
#  'steps-2019-03-20.json',
#  'time_in_heart_rate_zones-2019-02-17.json',
#  'heart_rate-2018-12-31.json',
#  'time_in_heart_rate_zones-2018-09-23.json',
#  'heart_rate-2018-01-21.json',
#  'heart_rate-2017-07-22.json',
#  'heart_rate-2018-11-21.json',
#  'time_in_heart_rate_zones-2019-01-07.json',
#  'heart_rate-2018-08-17.json',
#  'heart_rate-2018-06-09.json',
#  'sedentary_minutes-2018-06-23.json',
#  'time_in_heart_rate_zones-2018-02-28.json',
#  'time_in_heart_rate_zones-2017-08-08.json',
#  'time_in_heart_rate_zones-2017-06-16.json',
#  'time_in_heart_rate_zones-2018-12-28.json',
#  'time_in_heart_rate_zones-2018-10-15.json',
#  'sedentary_minutes-2017-03-30.json',
#  'heart_rate-2017-11-27.json',
#  'heart_rate-2018-07-24.json',
#  'heart_rate-2018-05-19.json',
#  'distance-2018-07-23.json',
#  'time_in_heart_rate_zones-2017-09-25.json',
#  'time_in_heart_rate_zones-2018-03-05.json',
#  'heart_rate-2019-03-23.json',
#  'sleep-2017-11-25.json',
#  'moderately_active_minutes-2017-10-26.json',
#  'distance-2019-01-19.json',
#  'heart_rate-2017-06-23.json',
#  'heart_rate-2018-10-20.json',
#  'time_in_heart_rate_zones-2018-04-01.json',
#  'time_in_heart_rate_zones-2017-12-02.json',
#  'time_in_heart_rate_zones-2018-08-22.json',
#  'time_in_heart_rate_zones-2019-03-16.json',
#  'heart_rate-2017-09-10.json',
#  'heart_rate-2018-03-30.json',
#  'time_in_heart_rate_zones-2017-11-12.json',
#  'time_in_heart_rate_zones-2018-07-11.json',
#  'altitude-2017-10-26.json',
#  'lightly_active_minutes-2019-01-19.json',
#  'sleep-2016-12-30.json',
#  'exercise-1100.json',
#  'lightly_active_minutes-2018-07-23.json',
#  'time_in_heart_rate_zones-2017-12-14.json',
#  'time_in_heart_rate_zones-2017-10-29.json',
#  'time_in_heart_rate_zones-2018-04-17.json',
#  'heart_rate-2018-03-26.json',
#  'heart_rate-2017-09-06.json',
#  'heart_rate-2017-07-18.json',
#  'time_in_heart_rate_zones-2018-09-19.json',
#  'time_in_heart_rate_zones-2018-07-07.json',
#  'time_in_heart_rate_zones-2017-11-04.json',
#  'heart_rate-2017-12-21.json',
#  'heart_rate-2018-04-22.json',
#  'heart_rate-2018-08-01.json',
#  'heart_rate-2019-02-18.json',
#  'calories-2017-02-28.json',
#  'time_in_heart_rate_zones-2018-10-03.json',
#  'heart_rate-2019-01-08.json',
#  'time_in_heart_rate_zones-2018-03-13.json',
#  'moderately_active_minutes-2017-08-27.json',
#  'time_in_heart_rate_zones-2018-07-27.json',
#  'time_in_heart_rate_zones-2017-11-24.json',
#  'heart_rate-2018-03-06.json',
#  'heart_rate-2017-09-26.json',
#  'time_in_heart_rate_zones-2019-03-20.json',
#  'time_in_heart_rate_zones-2018-08-14.json',
#  'moderately_active_minutes-2017-05-29.json',
#  'time_in_heart_rate_zones-2017-10-09.json',
#  'exercise-200.json',
#  'heart_rate-2018-10-16.json',
#  'heart_rate-2017-06-15.json',
#  'altitude-2017-08-27.json',
#  'time_in_heart_rate_zones-2017-05-30.json',
#  'heart_rate-2019-01-28.json',
#  'heart_rate-2019-03-15.json',
#  'time_in_heart_rate_zones-2017-09-13.json',
#  'heart_rate-2018-07-12.json',
#  'heart_rate-2017-11-11.json',
#  'time_in_heart_rate_zones-2018-10-23.json',
#  'time_in_heart_rate_zones-2017-06-20.json',
#  'altitude-2017-05-29.json',
#  'heart_rate-2017-12-01.json',
#  'heart_rate-2018-04-02.json',
#  'heart_rate-2018-08-21.json',
#  'time_in_heart_rate_zones-2017-09-05.json',
#  'time_in_heart_rate_zones-2018-01-18.json',
#  'time_in_heart_rate_zones-2018-03-25.json',
#  'heart_rate-2019-03-03.json',
#  'time_in_heart_rate_zones-2018-11-18.json',
#  'heart_rate-2017-11-07.json',
#  'heart_rate-2018-07-04.json',
#  'time_in_heart_rate_zones-2018-02-08.json',
#  'time_in_heart_rate_zones-2017-08-28.json',
#  'time_in_heart_rate_zones-2018-12-08.json',
#  'heart_rate-2018-04-14.json',
#  'heart_rate-2018-06-29.json',
#  'heart_rate-2017-12-17.json',
#  'calories-2018-01-24.json',
#  'time_in_heart_rate_zones-2018-07-31.json',
#  'heart_rate-2017-09-30.json',
#  'heart_rate-2018-03-10.json',
#  'time_in_heart_rate_zones-2018-04-21.json',
#  'time_in_heart_rate_zones-2017-12-22.json',
#  'very_active_minutes-2019-01-19.json',
#  'time_in_heart_rate_zones-2018-08-02.json',
#  'heart_rate-2017-06-03.json',
#  'very_active_minutes-2018-07-23.json',
#  'heart_rate-2018-05-15.json',
#  'heart_rate-2018-07-28.json',
#  'heart_rate-2019-01-12.json',
#  'sleep-2017-01-29.json',
#  'time_in_heart_rate_zones-2018-03-09.json',
#  'time_in_heart_rate_zones-2017-09-29.json',
#  'heart_rate-2017-10-06.json',
#  'heart_rate-2018-06-05.json',
#  'heart_rate-2019-02-02.json',
#  'time_in_heart_rate_zones-2018-10-19.json',
#  'time_in_heart_rate_zones-2018-12-24.json',
#  'time_in_heart_rate_zones-2017-08-04.json',
#  'time_in_heart_rate_zones-2018-02-24.json',
#  'heart_rate-2018-01-01.json',
#  'sedentary_minutes-2017-07-28.json',
#  'heart_rate-2017-07-02.json',
#  'heart_rate-2018-11-01.json',
#  'time_in_heart_rate_zones-2019-01-27.json',
#  'time_in_heart_rate_zones-2018-09-03.json',
#  'time_in_heart_rate_zones-2018-05-20.json',
#  'heart_rate-2017-08-31.json',
#  'heart_rate-2018-02-11.json',
#  'distance-2017-06-28.json',
#  'heart_rate-2018-12-11.json',
#  'time_in_heart_rate_zones-2018-06-30.json',
#  'time_in_heart_rate_zones-2019-01-31.json',
#  'heart_rate-2018-11-17.json',
#  'heart_rate-2017-07-14.json',
#  'heart_rate-2018-01-17.json',
#  'time_in_heart_rate_zones-2017-11-08.json',
#  'steps-2018-08-22.json',
#  'time_in_heart_rate_zones-2018-09-15.json',
#  'heart_rate-2018-12-07.json',
#  'time_in_heart_rate_zones-2019-02-21.json',
#  'very_active_minutes-2018-05-24.json',
#  'heart_rate-2018-02-07.json',
#  'heart_rate-2017-08-27.json',
#  'time_in_heart_rate_zones-2018-06-26.json',
#  'time_in_heart_rate_zones-2017-10-25.json',
#  'time_in_heart_rate_zones-2017-12-18.json',
#  'moderately_active_minutes-2017-09-26.json',
#  'heart_rate-2018-09-20.json',
#  'heart_rate-2018-05-03.json',
#  'very_active_minutes-2018-12-20.json',
#  'lightly_active_minutes-2017-06-28.json',
#  'time_in_heart_rate_zones-2018-01-22.json',
#  'heart_rate-2019-01-04.json',
#  'time_in_heart_rate_zones-2018-11-22.json',
#  'time_in_heart_rate_zones-2017-07-21.json',
#  'heart_rate-2018-06-13.json',
#  'heart_rate-2017-10-10.json',
#  'time_in_heart_rate_zones-2017-08-12.json',
#  'heart_rate-2019-02-14.json',
#  'altitude-2017-09-26.json',
#  'heart_rate-2018-06-12.json',
#  'heart_rate-2017-10-11.json',
#  'calories-2017-12-25.json',
#  'time_in_heart_rate_zones-2017-08-13.json',
#  'heart_rate-2019-02-15.json',
#  'heart_rate-2018-09-21.json',
#  'heart_rate-2018-05-02.json',
#  'time_in_heart_rate_zones-2018-01-23.json',
#  'altitude-2017-04-29.json',
#  'time_in_heart_rate_zones-2018-11-23.json',
#  'heart_rate-2019-01-05.json',
#  'time_in_heart_rate_zones-2017-07-20.json',
#  'time_in_heart_rate_zones-2019-02-20.json',
#  'heart_rate-2018-12-06.json',
#  'heart_rate-2018-02-06.json',
#  'heart_rate-2017-08-26.json',
#  'time_in_heart_rate_zones-2018-06-27.json',
#  'time_in_heart_rate_zones-2017-12-19.json',
#  'time_in_heart_rate_zones-2017-10-24.json',
#  'heart_rate-2018-11-16.json',
#  'time_in_heart_rate_zones-2019-01-30.json',
#  'heart_rate-2017-07-15.json',
#  'heart_rate-2018-01-16.json',
#  'time_in_heart_rate_zones-2017-11-09.json',
#  'moderately_active_minutes-2017-04-29.json',
#  'time_in_heart_rate_zones-2018-09-14.json',
#  'very_active_minutes-2017-03-30.json',
#  'heart_rate-2017-08-30.json',
#  'heart_rate-2018-02-10.json',
#  'heart_rate-2018-12-10.json',
#  'very_active_minutes-2018-06-23.json',
#  'heart_rate-2017-07-03.json',
#  'time_in_heart_rate_zones-2019-01-26.json',
#  'time_in_heart_rate_zones-2018-09-02.json',
#  'time_in_heart_rate_zones-2018-05-21.json',
#  'heart_rate-2017-10-07.json',
#  'heart_rate-2018-06-04.json',
#  'time_in_heart_rate_zones-2018-12-25.json',
#  'time_in_heart_rate_zones-2018-10-18.json',
#  'heart_rate-2019-02-03.json',
#  'time_in_heart_rate_zones-2017-08-05.json',
#  'time_in_heart_rate_zones-2018-02-25.json',
#  'heart_rate-2018-07-29.json',
#  'heart_rate-2018-05-14.json',
#  'heart_rate-2019-01-13.json',
#  'time_in_heart_rate_zones-2018-03-08.json',
#  'time_in_heart_rate_zones-2017-09-28.json',
#  'time_in_heart_rate_zones-2018-04-20.json',
#  'steps-2017-01-29.json',
#  'time_in_heart_rate_zones-2017-12-23.json',
#  'time_in_heart_rate_zones-2018-08-03.json',
#  'heart_rate-2017-06-02.json',
#  'sedentary_minutes-2017-06-28.json',
#  'heart_rate-2018-10-01.json',
#  'time_in_heart_rate_zones-2018-07-30.json',
#  'distance-2017-07-28.json',
#  'heart_rate-2018-03-11.json',
#  'time_in_heart_rate_zones-2018-02-09.json',
#  'time_in_heart_rate_zones-2017-08-29.json',
#  'time_in_heart_rate_zones-2018-12-09.json',
#  'heart_rate-2018-06-28.json',
#  'heart_rate-2018-04-15.json',
#  'heart_rate-2017-12-16.json',
#  'time_in_heart_rate_zones-2017-09-04.json',
#  'time_in_heart_rate_zones-2018-03-24.json',
#  'time_in_heart_rate_zones-2018-01-19.json',
#  'time_in_heart_rate_zones-2018-11-19.json',
#  'heart_rate-2019-03-02.json',
#  'heart_rate-2017-11-06.json',
#  'heart_rate-2018-07-05.json',
#  'time_in_heart_rate_zones-2018-10-22.json',
#  'time_in_heart_rate_zones-2017-06-21.json',
#  'sleep-2018-08-22.json',
#  'lightly_active_minutes-2017-07-28.json',
#  'moderately_active_minutes-2018-09-21.json',
#  'heart_rate-2018-04-03.json',
#  'heart_rate-2018-08-20.json',
#  'time_in_heart_rate_zones-2017-05-31.json',
#  'heart_rate-2019-03-14.json',
#  'heart_rate-2019-01-29.json',
#  'time_in_heart_rate_zones-2017-09-12.json',
#  'heart_rate-2018-07-13.json',
#  'heart_rate-2017-11-10.json',
#  'time_in_heart_rate_zones-2018-08-15.json',
#  'altitude-2018-09-21.json',
#  'time_in_heart_rate_zones-2017-10-08.json',
#  'calories-2018-02-23.json',
#  'heart_rate-2018-10-17.json',
#  'heart_rate-2017-06-14.json',
#  'time_in_heart_rate_zones-2018-07-26.json',
#  'time_in_heart_rate_zones-2017-11-25.json',
#  'heart_rate-2018-03-07.json',
#  'heart_rate-2017-09-27.json',
#  'very_active_minutes-2018-04-24.json',
#  'time_in_heart_rate_zones-2019-03-21.json',
#  'sedentary_minutes-2018-05-24.json',
#  'heart_rate-2017-11-30.json',
#  'heart_rate-2019-01-09.json',
#  'time_in_heart_rate_zones-2018-03-12.json',
#  'distance-2018-04-24.json',
#  'heart_rate-2017-12-20.json',
#  'heart_rate-2018-04-23.json',
#  'time_in_heart_rate_zones-2018-10-02.json',
#  'heart_rate-2019-02-19.json',
#  'time_in_heart_rate_zones-2017-06-01.json',
#  'heart_rate-2018-03-27.json',
#  'heart_rate-2017-09-07.json',
#  'heart_rate-2017-07-19.json',
#  'time_in_heart_rate_zones-2019-03-01.json',
#  'sleep-2018-03-25.json',
#  'time_in_heart_rate_zones-2018-09-18.json',
#  'time_in_heart_rate_zones-2018-07-06.json',
#  'time_in_heart_rate_zones-2017-11-05.json',
#  'sedentary_minutes-2018-12-20.json',
#  'time_in_heart_rate_zones-2017-10-28.json',
#  'time_in_heart_rate_zones-2017-12-15.json',
#  'time_in_heart_rate_zones-2018-04-16.json',
#  'time_in_heart_rate_zones-2019-03-17.json',
#  'heart_rate-2017-09-11.json',
#  'heart_rate-2018-03-31.json',
#  'time_in_heart_rate_zones-2017-11-13.json',
#  'time_in_heart_rate_zones-2018-07-10.json',
#  'lightly_active_minutes-2018-04-24.json',
#  'heart_rate-2017-06-22.json',
#  'heart_rate-2018-10-21.json',
#  'moderately_active_minutes-2018-11-20.json',
#  'time_in_heart_rate_zones-2017-12-03.json',
#  'time_in_heart_rate_zones-2018-08-23.json',
#  'heart_rate-2017-11-26.json',
#  'sleep-2019-03-20.json',
#  'heart_rate-2018-05-18.json',
#  'heart_rate-2018-07-25.json',
#  'time_in_heart_rate_zones-2017-09-24.json',
#  'time_in_heart_rate_zones-2018-03-04.json',
#  'heart_rate-2019-03-22.json',
#  'heart_rate-2018-08-16.json',
#  'heart_rate-2018-06-08.json',
#  'very_active_minutes-2017-07-28.json',
#  'time_in_heart_rate_zones-2017-08-09.json',
#  'altitude-2018-11-20.json',
#  'time_in_heart_rate_zones-2017-06-17.json',
#  'time_in_heart_rate_zones-2018-10-14.json',
#  'time_in_heart_rate_zones-2018-12-29.json',
#  'time_in_heart_rate_zones-2018-09-22.json',
#  'time_in_heart_rate_zones-2018-05-01.json',
#  'moderately_active_minutes-2018-10-21.json',
#  'heart_rate-2018-01-20.json',
#  'heart_rate-2017-07-23.json',
#  'time_in_heart_rate_zones-2019-01-06.json',
#  'heart_rate-2018-11-20.json',
#  'steps-2017-11-25.json',
#  'time_in_heart_rate_zones-2017-10-12.json',
#  'time_in_heart_rate_zones-2018-06-11.json',
#  'heart_rate-2017-08-10.json',
#  'heart_rate-2018-12-30.json',
#  'time_in_heart_rate_zones-2019-02-16.json',
#  'exercise-1300.json',
#  'time_in_heart_rate_zones-2017-07-16.json',
#  'sedentary_minutes-2019-01-19.json',
#  'time_in_heart_rate_zones-2018-11-15.json',
#  'altitude-2018-10-21.json',
#  'time_in_heart_rate_zones-2018-01-15.json',
#  'time_in_heart_rate_zones-2018-03-28.json',
#  'time_in_heart_rate_zones-2017-09-08.json',
#  'sedentary_minutes-2018-07-23.json',
#  'heart_rate-2018-07-09.json',
#  'distance-2017-03-30.json',
#  'heart_rate-2018-09-17.json',
#  'time_in_heart_rate_zones-2018-12-05.json',
#  'heart_rate-2019-02-23.json',
#  'time_in_heart_rate_zones-2017-08-25.json',
#  'time_in_heart_rate_zones-2018-02-05.json',
#  'distance-2018-06-23.json',
#  'heart_rate-2017-10-27.json',
#  'heart_rate-2018-04-19.json',
#  'heart_rate-2018-06-24.json',
#  'time_in_heart_rate_zones-2018-01-03.json',
#  'time_in_heart_rate_zones-2018-11-03.json',
#  'heart_rate-2019-01-25.json',
#  'heart_rate-2019-03-18.json',
#  'heart_rate-2018-09-01.json',
#  'steps-2016-12-30.json',
#  'heart_rate-2018-05-22.json',
#  'time_in_heart_rate_zones-2018-02-13.json',
#  'time_in_heart_rate_zones-2018-12-13.json',
#  'heart_rate-2017-10-31.json',
#  'time_in_heart_rate_zones-2017-11-29.json',
#  'time_in_heart_rate_zones-2018-05-17.json',
#  'lightly_active_minutes-2018-06-23.json',
#  'time_in_heart_rate_zones-2019-01-10.json',
#  'time_in_heart_rate_zones-2018-06-07.json',
#  'lightly_active_minutes-2017-03-30.json',
#  'time_in_heart_rate_zones-2017-10-04.json',
#  'time_in_heart_rate_zones-2018-08-19.json',
#  'heart_rate-2017-06-18.json',
#  'heart_rate-2018-12-26.json',
#  'heart_rate-2018-02-26.json',
#  'heart_rate-2017-08-06.json',
#  'time_in_heart_rate_zones-2017-11-22.json',
#  'steps-2017-02-28.json',
#  'time_in_heart_rate_zones-2018-07-21.json',
#  'time_in_heart_rate_zones-2019-03-26.json',
#  'sedentary_minutes-2017-05-29.json',
#  'heart_rate-2017-09-20.json',
#  'time_in_heart_rate_zones-2018-08-12.json',
#  'distance-2017-04-29.json',
#  'heart_rate-2017-06-13.json',
#  'heart_rate-2018-10-10.json',
#  'sedentary_minutes-2017-08-27.json',
#  'time_in_heart_rate_zones-2017-09-15.json',
#  'time_in_heart_rate_zones-2018-01-08.json',
#  'time_in_heart_rate_zones-2018-11-08.json',
#  'heart_rate-2019-03-13.json',
#  'heart_rate-2017-11-17.json',
#  'heart_rate-2018-05-29.json',
#  'heart_rate-2018-07-14.json',
#  'time_in_heart_rate_zones-2018-02-18.json',
#  'time_in_heart_rate_zones-2017-06-26.json',
#  'time_in_heart_rate_zones-2018-10-25.json',
#  'time_in_heart_rate_zones-2018-12-18.json',
#  'heart_rate-2018-08-27.json',
#  'heart_rate-2018-04-04.json',
#  'heart_rate-2017-12-07.json',
#  'heart_rate-2019-03-05.json',
#  'lightly_active_minutes-2017-04-29.json',
#  'time_in_heart_rate_zones-2018-03-23.json',
#  'time_in_heart_rate_zones-2017-09-03.json',
#  'heart_rate-2018-07-02.json',
#  'heart_rate-2017-11-01.json',
#  'very_active_minutes-2018-10-21.json',
#  'heart_rate-2019-02-28.json',
#  'time_in_heart_rate_zones-2017-06-30.json',
#  'heart_rate-2017-12-11.json',
#  'heart_rate-2018-04-12.json',
#  'heart_rate-2018-08-31.json',
#  'time_in_heart_rate_zones-2018-09-29.json',
#  'heart_rate-2018-03-16.json',
#  'heart_rate-2017-07-28.json',
#  'time_in_heart_rate_zones-2019-03-30.json',
#  'heart_rate-2019-04-01.json',
#  'time_in_heart_rate_zones-2018-08-04.json',
#  'time_in_heart_rate_zones-2017-10-19.json',
#  'time_in_heart_rate_zones-2017-12-24.json',
#  'time_in_heart_rate_zones-2018-04-27.json',
#  'heart_rate-2018-10-06.json',
#  'heart_rate-2017-06-05.json',
#  'heart_rate-2018-09-30.json',
#  'calories-2019-03-20.json',
#  'heart_rate-2018-05-13.json',
#  'heart_rate-2019-01-14.json',
#  'heart_rate-2019-03-29.json',
#  'time_in_heart_rate_zones-2017-07-31.json',
#  'very_active_minutes-2018-11-20.json',
#  'heart_rate-2018-06-03.json',
#  'altitude-2017-07-28.json',
#  'time_in_heart_rate_zones-2018-02-22.json',
#  'time_in_heart_rate_zones-2017-08-02.json',
#  'heart_rate-2019-02-04.json',
#  'time_in_heart_rate_zones-2018-12-22.json',
#  'exercise-400.json',
#  'heart_rate-2018-11-07.json',
#  'time_in_heart_rate_zones-2019-01-21.json',
#  'heart_rate-2017-07-04.json',
#  'heart_rate-2018-01-07.json',
#  'time_in_heart_rate_zones-2017-11-18.json',
#  'time_in_heart_rate_zones-2018-05-26.json',
#  'time_in_heart_rate_zones-2018-09-05.json',
#  'heart_rate-2017-06-29.json',
#  'heart_rate-2018-12-17.json',
#  'heart_rate-2018-02-17.json',
#  'lightly_active_minutes-2018-09-21.json',
#  'moderately_active_minutes-2017-07-28.json',
#  'time_in_heart_rate_zones-2017-12-08.json',
#  'time_in_heart_rate_zones-2018-08-28.json',
#  'heart_rate-2018-01-11.json',
#  'sedentary_minutes-2017-09-26.json',
#  'heart_rate-2017-07-12.json',
#  'heart_rate-2018-11-11.json',
#  'time_in_heart_rate_zones-2018-09-13.json',
#  'time_in_heart_rate_zones-2018-05-30.json',
#  'exercise-800.json',
#  'calories-2018-03-25.json',
#  'heart_rate-2017-08-21.json',
#  'heart_rate-2018-02-01.json',
#  'heart_rate-2018-12-01.json',
#  'time_in_heart_rate_zones-2019-02-27.json',
#  'time_in_heart_rate_zones-2017-10-23.json',
#  'time_in_heart_rate_zones-2018-06-20.json',
#  'heart_rate-2018-05-05.json',
#  'heart_rate-2018-09-26.json',
#  'distance-2018-09-21.json',
#  'time_in_heart_rate_zones-2017-07-27.json',
#  'heart_rate-2019-01-02.json',
#  'time_in_heart_rate_zones-2018-11-24.json',
#  'time_in_heart_rate_zones-2018-01-24.json',
#  'time_in_heart_rate_zones-2018-03-19.json',
#  'heart_rate-2017-10-16.json',
#  'heart_rate-2018-04-28.json',
#  'heart_rate-2018-06-15.json',
#  'time_in_heart_rate_zones-2018-10-09.json',
#  'heart_rate-2019-02-12.json',
#  'time_in_heart_rate_zones-2017-08-14.json',
#  'sleep-2018-02-23.json',
#  'time_in_heart_rate_zones-2017-10-03.json',
#  'heart_rate-2017-08-01.json',
#  'heart_rate-2018-02-21.json',
#  'very_active_minutes-2018-09-21.json',
#  'heart_rate-2018-12-21.json',
#  'time_in_heart_rate_zones-2019-02-07.json',
#  'altitude-2018-04-24.json',
#  'time_in_heart_rate_zones-2018-05-10.json',
#  'heart_rate-2018-01-31.json',
#  'time_in_heart_rate_zones-2019-01-17.json',
#  'time_in_heart_rate_zones-2018-12-14.json',
#  'time_in_heart_rate_zones-2018-10-29.json',
#  'sedentary_minutes-2019-02-18.json',
#  'calories-2018-08-22.json',
#  'lightly_active_minutes-2018-11-20.json',
#  'time_in_heart_rate_zones-2018-02-14.json',
#  'heart_rate-2018-04-08.json',
#  'time_in_heart_rate_zones-2017-07-07.json',
#  'moderately_active_minutes-2018-04-24.json',
#  'heart_rate-2019-01-22.json',
#  'time_in_heart_rate_zones-2018-11-04.json',
#  'time_in_heart_rate_zones-2018-01-04.json',
#  'time_in_heart_rate_zones-2017-09-19.json',
#  'heart_rate-2018-07-18.json',
#  'heart_rate-2018-05-25.json',
#  'heart_rate-2018-09-06.json',
#  'time_in_heart_rate_zones-2018-02-02.json',
#  'time_in_heart_rate_zones-2017-08-22.json',
#  'heart_rate-2019-02-24.json',
#  'time_in_heart_rate_zones-2018-12-02.json',
#  'heart_rate-2018-06-23.json',
#  'heart_rate-2017-10-20.json',
#  'time_in_heart_rate_zones-2018-01-12.json',
#  'time_in_heart_rate_zones-2018-11-12.json',
#  'heart_rate-2019-03-09.json',
#  'time_in_heart_rate_zones-2017-07-11.json',
#  'heart_rate-2018-09-10.json',
#  'time_in_heart_rate_zones-2018-06-16.json',
#  'time_in_heart_rate_zones-2017-12-28.json',
#  'time_in_heart_rate_zones-2017-10-15.json',
#  'time_in_heart_rate_zones-2018-08-08.json',
#  'heart_rate-2017-06-09.json',
#  'time_in_heart_rate_zones-2019-02-11.json',
#  'heart_rate-2017-08-17.json',
#  'exercise-1700.json',
#  'time_in_heart_rate_zones-2018-05-06.json',
#  'time_in_heart_rate_zones-2018-09-25.json',
#  'distance-2018-11-20.json',
#  'heart_rate-2018-11-27.json',
#  'time_in_heart_rate_zones-2019-01-01.json',
#  'heart_rate-2017-07-24.json',
#  'heart_rate-2018-01-27.json',
#  'heart_rate-2017-12-31.json',
#  'sedentary_minutes-2017-10-26.json',
#  'heart_rate-2018-08-11.json',
#  'steps-2018-01-24.json',
#  'time_in_heart_rate_zones-2018-10-13.json',
#  'heart_rate-2019-02-08.json',
#  'time_in_heart_rate_zones-2017-06-10.json',
#  'moderately_active_minutes-2017-03-30.json',
#  'heart_rate-2018-07-22.json',
#  'heart_rate-2017-11-21.json',
#  'heart_rate-2019-03-25.json',
#  'heart_rate-2019-01-18.json',
#  'moderately_active_minutes-2018-06-23.json',
#  'time_in_heart_rate_zones-2018-03-03.json',
#  'time_in_heart_rate_zones-2017-09-23.json',
#  'heart_rate-2018-10-26.json',
#  'heart_rate-2017-06-25.json',
#  'distance-2018-10-21.json',
#  'time_in_heart_rate_zones-2018-08-24.json',
#  'time_in_heart_rate_zones-2017-12-04.json',
#  'time_in_heart_rate_zones-2018-04-07.json',
#  'altitude-2017-03-30.json',
#  'heart_rate-2017-09-16.json',
#  'heart_rate-2017-07-08.json',
#  'time_in_heart_rate_zones-2019-03-10.json',
#  'time_in_heart_rate_zones-2018-09-09.json',
#  'altitude-2018-06-23.json',
#  'time_in_heart_rate_zones-2018-07-17.json',
#  'time_in_heart_rate_zones-2017-11-14.json',
#  'heart_rate-2018-10-30.json',
#  'time_in_heart_rate_zones-2018-04-11.json',
#  'time_in_heart_rate_zones-2017-12-12.json',
#  'time_in_heart_rate_zones-2019-03-06.json',
#  'heart_rate-2018-03-20.json',
#  'time_in_heart_rate_zones-2017-11-02.json',
#  'time_in_heart_rate_zones-2018-07-01.json',
#  'heart_rate-2018-08-07.json',
#  'heart_rate-2018-06-19.json',
#  'heart_rate-2018-04-24.json',
#  'heart_rate-2017-12-27.json',
#  'time_in_heart_rate_zones-2017-08-18.json',
#  'time_in_heart_rate_zones-2017-06-06.json',
#  'sleep-2017-12-25.json',
#  'time_in_heart_rate_zones-2018-10-05.json',
#  'resting_heart_rate-2016-12-30.json',
#  'very_active_minutes-2017-04-29.json',
#  'heart_rate-2018-05-09.json',
#  'lightly_active_minutes-2018-10-21.json',
#  'time_in_heart_rate_zones-2018-03-15.json',
#  'time_in_heart_rate_zones-2018-01-28.json',
#  'time_in_heart_rate_zones-2018-11-28.json',
#  'demographic_vo2_max-2017-12-30.json',
#  'heart_rate-2018-05-08.json',
#  'altitude-2018-12-20.json',
#  'time_in_heart_rate_zones-2018-01-29.json',
#  'time_in_heart_rate_zones-2018-03-14.json',
#  'time_in_heart_rate_zones-2018-11-29.json',
#  'steps-2018-02-23.json',
#  'very_active_minutes-2017-09-26.json',
#  'heart_rate-2018-08-06.json',
#  'heart_rate-2018-04-25.json',
#  'heart_rate-2018-06-18.json',
#  'heart_rate-2017-12-26.json',
#  'exercise-1500.json',
#  'time_in_heart_rate_zones-2017-08-19.json',
#  'distance-2019-02-18.json',
#  'time_in_heart_rate_zones-2017-06-07.json',
#  'time_in_heart_rate_zones-2018-10-04.json',
#  'moderately_active_minutes-2018-05-24.json',
#  'time_in_heart_rate_zones-2019-03-07.json',
#  'heart_rate-2017-09-01.json',
#  'heart_rate-2018-03-21.json',
#  'time_in_heart_rate_zones-2017-11-03.json',
#  'moderately_active_minutes-2018-12-20.json',
#  'heart_rate-2018-10-31.json',
#  'time_in_heart_rate_zones-2018-04-10.json',
#  'time_in_heart_rate_zones-2017-12-13.json',
#  'altitude-2018-05-24.json',
#  'lightly_active_minutes-2019-02-18.json',
#  'heart_rate-2017-09-17.json',
#  'heart_rate-2017-07-09.json',
#  'sedentary_minutes-2018-11-20.json',
#  'time_in_heart_rate_zones-2019-03-11.json',
#  'time_in_heart_rate_zones-2018-09-08.json',
#  'time_in_heart_rate_zones-2018-07-16.json',
#  'time_in_heart_rate_zones-2017-11-15.json',
#  'heart_rate-2018-10-27.json',
#  'heart_rate-2017-06-24.json',
#  'time_in_heart_rate_zones-2018-08-25.json',
#  'time_in_heart_rate_zones-2017-12-05.json',
#  'time_in_heart_rate_zones-2018-04-06.json',
#  'heart_rate-2018-07-23.json',
#  'heart_rate-2017-11-20.json',
#  'heart_rate-2019-01-19.json',
#  'calories-2017-01-29.json',
#  'heart_rate-2019-03-24.json',
#  'time_in_heart_rate_zones-2018-03-02.json',
#  'time_in_heart_rate_zones-2017-09-22.json',
#  'heart_rate-2017-12-30.json',
#  'heart_rate-2018-08-10.json',
#  'heart_rate-2019-02-09.json',
#  'time_in_heart_rate_zones-2018-10-12.json',
#  'time_in_heart_rate_zones-2017-06-11.json',
#  'time_in_heart_rate_zones-2018-05-07.json',
#  'time_in_heart_rate_zones-2018-09-24.json',
#  'sleep-2018-01-24.json',
#  'heart_rate-2018-11-26.json',
#  'heart_rate-2017-07-25.json',
#  'heart_rate-2018-01-26.json',
#  'time_in_heart_rate_zones-2018-06-17.json',
#  'time_in_heart_rate_zones-2017-10-14.json',
#  'time_in_heart_rate_zones-2017-12-29.json',
#  'altitude-2018-07-23.json',
#  'time_in_heart_rate_zones-2018-08-09.json',
#  'heart_rate-2017-06-08.json',
#  'sedentary_minutes-2018-10-21.json',
#  'time_in_heart_rate_zones-2019-02-10.json',
#  'altitude-2019-01-19.json',
#  'heart_rate-2017-08-16.json',
#  'time_in_heart_rate_zones-2018-01-13.json',
#  'heart_rate-2019-03-08.json',
#  'time_in_heart_rate_zones-2018-11-13.json',
#  'time_in_heart_rate_zones-2017-07-10.json',
#  'heart_rate-2018-09-11.json',
#  'time_in_heart_rate_zones-2018-02-03.json',
#  'time_in_heart_rate_zones-2017-08-23.json',
#  'time_in_heart_rate_zones-2018-12-03.json',
#  'moderately_active_minutes-2018-07-23.json',
#  'heart_rate-2019-02-25.json',
#  'distance-2017-10-26.json',
#  'moderately_active_minutes-2019-01-19.json',
#  'heart_rate-2018-06-22.json',
#  'heart_rate-2017-10-21.json',
#  'time_in_heart_rate_zones-2017-07-06.json',
#  'time_in_heart_rate_zones-2018-11-05.json',
#  'heart_rate-2019-01-23.json',
#  'time_in_heart_rate_zones-2018-01-05.json',
#  'time_in_heart_rate_zones-2017-09-18.json',
#  'heart_rate-2018-05-24.json',
#  'heart_rate-2018-07-19.json',
#  'heart_rate-2018-09-07.json',
#  'very_active_minutes-2017-08-27.json',
#  'time_in_heart_rate_zones-2018-10-28.json',
#  'time_in_heart_rate_zones-2018-12-15.json',
#  'time_in_heart_rate_zones-2018-02-15.json',
#  'heart_rate-2018-04-09.json',
#  'very_active_minutes-2017-05-29.json',
#  'steps-2017-12-25.json',
#  'lightly_active_minutes-2017-10-26.json',
#  'time_in_heart_rate_zones-2018-05-11.json',
#  'heart_rate-2018-01-30.json',
#  'heart_rate-2018-11-30.json',
#  'time_in_heart_rate_zones-2019-01-16.json',
#  'time_in_heart_rate_zones-2017-10-02.json',
#  'time_in_heart_rate_zones-2018-06-01.json',
#  'heart_rate-2018-02-20.json',
#  'time_in_heart_rate_zones-2019-02-06.json',
#  'heart_rate-2018-12-20.json',
#  'heart_rate-2017-10-17.json',
#  'heart_rate-2018-06-14.json',
#  'heart_rate-2018-04-29.json',
#  'heart_rate-2019-02-13.json',
#  'time_in_heart_rate_zones-2018-10-08.json',
#  'time_in_heart_rate_zones-2017-08-15.json',
#  'sleep-2017-02-28.json',
#  'heart_rate-2018-05-04.json',
#  'heart_rate-2018-09-27.json',
#  'time_in_heart_rate_zones-2017-07-26.json',
#  'time_in_heart_rate_zones-2018-11-25.json',
#  'heart_rate-2019-01-03.json',
#  'time_in_heart_rate_zones-2018-03-18.json',
#  'time_in_heart_rate_zones-2018-01-25.json',
#  'heart_rate-2017-08-20.json',
#  'distance-2017-08-27.json',
#  'time_in_heart_rate_zones-2019-02-26.json',
#  'calories-2016-12-30.json',
#  'sedentary_minutes-2017-04-29.json',
#  'time_in_heart_rate_zones-2017-10-22.json',
#  'time_in_heart_rate_zones-2018-06-21.json',
#  'heart_rate-2018-01-10.json',
#  'heart_rate-2017-07-13.json',
#  'heart_rate-2018-11-10.json',
#  'distance-2017-05-29.json',
#  'time_in_heart_rate_zones-2018-09-12.json',
#  'time_in_heart_rate_zones-2018-05-31.json',
#  'heart_rate-2017-06-28.json',
#  'heart_rate-2018-12-16.json',
#  'heart_rate-2018-02-16.json',
#  'time_in_heart_rate_zones-2017-12-09.json',
#  'time_in_heart_rate_zones-2018-08-29.json',
#  'very_active_minutes-2017-10-26.json',
#  'time_in_heart_rate_zones-2019-01-20.json',
#  'heart_rate-2018-11-06.json',
#  'heart_rate-2017-07-05.json',
#  'heart_rate-2018-01-06.json',
#  'time_in_heart_rate_zones-2017-11-19.json',
#  'time_in_heart_rate_zones-2018-05-27.json',
#  'time_in_heart_rate_zones-2018-09-04.json',
#  'heart_rate-2018-06-02.json',
#  'heart_rate-2017-10-01.json',
#  'time_in_heart_rate_zones-2018-02-23.json',
#  'lightly_active_minutes-2017-05-29.json',
#  'time_in_heart_rate_zones-2017-08-03.json',
#  'time_in_heart_rate_zones-2018-12-23.json',
#  'heart_rate-2019-02-05.json',
#  'heart_rate-2018-05-12.json',
#  'calories-2017-11-25.json',
#  'lightly_active_minutes-2017-08-27.json',
#  'heart_rate-2019-03-28.json',
#  'heart_rate-2019-01-15.json',
#  'time_in_heart_rate_zones-2017-07-30.json',
#  'time_in_heart_rate_zones-2018-08-05.json',
#  'time_in_heart_rate_zones-2017-12-25.json',
#  'time_in_heart_rate_zones-2017-10-18.json',
#  'time_in_heart_rate_zones-2018-04-26.json',
#  'heart_rate-2018-10-07.json',
#  'heart_rate-2017-06-04.json',
#  'time_in_heart_rate_zones-2018-09-28.json',
#  'moderately_active_minutes-2017-06-28.json',
#  'heart_rate-2018-03-17.json',
#  'heart_rate-2017-07-29.json',
#  'time_in_heart_rate_zones-2019-03-31.json',
#  'lightly_active_minutes-2017-09-26.json',
#  'heart_rate-2017-12-10.json',
#  'heart_rate-2018-04-13.json',
#  'heart_rate-2018-08-30.json',
#  'heart_rate-2019-03-04.json',
#  'time_in_heart_rate_zones-2018-03-22.json',
#  'time_in_heart_rate_zones-2017-09-02.json',
#  'altitude-2017-06-28.json',
#  'heart_rate-2018-07-03.json',
#  'time_in_heart_rate_zones-2018-02-19.json',
#  'time_in_heart_rate_zones-2017-06-27.json',
#  'time_in_heart_rate_zones-2018-12-19.json',
#  'time_in_heart_rate_zones-2018-10-24.json',
#  'exercise-600.json',
#  'heart_rate-2018-08-26.json',
#  'heart_rate-2018-04-05.json',
#  'heart_rate-2017-12-06.json',
#  'time_in_heart_rate_zones-2017-09-14.json',
#  'time_in_heart_rate_zones-2018-01-09.json',
#  'heart_rate-2019-03-12.json',
#  'time_in_heart_rate_zones-2018-11-09.json',
#  'sedentary_minutes-2018-09-21.json',
#  'heart_rate-2017-11-16.json',
#  'heart_rate-2018-07-15.json',
#  'heart_rate-2018-05-28.json',
#  'time_in_heart_rate_zones-2018-04-30.json',
#  'time_in_heart_rate_zones-2018-08-13.json',
#  'heart_rate-2017-06-12.json',
#  'heart_rate-2018-10-11.json',
#  'very_active_minutes-2019-02-18.json',
#  'time_in_heart_rate_zones-2017-11-23.json',
#  'time_in_heart_rate_zones-2018-07-20.json',
#  'time_in_heart_rate_zones-2019-03-27.json',
#  'run_vo2_max-2016-12-30.json',
#  'distance-2017-09-26.json',
#  'heart_rate-2017-09-21.json',
#  'heart_rate-2018-03-01.json',
#  'time_in_heart_rate_zones-2017-08-16.json',
#  'heart_rate-2019-02-10.json',
#  'time_in_heart_rate_zones-2017-06-08.json',
#  'heart_rate-2018-08-09.json',
#  'heart_rate-2017-12-29.json',
#  'heart_rate-2017-10-14.json',
#  'heart_rate-2018-06-17.json',
#  'time_in_heart_rate_zones-2018-01-26.json',
#  'time_in_heart_rate_zones-2017-07-25.json',
#  'time_in_heart_rate_zones-2018-11-26.json',
#  'heart_rate-2018-09-24.json',
#  'heart_rate-2018-05-07.json',
#  'time_in_heart_rate_zones-2017-10-21.json',
#  'time_in_heart_rate_zones-2018-06-22.json',
#  'time_in_heart_rate_zones-2019-02-25.json',
#  'heart_rate-2018-12-03.json',
#  'heart_rate-2017-08-23.json',
#  'heart_rate-2018-02-03.json',
#  'time_in_heart_rate_zones-2018-09-11.json',
#  'heart_rate-2017-07-10.json',
#  'heart_rate-2018-11-13.json',
#  'time_in_heart_rate_zones-2019-03-08.json',
#  'heart_rate-2018-01-13.json',
#  'calories-2018-10-21.json',
#  'time_in_heart_rate_zones-2018-04-09.json',
#  'heart_rate-2018-02-15.json',
#  'heart_rate-2018-12-15.json',
#  'heart_rate-2018-10-28.json',
#  'time_in_heart_rate_zones-2018-09-07.json',
#  'time_in_heart_rate_zones-2018-07-19.json',
#  'time_in_heart_rate_zones-2018-05-24.json',
#  'heart_rate-2017-09-18.json',
#  'heart_rate-2018-01-05.json',
#  'time_in_heart_rate_zones-2019-01-23.json',
#  'heart_rate-2018-11-05.json',
#  'heart_rate-2017-07-06.json',
#  'time_in_heart_rate_zones-2018-12-20.json',
#  'heart_rate-2019-02-06.json',
#  'time_in_heart_rate_zones-2018-02-20.json',
#  'heart_rate-2018-06-01.json',
#  'heart_rate-2017-10-02.json',
#  'heart_rate-2019-01-16.json',
#  'time_in_heart_rate_zones-2018-11-30.json',
#  'time_in_heart_rate_zones-2018-01-30.json',
#  'heart_rate-2018-05-11.json',
#  'heart_rate-2018-10-04.json',
#  'heart_rate-2017-06-07.json',
#  'heart_rate-2017-08-19.json',
#  'time_in_heart_rate_zones-2017-12-26.json',
#  'time_in_heart_rate_zones-2018-06-18.json',
#  'time_in_heart_rate_zones-2018-04-25.json',
#  'very_active_minutes-2019-03-20.json',
#  'time_in_heart_rate_zones-2018-08-06.json',
#  'heart_rate-2018-11-29.json',
#  'heart_rate-2018-03-14.json',
#  'heart_rate-2018-01-29.json',
#  'sleep-2017-07-28.json',
#  'time_in_heart_rate_zones-2018-05-08.json',
#  'lightly_active_minutes-2018-08-22.json',
#  'calories-2018-11-20.json',
#  'heart_rate-2017-12-13.json',
#  'heart_rate-2018-04-10.json',
#  'exercise-300.json',
#  'time_in_heart_rate_zones-2018-10-31.json',
#  'sedentary_minutes-2017-01-29.json',
#  'heart_rate-2017-11-03.json',
#  'time_in_heart_rate_zones-2018-03-21.json',
#  'steps-2017-06-28.json',
#  'time_in_heart_rate_zones-2017-09-01.json',
#  'heart_rate-2019-03-07.json',
#  'heart_rate-2018-04-06.json',
#  'heart_rate-2017-12-05.json',
#  'distance-2018-08-22.json',
#  'very_active_minutes-2018-03-25.json',
#  'heart_rate-2018-08-25.json',
#  'time_in_heart_rate_zones-2017-06-24.json',
#  'time_in_heart_rate_zones-2018-10-27.json',
#  'heart_rate-2017-11-15.json',
#  'heart_rate-2018-07-16.json',
#  'heart_rate-2018-09-08.json',
#  'heart_rate-2019-03-11.json',
#  'time_in_heart_rate_zones-2017-07-09.json',
#  'time_in_heart_rate_zones-2017-09-17.json',
#  'heart_rate-2017-06-11.json',
#  'heart_rate-2018-10-12.json',
#  'time_in_heart_rate_zones-2019-02-09.json',
#  'time_in_heart_rate_zones-2018-08-10.json',
#  'time_in_heart_rate_zones-2017-12-30.json',
#  'heart_rate-2017-09-22.json',
#  'heart_rate-2018-03-02.json',
#  'time_in_heart_rate_zones-2019-03-24.json',
#  'time_in_heart_rate_zones-2019-01-19.json',
#  'time_in_heart_rate_zones-2017-11-20.json',
#  'time_in_heart_rate_zones-2018-07-23.json',
#  'altitude-2018-02-23.json',
#  'heart_rate-2019-03-31.json',
#  'time_in_heart_rate_zones-2017-07-29.json',
#  'calories-2018-09-21.json',
#  'steps-2018-12-20.json',
#  'time_in_heart_rate_zones-2018-03-17.json',
#  'heart_rate-2018-09-28.json',
#  'sleep-2018-04-24.json',
#  'time_in_heart_rate_zones-2017-06-04.json',
#  'time_in_heart_rate_zones-2018-10-07.json',
#  'heart_rate-2018-04-26.json',
#  'heart_rate-2017-10-18.json',
#  'heart_rate-2017-12-25.json',
#  'heart_rate-2018-08-05.json',
#  'moderately_active_minutes-2018-02-23.json',
#  'time_in_heart_rate_zones-2018-07-03.json',
#  'distance-2018-03-25.json',
#  'very_active_minutes-2018-08-22.json',
#  'heart_rate-2017-09-02.json',
#  'heart_rate-2018-03-22.json',
#  'time_in_heart_rate_zones-2019-03-04.json',
#  'time_in_heart_rate_zones-2018-08-30.json',
#  'steps-2018-05-24.json',
#  'time_in_heart_rate_zones-2018-04-13.json',
#  'time_in_heart_rate_zones-2017-12-10.json',
#  'lightly_active_minutes-2019-03-20.json',
#  'time_in_heart_rate_zones-2018-05-28.json',
#  'time_in_heart_rate_zones-2018-07-15.json',
#  'time_in_heart_rate_zones-2017-11-16.json',
#  'heart_rate-2018-11-09.json',
#  'time_in_heart_rate_zones-2019-03-12.json',
#  'heart_rate-2018-01-09.json',
#  'heart_rate-2017-09-14.json',
#  'time_in_heart_rate_zones-2017-12-06.json',
#  'time_in_heart_rate_zones-2018-04-05.json',
#  'time_in_heart_rate_zones-2018-08-26.json',
#  'heart_rate-2018-10-24.json',
#  'heart_rate-2018-12-19.json',
#  'heart_rate-2017-06-27.json',
#  'heart_rate-2018-02-19.json',
#  'time_in_heart_rate_zones-2018-03-01.json',
#  'time_in_heart_rate_zones-2017-09-21.json',
#  'heart_rate-2019-03-27.json',
#  'distance-2019-03-20.json',
#  'heart_rate-2018-07-20.json',
#  'heart_rate-2017-11-23.json',
#  'time_in_heart_rate_zones-2018-10-11.json',
#  'time_in_heart_rate_zones-2017-06-12.json',
#  'lightly_active_minutes-2018-03-25.json',
#  'heart_rate-2018-08-13.json',
#  'heart_rate-2018-04-30.json',
#  'exercise-1000.json',
#  'heart_rate-2018-01-25.json',
#  'heart_rate-2018-03-18.json',
#  'time_in_heart_rate_zones-2019-01-03.json',
#  'heart_rate-2018-11-25.json',
#  'heart_rate-2017-07-26.json',
#  'time_in_heart_rate_zones-2018-09-27.json',
#  'time_in_heart_rate_zones-2018-05-04.json',
#  'steps-2019-01-19.json',
#  'heart_rate-2017-08-15.json',
#  'heart_rate-2018-10-08.json',
#  'time_in_heart_rate_zones-2019-02-13.json',
#  'steps-2018-07-23.json',
#  'time_in_heart_rate_zones-2018-04-29.json',
#  'time_in_heart_rate_zones-2018-06-14.json',
#  'time_in_heart_rate_zones-2017-10-17.json',
#  'sedentary_minutes-2017-11-25.json',
#  'heart_rate-2018-05-31.json',
#  'heart_rate-2018-09-12.json',
#  'time_in_heart_rate_zones-2018-11-10.json',
#  'time_in_heart_rate_zones-2017-07-13.json',
#  'time_in_heart_rate_zones-2018-01-10.json',
#  'sleep-2017-03-30.json',
#  'heart_rate-2018-06-21.json',
#  'heart_rate-2017-10-22.json',
#  'sleep-2018-06-23.json',
#  'heart_rate-2019-02-26.json',
#  'time_in_heart_rate_zones-2017-08-20.json',
#  'heart_rate-2018-09-04.json',
#  'heart_rate-2018-05-27.json',
#  'heart_rate-2017-11-19.json',
#  'time_in_heart_rate_zones-2018-01-06.json',
#  'moderately_active_minutes-2017-12-25.json',
#  ...]

# %%
grouped = group_files(json_files)
grouped
# Out:
# [['time_in_heart_rate_zones-2018-06-06.json',
#   'time_in_heart_rate_zones-2017-10-05.json',
#   'time_in_heart_rate_zones-2018-08-18.json',
#   'time_in_heart_rate_zones-2019-02-01.json',
#   'time_in_heart_rate_zones-2017-11-28.json',
#   'time_in_heart_rate_zones-2018-05-16.json',
#   'time_in_heart_rate_zones-2019-01-11.json',
#   'time_in_heart_rate_zones-2018-02-12.json',
#   'time_in_heart_rate_zones-2018-12-12.json',
#   'time_in_heart_rate_zones-2018-01-02.json',
#   'time_in_heart_rate_zones-2018-11-02.json',
#   'time_in_heart_rate_zones-2017-07-01.json',
#   'time_in_heart_rate_zones-2018-12-04.json',
#   'time_in_heart_rate_zones-2017-08-24.json',
#   'time_in_heart_rate_zones-2018-02-04.json',
#   'time_in_heart_rate_zones-2017-07-17.json',
#   'time_in_heart_rate_zones-2018-11-14.json',
#   'time_in_heart_rate_zones-2018-03-29.json',
#   'time_in_heart_rate_zones-2018-01-14.json',
#   'time_in_heart_rate_zones-2017-09-09.json',
#   'time_in_heart_rate_zones-2017-10-13.json',
#   'time_in_heart_rate_zones-2018-06-10.json',
#   'time_in_heart_rate_zones-2019-02-17.json',
#   'time_in_heart_rate_zones-2018-09-23.json',
#   'time_in_heart_rate_zones-2019-01-07.json',
#   'time_in_heart_rate_zones-2018-02-28.json',
#   'time_in_heart_rate_zones-2017-08-08.json',
#   'time_in_heart_rate_zones-2017-06-16.json',
#   'time_in_heart_rate_zones-2018-12-28.json',
#   'time_in_heart_rate_zones-2018-10-15.json',
#   'time_in_heart_rate_zones-2017-09-25.json',
#   'time_in_heart_rate_zones-2018-03-05.json',
#   'time_in_heart_rate_zones-2018-04-01.json',
#   'time_in_heart_rate_zones-2017-12-02.json',
#   'time_in_heart_rate_zones-2018-08-22.json',
#   'time_in_heart_rate_zones-2019-03-16.json',
#   'time_in_heart_rate_zones-2017-11-12.json',
#   'time_in_heart_rate_zones-2018-07-11.json',
#   'time_in_heart_rate_zones-2017-12-14.json',
#   'time_in_heart_rate_zones-2017-10-29.json',
#   'time_in_heart_rate_zones-2018-04-17.json',
#   'time_in_heart_rate_zones-2018-09-19.json',
#   'time_in_heart_rate_zones-2018-07-07.json',
#   'time_in_heart_rate_zones-2017-11-04.json',
#   'time_in_heart_rate_zones-2018-10-03.json',
#   'time_in_heart_rate_zones-2018-03-13.json',
#   'time_in_heart_rate_zones-2018-07-27.json',
#   'time_in_heart_rate_zones-2017-11-24.json',
#   'time_in_heart_rate_zones-2019-03-20.json',
#   'time_in_heart_rate_zones-2018-08-14.json',
#   'time_in_heart_rate_zones-2017-10-09.json',
#   'time_in_heart_rate_zones-2017-05-30.json',
#   'time_in_heart_rate_zones-2017-09-13.json',
#   'time_in_heart_rate_zones-2018-10-23.json',
#   'time_in_heart_rate_zones-2017-06-20.json',
#   'time_in_heart_rate_zones-2017-09-05.json',
#   'time_in_heart_rate_zones-2018-01-18.json',
#   'time_in_heart_rate_zones-2018-03-25.json',
#   'time_in_heart_rate_zones-2018-11-18.json',
#   'time_in_heart_rate_zones-2018-02-08.json',
#   'time_in_heart_rate_zones-2017-08-28.json',
#   'time_in_heart_rate_zones-2018-12-08.json',
#   'time_in_heart_rate_zones-2018-07-31.json',
#   'time_in_heart_rate_zones-2018-04-21.json',
#   'time_in_heart_rate_zones-2017-12-22.json',
#   'time_in_heart_rate_zones-2018-08-02.json',
#   'time_in_heart_rate_zones-2018-03-09.json',
#   'time_in_heart_rate_zones-2017-09-29.json',
#   'time_in_heart_rate_zones-2018-10-19.json',
#   'time_in_heart_rate_zones-2018-12-24.json',
#   'time_in_heart_rate_zones-2017-08-04.json',
#   'time_in_heart_rate_zones-2018-02-24.json',
#   'time_in_heart_rate_zones-2019-01-27.json',
#   'time_in_heart_rate_zones-2018-09-03.json',
#   'time_in_heart_rate_zones-2018-05-20.json',
#   'time_in_heart_rate_zones-2018-06-30.json',
#   'time_in_heart_rate_zones-2019-01-31.json',
#   'time_in_heart_rate_zones-2017-11-08.json',
#   'time_in_heart_rate_zones-2018-09-15.json',
#   'time_in_heart_rate_zones-2019-02-21.json',
#   'time_in_heart_rate_zones-2018-06-26.json',
#   'time_in_heart_rate_zones-2017-10-25.json',
#   'time_in_heart_rate_zones-2017-12-18.json',
#   'time_in_heart_rate_zones-2018-01-22.json',
#   'time_in_heart_rate_zones-2018-11-22.json',
#   'time_in_heart_rate_zones-2017-07-21.json',
#   'time_in_heart_rate_zones-2017-08-12.json',
#   'time_in_heart_rate_zones-2017-08-13.json',
#   'time_in_heart_rate_zones-2018-01-23.json',
#   'time_in_heart_rate_zones-2018-11-23.json',
#   'time_in_heart_rate_zones-2017-07-20.json',
#   'time_in_heart_rate_zones-2019-02-20.json',
#   'time_in_heart_rate_zones-2018-06-27.json',
#   'time_in_heart_rate_zones-2017-12-19.json',
#   'time_in_heart_rate_zones-2017-10-24.json',
#   'time_in_heart_rate_zones-2019-01-30.json',
#   'time_in_heart_rate_zones-2017-11-09.json',
#   'time_in_heart_rate_zones-2018-09-14.json',
#   'time_in_heart_rate_zones-2019-01-26.json',
#   'time_in_heart_rate_zones-2018-09-02.json',
#   'time_in_heart_rate_zones-2018-05-21.json',
#   'time_in_heart_rate_zones-2018-12-25.json',
#   'time_in_heart_rate_zones-2018-10-18.json',
#   'time_in_heart_rate_zones-2017-08-05.json',
#   'time_in_heart_rate_zones-2018-02-25.json',
#   'time_in_heart_rate_zones-2018-03-08.json',
#   'time_in_heart_rate_zones-2017-09-28.json',
#   'time_in_heart_rate_zones-2018-04-20.json',
#   'time_in_heart_rate_zones-2017-12-23.json',
#   'time_in_heart_rate_zones-2018-08-03.json',
#   'time_in_heart_rate_zones-2018-07-30.json',
#   'time_in_heart_rate_zones-2018-02-09.json',
#   'time_in_heart_rate_zones-2017-08-29.json',
#   'time_in_heart_rate_zones-2018-12-09.json',
#   'time_in_heart_rate_zones-2017-09-04.json',
#   'time_in_heart_rate_zones-2018-03-24.json',
#   'time_in_heart_rate_zones-2018-01-19.json',
#   'time_in_heart_rate_zones-2018-11-19.json',
#   'time_in_heart_rate_zones-2018-10-22.json',
#   'time_in_heart_rate_zones-2017-06-21.json',
#   'time_in_heart_rate_zones-2017-05-31.json',
#   'time_in_heart_rate_zones-2017-09-12.json',
#   'time_in_heart_rate_zones-2018-08-15.json',
#   'time_in_heart_rate_zones-2017-10-08.json',
#   'time_in_heart_rate_zones-2018-07-26.json',
#   'time_in_heart_rate_zones-2017-11-25.json',
#   'time_in_heart_rate_zones-2019-03-21.json',
#   'time_in_heart_rate_zones-2018-03-12.json',
#   'time_in_heart_rate_zones-2018-10-02.json',
#   'time_in_heart_rate_zones-2017-06-01.json',
#   'time_in_heart_rate_zones-2019-03-01.json',
#   'time_in_heart_rate_zones-2018-09-18.json',
#   'time_in_heart_rate_zones-2018-07-06.json',
#   'time_in_heart_rate_zones-2017-11-05.json',
#   'time_in_heart_rate_zones-2017-10-28.json',
#   'time_in_heart_rate_zones-2017-12-15.json',
#   'time_in_heart_rate_zones-2018-04-16.json',
#   'time_in_heart_rate_zones-2019-03-17.json',
#   'time_in_heart_rate_zones-2017-11-13.json',
#   'time_in_heart_rate_zones-2018-07-10.json',
#   'time_in_heart_rate_zones-2017-12-03.json',
#   'time_in_heart_rate_zones-2018-08-23.json',
#   'time_in_heart_rate_zones-2017-09-24.json',
#   'time_in_heart_rate_zones-2018-03-04.json',
#   'time_in_heart_rate_zones-2017-08-09.json',
#   'time_in_heart_rate_zones-2017-06-17.json',
#   'time_in_heart_rate_zones-2018-10-14.json',
#   'time_in_heart_rate_zones-2018-12-29.json',
#   'time_in_heart_rate_zones-2018-09-22.json',
#   'time_in_heart_rate_zones-2018-05-01.json',
#   'time_in_heart_rate_zones-2019-01-06.json',
#   'time_in_heart_rate_zones-2017-10-12.json',
#   'time_in_heart_rate_zones-2018-06-11.json',
#   'time_in_heart_rate_zones-2019-02-16.json',
#   'time_in_heart_rate_zones-2017-07-16.json',
#   'time_in_heart_rate_zones-2018-11-15.json',
#   'time_in_heart_rate_zones-2018-01-15.json',
#   'time_in_heart_rate_zones-2018-03-28.json',
#   'time_in_heart_rate_zones-2017-09-08.json',
#   'time_in_heart_rate_zones-2018-12-05.json',
#   'time_in_heart_rate_zones-2017-08-25.json',
#   'time_in_heart_rate_zones-2018-02-05.json',
#   'time_in_heart_rate_zones-2018-01-03.json',
#   'time_in_heart_rate_zones-2018-11-03.json',
#   'time_in_heart_rate_zones-2018-02-13.json',
#   'time_in_heart_rate_zones-2018-12-13.json',
#   'time_in_heart_rate_zones-2017-11-29.json',
#   'time_in_heart_rate_zones-2018-05-17.json',
#   'time_in_heart_rate_zones-2019-01-10.json',
#   'time_in_heart_rate_zones-2018-06-07.json',
#   'time_in_heart_rate_zones-2017-10-04.json',
#   'time_in_heart_rate_zones-2018-08-19.json',
#   'time_in_heart_rate_zones-2017-11-22.json',
#   'time_in_heart_rate_zones-2018-07-21.json',
#   'time_in_heart_rate_zones-2019-03-26.json',
#   'time_in_heart_rate_zones-2018-08-12.json',
#   'time_in_heart_rate_zones-2017-09-15.json',
#   'time_in_heart_rate_zones-2018-01-08.json',
#   'time_in_heart_rate_zones-2018-11-08.json',
#   'time_in_heart_rate_zones-2018-02-18.json',
#   'time_in_heart_rate_zones-2017-06-26.json',
#   'time_in_heart_rate_zones-2018-10-25.json',
#   'time_in_heart_rate_zones-2018-12-18.json',
#   'time_in_heart_rate_zones-2018-03-23.json',
#   'time_in_heart_rate_zones-2017-09-03.json',
#   'time_in_heart_rate_zones-2017-06-30.json',
#   'time_in_heart_rate_zones-2018-09-29.json',
#   'time_in_heart_rate_zones-2019-03-30.json',
#   'time_in_heart_rate_zones-2018-08-04.json',
#   'time_in_heart_rate_zones-2017-10-19.json',
#   'time_in_heart_rate_zones-2017-12-24.json',
#   'time_in_heart_rate_zones-2018-04-27.json',
#   'time_in_heart_rate_zones-2017-07-31.json',
#   'time_in_heart_rate_zones-2018-02-22.json',
#   'time_in_heart_rate_zones-2017-08-02.json',
#   'time_in_heart_rate_zones-2018-12-22.json',
#   'time_in_heart_rate_zones-2019-01-21.json',
#   'time_in_heart_rate_zones-2017-11-18.json',
#   'time_in_heart_rate_zones-2018-05-26.json',
#   'time_in_heart_rate_zones-2018-09-05.json',
#   'time_in_heart_rate_zones-2017-12-08.json',
#   'time_in_heart_rate_zones-2018-08-28.json',
#   'time_in_heart_rate_zones-2018-09-13.json',
#   'time_in_heart_rate_zones-2018-05-30.json',
#   'time_in_heart_rate_zones-2019-02-27.json',
#   'time_in_heart_rate_zones-2017-10-23.json',
#   'time_in_heart_rate_zones-2018-06-20.json',
#   'time_in_heart_rate_zones-2017-07-27.json',
#   'time_in_heart_rate_zones-2018-11-24.json',
#   'time_in_heart_rate_zones-2018-01-24.json',
#   'time_in_heart_rate_zones-2018-03-19.json',
#   'time_in_heart_rate_zones-2018-10-09.json',
#   'time_in_heart_rate_zones-2017-08-14.json',
#   'time_in_heart_rate_zones-2017-10-03.json',
#   'time_in_heart_rate_zones-2019-02-07.json',
#   'time_in_heart_rate_zones-2018-05-10.json',
#   'time_in_heart_rate_zones-2019-01-17.json',
#   'time_in_heart_rate_zones-2018-12-14.json',
#   'time_in_heart_rate_zones-2018-10-29.json',
#   'time_in_heart_rate_zones-2018-02-14.json',
#   'time_in_heart_rate_zones-2017-07-07.json',
#   'time_in_heart_rate_zones-2018-11-04.json',
#   'time_in_heart_rate_zones-2018-01-04.json',
#   'time_in_heart_rate_zones-2017-09-19.json',
#   'time_in_heart_rate_zones-2018-02-02.json',
#   'time_in_heart_rate_zones-2017-08-22.json',
#   'time_in_heart_rate_zones-2018-12-02.json',
#   'time_in_heart_rate_zones-2018-01-12.json',
#   'time_in_heart_rate_zones-2018-11-12.json',
#   'time_in_heart_rate_zones-2017-07-11.json',
#   'time_in_heart_rate_zones-2018-06-16.json',
#   'time_in_heart_rate_zones-2017-12-28.json',
#   'time_in_heart_rate_zones-2017-10-15.json',
#   'time_in_heart_rate_zones-2018-08-08.json',
#   'time_in_heart_rate_zones-2019-02-11.json',
#   'time_in_heart_rate_zones-2018-05-06.json',
#   'time_in_heart_rate_zones-2018-09-25.json',
#   'time_in_heart_rate_zones-2019-01-01.json',
#   'time_in_heart_rate_zones-2018-10-13.json',
#   'time_in_heart_rate_zones-2017-06-10.json',
#   'time_in_heart_rate_zones-2018-03-03.json',
#   'time_in_heart_rate_zones-2017-09-23.json',
#   'time_in_heart_rate_zones-2018-08-24.json',
#   'time_in_heart_rate_zones-2017-12-04.json',
#   'time_in_heart_rate_zones-2018-04-07.json',
#   'time_in_heart_rate_zones-2019-03-10.json',
#   'time_in_heart_rate_zones-2018-09-09.json',
#   'time_in_heart_rate_zones-2018-07-17.json',
#   'time_in_heart_rate_zones-2017-11-14.json',
#   'time_in_heart_rate_zones-2018-04-11.json',
#   'time_in_heart_rate_zones-2017-12-12.json',
#   'time_in_heart_rate_zones-2019-03-06.json',
#   'time_in_heart_rate_zones-2017-11-02.json',
#   'time_in_heart_rate_zones-2018-07-01.json',
#   'time_in_heart_rate_zones-2017-08-18.json',
#   'time_in_heart_rate_zones-2017-06-06.json',
#   'time_in_heart_rate_zones-2018-10-05.json',
#   'time_in_heart_rate_zones-2018-03-15.json',
#   'time_in_heart_rate_zones-2018-01-28.json',
#   'time_in_heart_rate_zones-2018-11-28.json',
#   'time_in_heart_rate_zones-2018-01-29.json',
#   'time_in_heart_rate_zones-2018-03-14.json',
#   'time_in_heart_rate_zones-2018-11-29.json',
#   'time_in_heart_rate_zones-2017-08-19.json',
#   'time_in_heart_rate_zones-2017-06-07.json',
#   'time_in_heart_rate_zones-2018-10-04.json',
#   'time_in_heart_rate_zones-2019-03-07.json',
#   'time_in_heart_rate_zones-2017-11-03.json',
#   'time_in_heart_rate_zones-2018-04-10.json',
#   'time_in_heart_rate_zones-2017-12-13.json',
#   'time_in_heart_rate_zones-2019-03-11.json',
#   'time_in_heart_rate_zones-2018-09-08.json',
#   'time_in_heart_rate_zones-2018-07-16.json',
#   'time_in_heart_rate_zones-2017-11-15.json',
#   'time_in_heart_rate_zones-2018-08-25.json',
#   'time_in_heart_rate_zones-2017-12-05.json',
#   'time_in_heart_rate_zones-2018-04-06.json',
#   'time_in_heart_rate_zones-2018-03-02.json',
#   'time_in_heart_rate_zones-2017-09-22.json',
#   'time_in_heart_rate_zones-2018-10-12.json',
#   'time_in_heart_rate_zones-2017-06-11.json',
#   'time_in_heart_rate_zones-2018-05-07.json',
#   'time_in_heart_rate_zones-2018-09-24.json',
#   'time_in_heart_rate_zones-2018-06-17.json',
#   'time_in_heart_rate_zones-2017-10-14.json',
#   'time_in_heart_rate_zones-2017-12-29.json',
#   'time_in_heart_rate_zones-2018-08-09.json',
#   'time_in_heart_rate_zones-2019-02-10.json',
#   'time_in_heart_rate_zones-2018-01-13.json',
#   'time_in_heart_rate_zones-2018-11-13.json',
#   'time_in_heart_rate_zones-2017-07-10.json',
#   'time_in_heart_rate_zones-2018-02-03.json',
#   'time_in_heart_rate_zones-2017-08-23.json',
#   'time_in_heart_rate_zones-2018-12-03.json',
#   'time_in_heart_rate_zones-2017-07-06.json',
#   'time_in_heart_rate_zones-2018-11-05.json',
#   'time_in_heart_rate_zones-2018-01-05.json',
#   'time_in_heart_rate_zones-2017-09-18.json',
#   'time_in_heart_rate_zones-2018-10-28.json',
#   'time_in_heart_rate_zones-2018-12-15.json',
#   'time_in_heart_rate_zones-2018-02-15.json',
#   'time_in_heart_rate_zones-2018-05-11.json',
#   'time_in_heart_rate_zones-2019-01-16.json',
#   'time_in_heart_rate_zones-2017-10-02.json',
#   'time_in_heart_rate_zones-2018-06-01.json',
#   'time_in_heart_rate_zones-2019-02-06.json',
#   'time_in_heart_rate_zones-2018-10-08.json',
#   'time_in_heart_rate_zones-2017-08-15.json',
#   'time_in_heart_rate_zones-2017-07-26.json',
#   'time_in_heart_rate_zones-2018-11-25.json',
#   'time_in_heart_rate_zones-2018-03-18.json',
#   'time_in_heart_rate_zones-2018-01-25.json',
#   'time_in_heart_rate_zones-2019-02-26.json',
#   'time_in_heart_rate_zones-2017-10-22.json',
#   'time_in_heart_rate_zones-2018-06-21.json',
#   'time_in_heart_rate_zones-2018-09-12.json',
#   'time_in_heart_rate_zones-2018-05-31.json',
#   'time_in_heart_rate_zones-2017-12-09.json',
#   'time_in_heart_rate_zones-2018-08-29.json',
#   'time_in_heart_rate_zones-2019-01-20.json',
#   'time_in_heart_rate_zones-2017-11-19.json',
#   'time_in_heart_rate_zones-2018-05-27.json',
#   'time_in_heart_rate_zones-2018-09-04.json',
#   'time_in_heart_rate_zones-2018-02-23.json',
#   'time_in_heart_rate_zones-2017-08-03.json',
#   'time_in_heart_rate_zones-2018-12-23.json',
#   'time_in_heart_rate_zones-2017-07-30.json',
#   'time_in_heart_rate_zones-2018-08-05.json',
#   'time_in_heart_rate_zones-2017-12-25.json',
#   'time_in_heart_rate_zones-2017-10-18.json',
#   'time_in_heart_rate_zones-2018-04-26.json',
#   'time_in_heart_rate_zones-2018-09-28.json',
#   'time_in_heart_rate_zones-2019-03-31.json',
#   'time_in_heart_rate_zones-2018-03-22.json',
#   'time_in_heart_rate_zones-2017-09-02.json',
#   'time_in_heart_rate_zones-2018-02-19.json',
#   'time_in_heart_rate_zones-2017-06-27.json',
#   'time_in_heart_rate_zones-2018-12-19.json',
#   'time_in_heart_rate_zones-2018-10-24.json',
#   'time_in_heart_rate_zones-2017-09-14.json',
#   'time_in_heart_rate_zones-2018-01-09.json',
#   'time_in_heart_rate_zones-2018-11-09.json',
#   'time_in_heart_rate_zones-2018-04-30.json',
#   'time_in_heart_rate_zones-2018-08-13.json',
#   'time_in_heart_rate_zones-2017-11-23.json',
#   'time_in_heart_rate_zones-2018-07-20.json',
#   'time_in_heart_rate_zones-2019-03-27.json',
#   'time_in_heart_rate_zones-2017-08-16.json',
#   'time_in_heart_rate_zones-2017-06-08.json',
#   'time_in_heart_rate_zones-2018-01-26.json',
#   'time_in_heart_rate_zones-2017-07-25.json',
#   'time_in_heart_rate_zones-2018-11-26.json',
#   'time_in_heart_rate_zones-2017-10-21.json',
#   'time_in_heart_rate_zones-2018-06-22.json',
#   'time_in_heart_rate_zones-2019-02-25.json',
#   'time_in_heart_rate_zones-2018-09-11.json',
#   'time_in_heart_rate_zones-2019-03-08.json',
#   'time_in_heart_rate_zones-2018-04-09.json',
#   'time_in_heart_rate_zones-2018-09-07.json',
#   'time_in_heart_rate_zones-2018-07-19.json',
#   'time_in_heart_rate_zones-2018-05-24.json',
#   'time_in_heart_rate_zones-2019-01-23.json',
#   'time_in_heart_rate_zones-2018-12-20.json',
#   'time_in_heart_rate_zones-2018-02-20.json',
#   'time_in_heart_rate_zones-2018-11-30.json',
#   'time_in_heart_rate_zones-2018-01-30.json',
#   'time_in_heart_rate_zones-2017-12-26.json',
#   'time_in_heart_rate_zones-2018-06-18.json',
#   'time_in_heart_rate_zones-2018-04-25.json',
#   'time_in_heart_rate_zones-2018-08-06.json',
#   'time_in_heart_rate_zones-2018-05-08.json',
#   'time_in_heart_rate_zones-2018-10-31.json',
#   'time_in_heart_rate_zones-2018-03-21.json',
#   'time_in_heart_rate_zones-2017-09-01.json',
#   'time_in_heart_rate_zones-2017-06-24.json',
#   'time_in_heart_rate_zones-2018-10-27.json',
#   'time_in_heart_rate_zones-2017-07-09.json',
#   'time_in_heart_rate_zones-2017-09-17.json',
#   'time_in_heart_rate_zones-2019-02-09.json',
#   'time_in_heart_rate_zones-2018-08-10.json',
#   'time_in_heart_rate_zones-2017-12-30.json',
#   'time_in_heart_rate_zones-2019-03-24.json',
#   'time_in_heart_rate_zones-2019-01-19.json',
#   'time_in_heart_rate_zones-2017-11-20.json',
#   'time_in_heart_rate_zones-2018-07-23.json',
#   'time_in_heart_rate_zones-2017-07-29.json',
#   'time_in_heart_rate_zones-2018-03-17.json',
#   'time_in_heart_rate_zones-2017-06-04.json',
#   'time_in_heart_rate_zones-2018-10-07.json',
#   'time_in_heart_rate_zones-2018-07-03.json',
#   'time_in_heart_rate_zones-2019-03-04.json',
#   'time_in_heart_rate_zones-2018-08-30.json',
#   'time_in_heart_rate_zones-2018-04-13.json',
#   'time_in_heart_rate_zones-2017-12-10.json',
#   'time_in_heart_rate_zones-2018-05-28.json',
#   'time_in_heart_rate_zones-2018-07-15.json',
#   'time_in_heart_rate_zones-2017-11-16.json',
#   'time_in_heart_rate_zones-2019-03-12.json',
#   'time_in_heart_rate_zones-2017-12-06.json',
#   'time_in_heart_rate_zones-2018-04-05.json',
#   'time_in_heart_rate_zones-2018-08-26.json',
#   'time_in_heart_rate_zones-2018-03-01.json',
#   'time_in_heart_rate_zones-2017-09-21.json',
#   'time_in_heart_rate_zones-2018-10-11.json',
#   'time_in_heart_rate_zones-2017-06-12.json',
#   'time_in_heart_rate_zones-2019-01-03.json',
#   'time_in_heart_rate_zones-2018-09-27.json',
#   'time_in_heart_rate_zones-2018-05-04.json',
#   'time_in_heart_rate_zones-2019-02-13.json',
#   'time_in_heart_rate_zones-2018-04-29.json',
#   'time_in_heart_rate_zones-2018-06-14.json',
#   'time_in_heart_rate_zones-2017-10-17.json',
#   'time_in_heart_rate_zones-2018-11-10.json',
#   'time_in_heart_rate_zones-2017-07-13.json',
#   'time_in_heart_rate_zones-2018-01-10.json',
#   'time_in_heart_rate_zones-2017-08-20.json',
#   'time_in_heart_rate_zones-2018-01-06.json',
#   'time_in_heart_rate_zones-2017-07-05.json',
#   'time_in_heart_rate_zones-2018-11-06.json',
#   'time_in_heart_rate_zones-2018-02-16.json',
#   'time_in_heart_rate_zones-2018-12-16.json',
#   'time_in_heart_rate_zones-2017-06-28.json',
#   'time_in_heart_rate_zones-2019-01-15.json',
#   'time_in_heart_rate_zones-2019-03-28.json',
#   'time_in_heart_rate_zones-2018-05-12.json',
#   'time_in_heart_rate_zones-2019-02-05.json',
#   'time_in_heart_rate_zones-2017-10-01.json',
#   'time_in_heart_rate_zones-2018-06-02.json',
#   'time_in_heart_rate_zones-2019-02-04.json',
#   'time_in_heart_rate_zones-2018-06-03.json',
#   'time_in_heart_rate_zones-2019-03-29.json',
#   'time_in_heart_rate_zones-2019-01-14.json',
#   'time_in_heart_rate_zones-2018-05-13.json',
#   'time_in_heart_rate_zones-2018-09-30.json',
#   'time_in_heart_rate_zones-2018-02-17.json',
#   'time_in_heart_rate_zones-2018-12-17.json',
#   'time_in_heart_rate_zones-2017-06-29.json',
#   'time_in_heart_rate_zones-2018-01-07.json',
#   'time_in_heart_rate_zones-2017-07-04.json',
#   'time_in_heart_rate_zones-2018-11-07.json',
#   'time_in_heart_rate_zones-2018-12-01.json',
#   'time_in_heart_rate_zones-2018-02-01.json',
#   'time_in_heart_rate_zones-2017-08-21.json',
#   'time_in_heart_rate_zones-2018-11-11.json',
#   'time_in_heart_rate_zones-2017-07-12.json',
#   'time_in_heart_rate_zones-2018-01-11.json',
#   'time_in_heart_rate_zones-2019-02-12.json',
#   'time_in_heart_rate_zones-2018-06-15.json',
#   'time_in_heart_rate_zones-2018-04-28.json',
#   'time_in_heart_rate_zones-2017-10-16.json',
#   'time_in_heart_rate_zones-2019-01-02.json',
#   'time_in_heart_rate_zones-2018-09-26.json',
#   'time_in_heart_rate_zones-2018-05-05.json',
#   'time_in_heart_rate_zones-2018-10-10.json',
#   'time_in_heart_rate_zones-2017-06-13.json',
#   'time_in_heart_rate_zones-2017-09-20.json',
#   'time_in_heart_rate_zones-2017-12-07.json',
#   'time_in_heart_rate_zones-2018-04-04.json',
#   'time_in_heart_rate_zones-2018-08-27.json',
#   'time_in_heart_rate_zones-2018-07-14.json',
#   'time_in_heart_rate_zones-2018-05-29.json',
#   'time_in_heart_rate_zones-2017-11-17.json',
#   'time_in_heart_rate_zones-2019-03-13.json',
#   'time_in_heart_rate_zones-2018-08-31.json',
#   'time_in_heart_rate_zones-2018-04-12.json',
#   'time_in_heart_rate_zones-2017-12-11.json',
#   'time_in_heart_rate_zones-2019-02-28.json',
#   'time_in_heart_rate_zones-2017-11-01.json',
#   'time_in_heart_rate_zones-2018-07-02.json',
#   'time_in_heart_rate_zones-2019-03-05.json',
#   'time_in_heart_rate_zones-2017-06-05.json',
#   'time_in_heart_rate_zones-2018-10-06.json',
#   'time_in_heart_rate_zones-2019-04-01.json',
#   'time_in_heart_rate_zones-2017-07-28.json',
#   'time_in_heart_rate_zones-2018-03-16.json',
#   'time_in_heart_rate_zones-2019-01-18.json',
#   'time_in_heart_rate_zones-2019-03-25.json',
#   'time_in_heart_rate_zones-2017-11-21.json',
#   'time_in_heart_rate_zones-2018-07-22.json',
#   'time_in_heart_rate_zones-2019-02-08.json',
#   'time_in_heart_rate_zones-2018-08-11.json',
#   'time_in_heart_rate_zones-2017-12-31.json',
#   'time_in_heart_rate_zones-2017-07-08.json',
#   'time_in_heart_rate_zones-2017-09-16.json',
#   'time_in_heart_rate_zones-2017-06-25.json',
#   'time_in_heart_rate_zones-2018-10-26.json',
#   'time_in_heart_rate_zones-2018-03-20.json',
#   'time_in_heart_rate_zones-2018-10-30.json',
#   'time_in_heart_rate_zones-2018-05-09.json',
#   'time_in_heart_rate_zones-2017-12-27.json',
#   'time_in_heart_rate_zones-2018-04-24.json',
#   'time_in_heart_rate_zones-2018-06-19.json',
#   'time_in_heart_rate_zones-2018-08-07.json',
#   'time_in_heart_rate_zones-2018-01-31.json',
#   'time_in_heart_rate_zones-2018-12-21.json',
#   'time_in_heart_rate_zones-2018-02-21.json',
#   'time_in_heart_rate_zones-2017-08-01.json',
#   'time_in_heart_rate_zones-2018-09-06.json',
#   'time_in_heart_rate_zones-2018-05-25.json',
#   'time_in_heart_rate_zones-2018-07-18.json',
#   'time_in_heart_rate_zones-2019-01-22.json',
#   'time_in_heart_rate_zones-2018-04-08.json',
#   'time_in_heart_rate_zones-2018-09-10.json',
#   'time_in_heart_rate_zones-2019-03-09.json',
#   'time_in_heart_rate_zones-2017-10-20.json',
#   'time_in_heart_rate_zones-2018-06-23.json',
#   'time_in_heart_rate_zones-2019-02-24.json',
#   'time_in_heart_rate_zones-2018-01-27.json',
#   'time_in_heart_rate_zones-2017-07-24.json',
#   'time_in_heart_rate_zones-2018-11-27.json',
#   'time_in_heart_rate_zones-2017-08-17.json',
#   'time_in_heart_rate_zones-2017-06-09.json',
#   'time_in_heart_rate_zones-2018-03-11.json',
#   'time_in_heart_rate_zones-2018-10-01.json',
#   'time_in_heart_rate_zones-2017-06-02.json',
#   'time_in_heart_rate_zones-2018-07-05.json',
#   'time_in_heart_rate_zones-2017-11-06.json',
#   'time_in_heart_rate_zones-2019-03-02.json',
#   'time_in_heart_rate_zones-2017-12-16.json',
#   'time_in_heart_rate_zones-2018-04-15.json',
#   'time_in_heart_rate_zones-2018-06-28.json',
#   'time_in_heart_rate_zones-2017-11-10.json',
#   'time_in_heart_rate_zones-2018-07-13.json',
#   'time_in_heart_rate_zones-2019-01-29.json',
#   'time_in_heart_rate_zones-2019-03-14.json',
#   'time_in_heart_rate_zones-2018-08-20.json',
#   'time_in_heart_rate_zones-2018-04-03.json',
#   'time_in_heart_rate_zones-2017-09-27.json',
#   'time_in_heart_rate_zones-2018-03-07.json',
#   'time_in_heart_rate_zones-2017-06-14.json',
#   'time_in_heart_rate_zones-2018-10-17.json',
#   'time_in_heart_rate_zones-2019-01-05.json',
#   'time_in_heart_rate_zones-2018-05-02.json',
#   'time_in_heart_rate_zones-2018-09-21.json',
#   'time_in_heart_rate_zones-2019-02-15.json',
#   'time_in_heart_rate_zones-2017-10-11.json',
#   'time_in_heart_rate_zones-2018-06-12.json',
#   'time_in_heart_rate_zones-2018-01-16.json',
#   'time_in_heart_rate_zones-2017-07-15.json',
#   'time_in_heart_rate_zones-2018-11-16.json',
#   'time_in_heart_rate_zones-2017-08-26.json',
#   'time_in_heart_rate_zones-2018-02-06.json',
#   'time_in_heart_rate_zones-2018-12-06.json',
#   'time_in_heart_rate_zones-2017-07-03.json',
#   'time_in_heart_rate_zones-2018-12-10.json',
#   'time_in_heart_rate_zones-2018-02-10.json',
#   'time_in_heart_rate_zones-2017-08-30.json',
#   'time_in_heart_rate_zones-2019-01-13.json',
#   'time_in_heart_rate_zones-2018-05-14.json',
#   'time_in_heart_rate_zones-2018-07-29.json',
#   'time_in_heart_rate_zones-2019-02-03.json',
#   'time_in_heart_rate_zones-2018-06-04.json',
#   'time_in_heart_rate_zones-2017-10-07.json',
#   'time_in_heart_rate_zones-2018-12-30.json',
#   'time_in_heart_rate_zones-2017-08-10.json',
#   'time_in_heart_rate_zones-2018-11-20.json',
#   'time_in_heart_rate_zones-2017-07-23.json',
#   'time_in_heart_rate_zones-2018-01-20.json',
#   'time_in_heart_rate_zones-2018-06-24.json',
#   'time_in_heart_rate_zones-2018-04-19.json',
#   'time_in_heart_rate_zones-2017-10-27.json',
#   'time_in_heart_rate_zones-2019-02-23.json',
#   'time_in_heart_rate_zones-2018-09-17.json',
#   'time_in_heart_rate_zones-2018-07-09.json',
#   'time_in_heart_rate_zones-2017-10-31.json',
#   'time_in_heart_rate_zones-2018-05-22.json',
#   'time_in_heart_rate_zones-2018-09-01.json',
#   'time_in_heart_rate_zones-2019-03-18.json',
#   'time_in_heart_rate_zones-2019-01-25.json',
#   'time_in_heart_rate_zones-2017-08-06.json',
#   'time_in_heart_rate_zones-2018-02-26.json',
#   'time_in_heart_rate_zones-2018-12-26.json',
#   'time_in_heart_rate_zones-2017-06-18.json',
#   'time_in_heart_rate_zones-2019-02-19.json',
#   'time_in_heart_rate_zones-2018-04-23.json',
#   'time_in_heart_rate_zones-2017-12-20.json',
#   'time_in_heart_rate_zones-2019-01-09.json',
#   'time_in_heart_rate_zones-2017-11-30.json',
#   'time_in_heart_rate_zones-2017-07-19.json',
#   'time_in_heart_rate_zones-2017-09-07.json',
#   'time_in_heart_rate_zones-2018-03-27.json',
#   'time_in_heart_rate_zones-2018-10-21.json',
#   'time_in_heart_rate_zones-2017-06-22.json',
#   'time_in_heart_rate_zones-2018-03-31.json',
#   'time_in_heart_rate_zones-2017-09-11.json',
#   'time_in_heart_rate_zones-2018-06-08.json',
#   'time_in_heart_rate_zones-2018-08-16.json',
#   'time_in_heart_rate_zones-2019-03-22.json',
#   'time_in_heart_rate_zones-2018-07-25.json',
#   'time_in_heart_rate_zones-2018-05-18.json',
#   'time_in_heart_rate_zones-2017-11-26.json',
#   'time_in_heart_rate_zones-2019-03-23.json',
#   'time_in_heart_rate_zones-2018-05-19.json',
#   'time_in_heart_rate_zones-2018-07-24.json',
#   'time_in_heart_rate_zones-2017-11-27.json',
#   'time_in_heart_rate_zones-2018-06-09.json',
#   'time_in_heart_rate_zones-2018-08-17.json',
#   'time_in_heart_rate_zones-2018-03-30.json',
#   'time_in_heart_rate_zones-2017-09-10.json',
#   'time_in_heart_rate_zones-2018-10-20.json',
#   'time_in_heart_rate_zones-2017-06-23.json',
#   'time_in_heart_rate_zones-2017-07-18.json',
#   'time_in_heart_rate_zones-2017-09-06.json',
#   'time_in_heart_rate_zones-2018-03-26.json',
#   'time_in_heart_rate_zones-2019-01-08.json',
#   'time_in_heart_rate_zones-2019-02-18.json',
#   'time_in_heart_rate_zones-2018-08-01.json',
#   'time_in_heart_rate_zones-2018-04-22.json',
#   'time_in_heart_rate_zones-2017-12-21.json',
#   'time_in_heart_rate_zones-2017-08-07.json',
#   'time_in_heart_rate_zones-2018-02-27.json',
#   'time_in_heart_rate_zones-2018-12-27.json',
#   'time_in_heart_rate_zones-2017-06-19.json',
#   'time_in_heart_rate_zones-2018-05-23.json',
#   'time_in_heart_rate_zones-2019-01-24.json',
#   'time_in_heart_rate_zones-2019-03-19.json',
#   'time_in_heart_rate_zones-2017-10-30.json',
#   'time_in_heart_rate_zones-2018-09-16.json',
#   'time_in_heart_rate_zones-2018-07-08.json',
#   'time_in_heart_rate_zones-2018-04-18.json',
#   'time_in_heart_rate_zones-2018-06-25.json',
#   'time_in_heart_rate_zones-2017-10-26.json',
#   'time_in_heart_rate_zones-2019-02-22.json',
#   'time_in_heart_rate_zones-2018-11-21.json',
#   'time_in_heart_rate_zones-2017-07-22.json',
#   'time_in_heart_rate_zones-2018-01-21.json',
#   'time_in_heart_rate_zones-2018-12-31.json',
#   'time_in_heart_rate_zones-2017-08-11.json',
#   'time_in_heart_rate_zones-2019-02-02.json',
#   'time_in_heart_rate_zones-2018-06-05.json',
#   'time_in_heart_rate_zones-2017-10-06.json',
#   'time_in_heart_rate_zones-2019-01-12.json',
#   'time_in_heart_rate_zones-2018-07-28.json',
#   'time_in_heart_rate_zones-2018-05-15.json',
#   'time_in_heart_rate_zones-2018-12-11.json',
#   'time_in_heart_rate_zones-2018-02-11.json',
#   'time_in_heart_rate_zones-2017-08-31.json',
#   'time_in_heart_rate_zones-2018-11-01.json',
#   'time_in_heart_rate_zones-2017-07-02.json',
#   'time_in_heart_rate_zones-2018-01-01.json',
#   'time_in_heart_rate_zones-2017-08-27.json',
#   'time_in_heart_rate_zones-2018-02-07.json',
#   'time_in_heart_rate_zones-2018-12-07.json',
#   'time_in_heart_rate_zones-2018-01-17.json',
#   'time_in_heart_rate_zones-2017-07-14.json',
#   'time_in_heart_rate_zones-2018-11-17.json',
#   'time_in_heart_rate_zones-2019-02-14.json',
#   'time_in_heart_rate_zones-2017-10-10.json',
#   'time_in_heart_rate_zones-2018-06-13.json',
#   'time_in_heart_rate_zones-2019-01-04.json',
#   'time_in_heart_rate_zones-2018-05-03.json',
#   'time_in_heart_rate_zones-2018-09-20.json',
#   'time_in_heart_rate_zones-2017-06-15.json',
#   'time_in_heart_rate_zones-2018-10-16.json',
#   'time_in_heart_rate_zones-2017-09-26.json',
#   'time_in_heart_rate_zones-2018-03-06.json',
#   'time_in_heart_rate_zones-2018-08-21.json',
#   'time_in_heart_rate_zones-2018-04-02.json',
#   'time_in_heart_rate_zones-2017-12-01.json',
#   'time_in_heart_rate_zones-2017-11-11.json',
#   'time_in_heart_rate_zones-2018-07-12.json',
#   'time_in_heart_rate_zones-2019-03-15.json',
#   'time_in_heart_rate_zones-2019-01-28.json',
#   'time_in_heart_rate_zones-2017-12-17.json',
#   'time_in_heart_rate_zones-2018-06-29.json',
#   'time_in_heart_rate_zones-2018-04-14.json',
#   'time_in_heart_rate_zones-2018-07-04.json',
#   'time_in_heart_rate_zones-2017-11-07.json',
#   'time_in_heart_rate_zones-2019-03-03.json',
#   'time_in_heart_rate_zones-2017-06-03.json',
#   'time_in_heart_rate_zones-2018-03-10.json',
#   'time_in_heart_rate_zones-2017-09-30.json'],
#  ['sedentary_minutes-2018-04-24.json',
#   'sedentary_minutes-2018-06-23.json',
#   'sedentary_minutes-2017-03-30.json',
#   'sedentary_minutes-2017-07-28.json',
#   'sedentary_minutes-2017-06-28.json',
#   'sedentary_minutes-2018-05-24.json',
#   'sedentary_minutes-2018-12-20.json',
#   'sedentary_minutes-2019-01-19.json',
#   'sedentary_minutes-2018-07-23.json',
#   'sedentary_minutes-2017-05-29.json',
#   'sedentary_minutes-2017-08-27.json',
#   'sedentary_minutes-2017-09-26.json',
#   'sedentary_minutes-2019-02-18.json',
#   'sedentary_minutes-2017-10-26.json',
#   'sedentary_minutes-2018-11-20.json',
#   'sedentary_minutes-2018-10-21.json',
#   'sedentary_minutes-2017-04-29.json',
#   'sedentary_minutes-2018-09-21.json',
#   'sedentary_minutes-2017-01-29.json',
#   'sedentary_minutes-2017-11-25.json',
#   'sedentary_minutes-2016-12-30.json',
#   'sedentary_minutes-2018-03-25.json',
#   'sedentary_minutes-2019-03-20.json',
#   'sedentary_minutes-2018-08-22.json',
#   'sedentary_minutes-2018-02-23.json',
#   'sedentary_minutes-2017-12-25.json',
#   'sedentary_minutes-2017-02-28.json',
#   'sedentary_minutes-2018-01-24.json'],
#  ['moderately_active_minutes-2019-02-18.json',
#   'moderately_active_minutes-2017-10-26.json',
#   'moderately_active_minutes-2017-08-27.json',
#   'moderately_active_minutes-2017-05-29.json',
#   'moderately_active_minutes-2017-09-26.json',
#   'moderately_active_minutes-2017-04-29.json',
#   'moderately_active_minutes-2018-09-21.json',
#   'moderately_active_minutes-2018-11-20.json',
#   'moderately_active_minutes-2018-10-21.json',
#   'moderately_active_minutes-2017-07-28.json',
#   'moderately_active_minutes-2018-04-24.json',
#   'moderately_active_minutes-2017-03-30.json',
#   'moderately_active_minutes-2018-06-23.json',
#   'moderately_active_minutes-2018-05-24.json',
#   'moderately_active_minutes-2018-12-20.json',
#   'moderately_active_minutes-2018-07-23.json',
#   'moderately_active_minutes-2019-01-19.json',
#   'moderately_active_minutes-2017-06-28.json',
#   'moderately_active_minutes-2018-02-23.json',
#   'moderately_active_minutes-2017-12-25.json',
#   'moderately_active_minutes-2018-01-24.json',
#   'moderately_active_minutes-2017-02-28.json',
#   'moderately_active_minutes-2017-11-25.json',
#   'moderately_active_minutes-2016-12-30.json',
#   'moderately_active_minutes-2017-01-29.json',
#   'moderately_active_minutes-2018-08-22.json',
#   'moderately_active_minutes-2018-03-25.json',
#   'moderately_active_minutes-2019-03-20.json'],
#  ['heart_rate-2017-06-19.json',
#   'heart_rate-2018-12-27.json',
#   'heart_rate-2018-02-27.json',
#   'heart_rate-2017-08-07.json',
#   'heart_rate-2017-10-30.json',
#   'heart_rate-2019-03-19.json',
#   'heart_rate-2019-01-24.json',
#   'heart_rate-2018-05-23.json',
#   'heart_rate-2019-02-22.json',
#   'heart_rate-2017-10-26.json',
#   'heart_rate-2018-06-25.json',
#   'heart_rate-2018-04-18.json',
#   'heart_rate-2018-07-08.json',
#   'heart_rate-2018-09-16.json',
#   'heart_rate-2017-08-11.json',
#   'heart_rate-2018-12-31.json',
#   'heart_rate-2018-01-21.json',
#   'heart_rate-2017-07-22.json',
#   'heart_rate-2018-11-21.json',
#   'heart_rate-2018-08-17.json',
#   'heart_rate-2018-06-09.json',
#   'heart_rate-2017-11-27.json',
#   'heart_rate-2018-07-24.json',
#   'heart_rate-2018-05-19.json',
#   'heart_rate-2019-03-23.json',
#   'heart_rate-2017-06-23.json',
#   'heart_rate-2018-10-20.json',
#   'heart_rate-2017-09-10.json',
#   'heart_rate-2018-03-30.json',
#   'heart_rate-2018-03-26.json',
#   'heart_rate-2017-09-06.json',
#   'heart_rate-2017-07-18.json',
#   'heart_rate-2017-12-21.json',
#   'heart_rate-2018-04-22.json',
#   'heart_rate-2018-08-01.json',
#   'heart_rate-2019-02-18.json',
#   'heart_rate-2019-01-08.json',
#   'heart_rate-2018-03-06.json',
#   'heart_rate-2017-09-26.json',
#   'heart_rate-2018-10-16.json',
#   'heart_rate-2017-06-15.json',
#   'heart_rate-2019-01-28.json',
#   'heart_rate-2019-03-15.json',
#   'heart_rate-2018-07-12.json',
#   'heart_rate-2017-11-11.json',
#   'heart_rate-2017-12-01.json',
#   'heart_rate-2018-04-02.json',
#   'heart_rate-2018-08-21.json',
#   'heart_rate-2019-03-03.json',
#   'heart_rate-2017-11-07.json',
#   'heart_rate-2018-07-04.json',
#   'heart_rate-2018-04-14.json',
#   'heart_rate-2018-06-29.json',
#   'heart_rate-2017-12-17.json',
#   'heart_rate-2017-09-30.json',
#   'heart_rate-2018-03-10.json',
#   'heart_rate-2017-06-03.json',
#   'heart_rate-2018-05-15.json',
#   'heart_rate-2018-07-28.json',
#   'heart_rate-2019-01-12.json',
#   'heart_rate-2017-10-06.json',
#   'heart_rate-2018-06-05.json',
#   'heart_rate-2019-02-02.json',
#   'heart_rate-2018-01-01.json',
#   'heart_rate-2017-07-02.json',
#   'heart_rate-2018-11-01.json',
#   'heart_rate-2017-08-31.json',
#   'heart_rate-2018-02-11.json',
#   'heart_rate-2018-12-11.json',
#   'heart_rate-2018-11-17.json',
#   'heart_rate-2017-07-14.json',
#   'heart_rate-2018-01-17.json',
#   'heart_rate-2018-12-07.json',
#   'heart_rate-2018-02-07.json',
#   'heart_rate-2017-08-27.json',
#   'heart_rate-2018-09-20.json',
#   'heart_rate-2018-05-03.json',
#   'heart_rate-2019-01-04.json',
#   'heart_rate-2018-06-13.json',
#   'heart_rate-2017-10-10.json',
#   'heart_rate-2019-02-14.json',
#   'heart_rate-2018-06-12.json',
#   'heart_rate-2017-10-11.json',
#   'heart_rate-2019-02-15.json',
#   'heart_rate-2018-09-21.json',
#   'heart_rate-2018-05-02.json',
#   'heart_rate-2019-01-05.json',
#   'heart_rate-2018-12-06.json',
#   'heart_rate-2018-02-06.json',
#   'heart_rate-2017-08-26.json',
#   'heart_rate-2018-11-16.json',
#   'heart_rate-2017-07-15.json',
#   'heart_rate-2018-01-16.json',
#   'heart_rate-2017-08-30.json',
#   'heart_rate-2018-02-10.json',
#   'heart_rate-2018-12-10.json',
#   'heart_rate-2017-07-03.json',
#   'heart_rate-2017-10-07.json',
#   'heart_rate-2018-06-04.json',
#   'heart_rate-2019-02-03.json',
#   'heart_rate-2018-07-29.json',
#   'heart_rate-2018-05-14.json',
#   'heart_rate-2019-01-13.json',
#   'heart_rate-2017-06-02.json',
#   'heart_rate-2018-10-01.json',
#   'heart_rate-2018-03-11.json',
#   'heart_rate-2018-06-28.json',
#   'heart_rate-2018-04-15.json',
#   'heart_rate-2017-12-16.json',
#   'heart_rate-2019-03-02.json',
#   'heart_rate-2017-11-06.json',
#   'heart_rate-2018-07-05.json',
#   'heart_rate-2018-04-03.json',
#   'heart_rate-2018-08-20.json',
#   'heart_rate-2019-03-14.json',
#   'heart_rate-2019-01-29.json',
#   'heart_rate-2018-07-13.json',
#   'heart_rate-2017-11-10.json',
#   'heart_rate-2018-10-17.json',
#   'heart_rate-2017-06-14.json',
#   'heart_rate-2018-03-07.json',
#   'heart_rate-2017-09-27.json',
#   'heart_rate-2017-11-30.json',
#   'heart_rate-2019-01-09.json',
#   'heart_rate-2017-12-20.json',
#   'heart_rate-2018-04-23.json',
#   'heart_rate-2019-02-19.json',
#   'heart_rate-2018-03-27.json',
#   'heart_rate-2017-09-07.json',
#   'heart_rate-2017-07-19.json',
#   'heart_rate-2017-09-11.json',
#   'heart_rate-2018-03-31.json',
#   'heart_rate-2017-06-22.json',
#   'heart_rate-2018-10-21.json',
#   'heart_rate-2017-11-26.json',
#   'heart_rate-2018-05-18.json',
#   'heart_rate-2018-07-25.json',
#   'heart_rate-2019-03-22.json',
#   'heart_rate-2018-08-16.json',
#   'heart_rate-2018-06-08.json',
#   'heart_rate-2018-01-20.json',
#   'heart_rate-2017-07-23.json',
#   'heart_rate-2018-11-20.json',
#   'heart_rate-2017-08-10.json',
#   'heart_rate-2018-12-30.json',
#   'heart_rate-2018-07-09.json',
#   'heart_rate-2018-09-17.json',
#   'heart_rate-2019-02-23.json',
#   'heart_rate-2017-10-27.json',
#   'heart_rate-2018-04-19.json',
#   'heart_rate-2018-06-24.json',
#   'heart_rate-2019-01-25.json',
#   'heart_rate-2019-03-18.json',
#   'heart_rate-2018-09-01.json',
#   'heart_rate-2018-05-22.json',
#   'heart_rate-2017-10-31.json',
#   'heart_rate-2017-06-18.json',
#   'heart_rate-2018-12-26.json',
#   'heart_rate-2018-02-26.json',
#   'heart_rate-2017-08-06.json',
#   'heart_rate-2017-09-20.json',
#   'heart_rate-2017-06-13.json',
#   'heart_rate-2018-10-10.json',
#   'heart_rate-2019-03-13.json',
#   'heart_rate-2017-11-17.json',
#   'heart_rate-2018-05-29.json',
#   'heart_rate-2018-07-14.json',
#   'heart_rate-2018-08-27.json',
#   'heart_rate-2018-04-04.json',
#   'heart_rate-2017-12-07.json',
#   'heart_rate-2019-03-05.json',
#   'heart_rate-2018-07-02.json',
#   'heart_rate-2017-11-01.json',
#   'heart_rate-2019-02-28.json',
#   'heart_rate-2017-12-11.json',
#   'heart_rate-2018-04-12.json',
#   'heart_rate-2018-08-31.json',
#   'heart_rate-2018-03-16.json',
#   'heart_rate-2017-07-28.json',
#   'heart_rate-2019-04-01.json',
#   'heart_rate-2018-10-06.json',
#   'heart_rate-2017-06-05.json',
#   'heart_rate-2018-09-30.json',
#   'heart_rate-2018-05-13.json',
#   'heart_rate-2019-01-14.json',
#   'heart_rate-2019-03-29.json',
#   'heart_rate-2018-06-03.json',
#   'heart_rate-2019-02-04.json',
#   'heart_rate-2018-11-07.json',
#   'heart_rate-2017-07-04.json',
#   'heart_rate-2018-01-07.json',
#   'heart_rate-2017-06-29.json',
#   'heart_rate-2018-12-17.json',
#   'heart_rate-2018-02-17.json',
#   'heart_rate-2018-01-11.json',
#   'heart_rate-2017-07-12.json',
#   'heart_rate-2018-11-11.json',
#   'heart_rate-2017-08-21.json',
#   'heart_rate-2018-02-01.json',
#   'heart_rate-2018-12-01.json',
#   'heart_rate-2018-05-05.json',
#   'heart_rate-2018-09-26.json',
#   'heart_rate-2019-01-02.json',
#   'heart_rate-2017-10-16.json',
#   'heart_rate-2018-04-28.json',
#   'heart_rate-2018-06-15.json',
#   'heart_rate-2019-02-12.json',
#   'heart_rate-2017-08-01.json',
#   'heart_rate-2018-02-21.json',
#   'heart_rate-2018-12-21.json',
#   'heart_rate-2018-01-31.json',
#   'heart_rate-2018-04-08.json',
#   'heart_rate-2019-01-22.json',
#   'heart_rate-2018-07-18.json',
#   'heart_rate-2018-05-25.json',
#   'heart_rate-2018-09-06.json',
#   'heart_rate-2019-02-24.json',
#   'heart_rate-2018-06-23.json',
#   'heart_rate-2017-10-20.json',
#   'heart_rate-2019-03-09.json',
#   'heart_rate-2018-09-10.json',
#   'heart_rate-2017-06-09.json',
#   'heart_rate-2017-08-17.json',
#   'heart_rate-2018-11-27.json',
#   'heart_rate-2017-07-24.json',
#   'heart_rate-2018-01-27.json',
#   'heart_rate-2017-12-31.json',
#   'heart_rate-2018-08-11.json',
#   'heart_rate-2019-02-08.json',
#   'heart_rate-2018-07-22.json',
#   'heart_rate-2017-11-21.json',
#   'heart_rate-2019-03-25.json',
#   'heart_rate-2019-01-18.json',
#   'heart_rate-2018-10-26.json',
#   'heart_rate-2017-06-25.json',
#   'heart_rate-2017-09-16.json',
#   'heart_rate-2017-07-08.json',
#   'heart_rate-2018-10-30.json',
#   'heart_rate-2018-03-20.json',
#   'heart_rate-2018-08-07.json',
#   'heart_rate-2018-06-19.json',
#   'heart_rate-2018-04-24.json',
#   'heart_rate-2017-12-27.json',
#   'heart_rate-2018-05-09.json',
#   'heart_rate-2018-05-08.json',
#   'heart_rate-2018-08-06.json',
#   'heart_rate-2018-04-25.json',
#   'heart_rate-2018-06-18.json',
#   'heart_rate-2017-12-26.json',
#   'heart_rate-2017-09-01.json',
#   'heart_rate-2018-03-21.json',
#   'heart_rate-2018-10-31.json',
#   'heart_rate-2017-09-17.json',
#   'heart_rate-2017-07-09.json',
#   'heart_rate-2018-10-27.json',
#   'heart_rate-2017-06-24.json',
#   'heart_rate-2018-07-23.json',
#   'heart_rate-2017-11-20.json',
#   'heart_rate-2019-01-19.json',
#   'heart_rate-2019-03-24.json',
#   'heart_rate-2017-12-30.json',
#   'heart_rate-2018-08-10.json',
#   'heart_rate-2019-02-09.json',
#   'heart_rate-2018-11-26.json',
#   'heart_rate-2017-07-25.json',
#   'heart_rate-2018-01-26.json',
#   'heart_rate-2017-06-08.json',
#   'heart_rate-2017-08-16.json',
#   'heart_rate-2019-03-08.json',
#   'heart_rate-2018-09-11.json',
#   'heart_rate-2019-02-25.json',
#   'heart_rate-2018-06-22.json',
#   'heart_rate-2017-10-21.json',
#   'heart_rate-2019-01-23.json',
#   'heart_rate-2018-05-24.json',
#   'heart_rate-2018-07-19.json',
#   'heart_rate-2018-09-07.json',
#   'heart_rate-2018-04-09.json',
#   'heart_rate-2018-01-30.json',
#   'heart_rate-2018-11-30.json',
#   'heart_rate-2018-02-20.json',
#   'heart_rate-2018-12-20.json',
#   'heart_rate-2017-10-17.json',
#   'heart_rate-2018-06-14.json',
#   'heart_rate-2018-04-29.json',
#   'heart_rate-2019-02-13.json',
#   'heart_rate-2018-05-04.json',
#   'heart_rate-2018-09-27.json',
#   'heart_rate-2019-01-03.json',
#   'heart_rate-2017-08-20.json',
#   'heart_rate-2018-01-10.json',
#   'heart_rate-2017-07-13.json',
#   'heart_rate-2018-11-10.json',
#   'heart_rate-2017-06-28.json',
#   'heart_rate-2018-12-16.json',
#   'heart_rate-2018-02-16.json',
#   'heart_rate-2018-11-06.json',
#   'heart_rate-2017-07-05.json',
#   'heart_rate-2018-01-06.json',
#   'heart_rate-2018-06-02.json',
#   'heart_rate-2017-10-01.json',
#   'heart_rate-2019-02-05.json',
#   'heart_rate-2018-05-12.json',
#   'heart_rate-2019-03-28.json',
#   'heart_rate-2019-01-15.json',
#   'heart_rate-2018-10-07.json',
#   'heart_rate-2017-06-04.json',
#   'heart_rate-2018-03-17.json',
#   'heart_rate-2017-07-29.json',
#   'heart_rate-2017-12-10.json',
#   'heart_rate-2018-04-13.json',
#   'heart_rate-2018-08-30.json',
#   'heart_rate-2019-03-04.json',
#   'heart_rate-2018-07-03.json',
#   'heart_rate-2018-08-26.json',
#   'heart_rate-2018-04-05.json',
#   'heart_rate-2017-12-06.json',
#   'heart_rate-2019-03-12.json',
#   'heart_rate-2017-11-16.json',
#   'heart_rate-2018-07-15.json',
#   'heart_rate-2018-05-28.json',
#   'heart_rate-2017-06-12.json',
#   'heart_rate-2018-10-11.json',
#   'heart_rate-2017-09-21.json',
#   'heart_rate-2018-03-01.json',
#   'heart_rate-2019-02-10.json',
#   'heart_rate-2018-08-09.json',
#   'heart_rate-2017-12-29.json',
#   'heart_rate-2017-10-14.json',
#   'heart_rate-2018-06-17.json',
#   'heart_rate-2018-09-24.json',
#   'heart_rate-2018-05-07.json',
#   'heart_rate-2018-12-03.json',
#   'heart_rate-2017-08-23.json',
#   'heart_rate-2018-02-03.json',
#   'heart_rate-2017-07-10.json',
#   'heart_rate-2018-11-13.json',
#   'heart_rate-2018-01-13.json',
#   'heart_rate-2018-02-15.json',
#   'heart_rate-2018-12-15.json',
#   'heart_rate-2018-10-28.json',
#   'heart_rate-2017-09-18.json',
#   'heart_rate-2018-01-05.json',
#   'heart_rate-2018-11-05.json',
#   'heart_rate-2017-07-06.json',
#   'heart_rate-2019-02-06.json',
#   'heart_rate-2018-06-01.json',
#   'heart_rate-2017-10-02.json',
#   'heart_rate-2019-01-16.json',
#   'heart_rate-2018-05-11.json',
#   'heart_rate-2018-10-04.json',
#   'heart_rate-2017-06-07.json',
#   'heart_rate-2017-08-19.json',
#   'heart_rate-2018-11-29.json',
#   'heart_rate-2018-03-14.json',
#   'heart_rate-2018-01-29.json',
#   'heart_rate-2017-12-13.json',
#   'heart_rate-2018-04-10.json',
#   'heart_rate-2017-11-03.json',
#   'heart_rate-2019-03-07.json',
#   'heart_rate-2018-04-06.json',
#   'heart_rate-2017-12-05.json',
#   'heart_rate-2018-08-25.json',
#   'heart_rate-2017-11-15.json',
#   'heart_rate-2018-07-16.json',
#   'heart_rate-2018-09-08.json',
#   'heart_rate-2019-03-11.json',
#   'heart_rate-2017-06-11.json',
#   'heart_rate-2018-10-12.json',
#   'heart_rate-2017-09-22.json',
#   'heart_rate-2018-03-02.json',
#   'heart_rate-2019-03-31.json',
#   'heart_rate-2018-09-28.json',
#   'heart_rate-2018-04-26.json',
#   'heart_rate-2017-10-18.json',
#   'heart_rate-2017-12-25.json',
#   'heart_rate-2018-08-05.json',
#   'heart_rate-2017-09-02.json',
#   'heart_rate-2018-03-22.json',
#   'heart_rate-2018-11-09.json',
#   'heart_rate-2018-01-09.json',
#   'heart_rate-2017-09-14.json',
#   'heart_rate-2018-10-24.json',
#   'heart_rate-2018-12-19.json',
#   'heart_rate-2017-06-27.json',
#   'heart_rate-2018-02-19.json',
#   'heart_rate-2019-03-27.json',
#   'heart_rate-2018-07-20.json',
#   'heart_rate-2017-11-23.json',
#   'heart_rate-2018-08-13.json',
#   'heart_rate-2018-04-30.json',
#   'heart_rate-2018-01-25.json',
#   'heart_rate-2018-03-18.json',
#   'heart_rate-2018-11-25.json',
#   'heart_rate-2017-07-26.json',
#   'heart_rate-2017-08-15.json',
#   'heart_rate-2018-10-08.json',
#   'heart_rate-2018-05-31.json',
#   'heart_rate-2018-09-12.json',
#   'heart_rate-2018-06-21.json',
#   'heart_rate-2017-10-22.json',
#   'heart_rate-2019-02-26.json',
#   'heart_rate-2018-09-04.json',
#   'heart_rate-2018-05-27.json',
#   'heart_rate-2017-11-19.json',
#   'heart_rate-2019-01-20.json',
#   'heart_rate-2018-08-29.json',
#   'heart_rate-2017-12-09.json',
#   'heart_rate-2017-07-30.json',
#   'heart_rate-2018-12-23.json',
#   'heart_rate-2017-08-03.json',
#   'heart_rate-2018-02-23.json',
#   'heart_rate-2018-12-22.json',
#   'heart_rate-2017-08-02.json',
#   'heart_rate-2018-02-22.json',
#   'heart_rate-2017-07-31.json',
#   'heart_rate-2018-08-28.json',
#   'heart_rate-2017-12-08.json',
#   'heart_rate-2018-09-05.json',
#   'heart_rate-2018-05-26.json',
#   'heart_rate-2017-11-18.json',
#   'heart_rate-2019-01-21.json',
#   'heart_rate-2018-06-20.json',
#   'heart_rate-2017-10-23.json',
#   'heart_rate-2019-02-27.json',
#   'heart_rate-2018-05-30.json',
#   'heart_rate-2018-09-13.json',
#   'heart_rate-2017-08-14.json',
#   'heart_rate-2018-10-09.json',
#   'heart_rate-2018-03-19.json',
#   'heart_rate-2018-01-24.json',
#   'heart_rate-2018-11-24.json',
#   'heart_rate-2017-07-27.json',
#   'heart_rate-2018-08-12.json',
#   'heart_rate-2019-03-26.json',
#   'heart_rate-2018-07-21.json',
#   'heart_rate-2017-11-22.json',
#   'heart_rate-2018-12-18.json',
#   'heart_rate-2018-10-25.json',
#   'heart_rate-2017-06-26.json',
#   'heart_rate-2018-02-18.json',
#   'heart_rate-2018-11-08.json',
#   'heart_rate-2018-01-08.json',
#   'heart_rate-2017-09-15.json',
#   'heart_rate-2017-06-30.json',
#   'heart_rate-2017-09-03.json',
#   'heart_rate-2018-03-23.json',
#   'heart_rate-2018-04-27.json',
#   'heart_rate-2017-12-24.json',
#   'heart_rate-2017-10-19.json',
#   'heart_rate-2018-08-04.json',
#   'heart_rate-2019-03-30.json',
#   'heart_rate-2018-09-29.json',
#   'heart_rate-2017-09-23.json',
#   'heart_rate-2018-03-03.json',
#   'heart_rate-2017-06-10.json',
#   'heart_rate-2018-10-13.json',
#   'heart_rate-2017-11-14.json',
#   'heart_rate-2018-07-17.json',
#   'heart_rate-2018-09-09.json',
#   'heart_rate-2019-03-10.json',
#   'heart_rate-2018-04-07.json',
#   'heart_rate-2017-12-04.json',
#   'heart_rate-2018-08-24.json',
#   'heart_rate-2018-07-01.json',
#   'heart_rate-2017-11-02.json',
#   'heart_rate-2019-03-06.json',
#   'heart_rate-2017-12-12.json',
#   'heart_rate-2018-04-11.json',
#   'heart_rate-2018-11-28.json',
#   'heart_rate-2018-01-28.json',
#   'heart_rate-2018-03-15.json',
#   'heart_rate-2018-10-05.json',
#   'heart_rate-2017-06-06.json',
#   'heart_rate-2017-08-18.json',
#   'heart_rate-2019-01-17.json',
#   'heart_rate-2018-05-10.json',
#   'heart_rate-2019-02-07.json',
#   'heart_rate-2017-10-03.json',
#   'heart_rate-2017-09-19.json',
#   'heart_rate-2018-01-04.json',
#   'heart_rate-2018-11-04.json',
#   'heart_rate-2017-07-07.json',
#   'heart_rate-2018-02-14.json',
#   'heart_rate-2018-10-29.json',
#   'heart_rate-2018-12-14.json',
#   'heart_rate-2017-07-11.json',
#   'heart_rate-2018-11-12.json',
#   'heart_rate-2018-01-12.json',
#   'heart_rate-2018-12-02.json',
#   'heart_rate-2017-08-22.json',
#   'heart_rate-2018-02-02.json',
#   'heart_rate-2019-01-01.json',
#   'heart_rate-2018-09-25.json',
#   'heart_rate-2018-05-06.json',
#   'heart_rate-2019-02-11.json',
#   'heart_rate-2018-08-08.json',
#   'heart_rate-2017-10-15.json',
#   'heart_rate-2017-12-28.json',
#   'heart_rate-2018-06-16.json',
#   'heart_rate-2018-07-30.json',
#   'heart_rate-2018-08-03.json',
#   'heart_rate-2017-12-23.json',
#   'heart_rate-2018-04-20.json',
#   'heart_rate-2018-11-19.json',
#   'heart_rate-2018-01-19.json',
#   'heart_rate-2018-03-24.json',
#   'heart_rate-2017-09-04.json',
#   'heart_rate-2018-12-09.json',
#   'heart_rate-2017-08-29.json',
#   'heart_rate-2018-02-09.json',
#   'heart_rate-2017-09-12.json',
#   'heart_rate-2017-05-31.json',
#   'heart_rate-2017-06-21.json',
#   'heart_rate-2018-10-22.json',
#   'heart_rate-2019-03-21.json',
#   'heart_rate-2017-11-25.json',
#   'heart_rate-2018-07-26.json',
#   'heart_rate-2017-10-08.json',
#   'heart_rate-2018-08-15.json',
#   'heart_rate-2017-07-20.json',
#   'heart_rate-2018-11-23.json',
#   'heart_rate-2018-01-23.json',
#   'heart_rate-2017-08-13.json',
#   'heart_rate-2018-09-14.json',
#   'heart_rate-2017-11-09.json',
#   'heart_rate-2019-01-30.json',
#   'heart_rate-2017-10-24.json',
#   'heart_rate-2017-12-19.json',
#   'heart_rate-2018-06-27.json',
#   'heart_rate-2019-02-20.json',
#   'heart_rate-2018-05-21.json',
#   'heart_rate-2018-09-02.json',
#   'heart_rate-2019-01-26.json',
#   'heart_rate-2017-09-28.json',
#   'heart_rate-2018-03-08.json',
#   'heart_rate-2018-02-25.json',
#   'heart_rate-2017-08-05.json',
#   'heart_rate-2018-10-18.json',
#   'heart_rate-2018-12-25.json',
#   'heart_rate-2019-02-16.json',
#   'heart_rate-2018-06-11.json',
#   'heart_rate-2017-10-12.json',
#   'heart_rate-2019-01-06.json',
#   'heart_rate-2018-05-01.json',
#   'heart_rate-2018-09-22.json',
#   'heart_rate-2018-02-05.json',
#   'heart_rate-2017-08-25.json',
#   'heart_rate-2018-12-05.json',
#   'heart_rate-2017-09-08.json',
#   'heart_rate-2018-03-28.json',
#   'heart_rate-2018-01-15.json',
#   'heart_rate-2018-11-15.json',
#   'heart_rate-2017-07-16.json',
#   'heart_rate-2018-12-13.json',
#   'heart_rate-2018-02-13.json',
#   'heart_rate-2018-11-03.json',
#   'heart_rate-2018-01-03.json',
#   'heart_rate-2018-08-19.json',
#   'heart_rate-2017-10-04.json',
#   'heart_rate-2018-06-07.json',
#   'heart_rate-2019-01-10.json',
#   'heart_rate-2018-05-17.json',
#   'heart_rate-2017-11-29.json',
#   'heart_rate-2017-06-01.json',
#   'heart_rate-2018-10-02.json',
#   'heart_rate-2018-03-12.json',
#   'heart_rate-2018-04-16.json',
#   'heart_rate-2017-12-15.json',
#   'heart_rate-2017-10-28.json',
#   'heart_rate-2017-11-05.json',
#   'heart_rate-2018-07-06.json',
#   'heart_rate-2018-09-18.json',
#   'heart_rate-2019-03-01.json',
#   'heart_rate-2018-08-23.json',
#   'heart_rate-2017-12-03.json',
#   'heart_rate-2018-07-10.json',
#   'heart_rate-2017-11-13.json',
#   'heart_rate-2019-03-17.json',
#   'heart_rate-2018-12-29.json',
#   'heart_rate-2018-10-14.json',
#   'heart_rate-2017-06-17.json',
#   'heart_rate-2017-08-09.json',
#   'heart_rate-2018-03-04.json',
#   'heart_rate-2017-09-24.json',
#   'heart_rate-2018-03-05.json',
#   'heart_rate-2017-09-25.json',
#   'heart_rate-2018-10-15.json',
#   'heart_rate-2018-12-28.json',
#   'heart_rate-2017-06-16.json',
#   'heart_rate-2017-08-08.json',
#   'heart_rate-2018-02-28.json',
#   'heart_rate-2018-07-11.json',
#   'heart_rate-2017-11-12.json',
#   'heart_rate-2019-03-16.json',
#   'heart_rate-2018-08-22.json',
#   'heart_rate-2017-12-02.json',
#   'heart_rate-2018-04-01.json',
#   'heart_rate-2017-11-04.json',
#   'heart_rate-2018-07-07.json',
#   'heart_rate-2018-09-19.json',
#   'heart_rate-2018-04-17.json',
#   'heart_rate-2017-10-29.json',
#   'heart_rate-2017-12-14.json',
#   'heart_rate-2018-03-13.json',
#   'heart_rate-2018-10-03.json',
#   'heart_rate-2019-01-11.json',
#   'heart_rate-2018-05-16.json',
#   'heart_rate-2017-11-28.json',
#   'heart_rate-2019-02-01.json',
#   'heart_rate-2018-08-18.json',
#   'heart_rate-2017-10-05.json',
#   'heart_rate-2018-06-06.json',
#   'heart_rate-2017-07-01.json',
#   'heart_rate-2018-11-02.json',
#   'heart_rate-2018-01-02.json',
#   'heart_rate-2018-12-12.json',
#   'heart_rate-2018-02-12.json',
#   'heart_rate-2017-09-09.json',
#   'heart_rate-2018-01-14.json',
#   'heart_rate-2018-03-29.json',
#   'heart_rate-2018-11-14.json',
#   'heart_rate-2017-07-17.json',
#   'heart_rate-2018-02-04.json',
#   'heart_rate-2017-08-24.json',
#   'heart_rate-2018-12-04.json',
#   'heart_rate-2019-01-07.json',
#   'heart_rate-2018-09-23.json',
#   'heart_rate-2019-02-17.json',
#   'heart_rate-2018-06-10.json',
#   'heart_rate-2017-10-13.json',
#   'heart_rate-2018-02-24.json',
#   'heart_rate-2017-08-04.json',
#   'heart_rate-2018-12-24.json',
#   'heart_rate-2018-10-19.json',
#   'heart_rate-2017-09-29.json',
#   'heart_rate-2018-03-09.json',
#   'heart_rate-2018-06-30.json',
#   'heart_rate-2018-05-20.json',
#   'heart_rate-2018-09-03.json',
#   'heart_rate-2019-01-27.json',
#   'heart_rate-2017-12-18.json',
#   'heart_rate-2017-10-25.json',
#   'heart_rate-2018-06-26.json',
#   'heart_rate-2019-02-21.json',
#   'heart_rate-2018-09-15.json',
#   'heart_rate-2017-11-08.json',
#   'heart_rate-2019-01-31.json',
#   'heart_rate-2017-08-12.json',
#   'heart_rate-2017-07-21.json',
#   'heart_rate-2018-11-22.json',
#   'heart_rate-2018-01-22.json',
#   'heart_rate-2017-10-09.json',
#   'heart_rate-2018-08-14.json',
#   'heart_rate-2019-03-20.json',
#   'heart_rate-2017-11-24.json',
#   'heart_rate-2018-07-27.json',
#   'heart_rate-2017-06-20.json',
#   'heart_rate-2018-10-23.json',
#   'heart_rate-2017-09-13.json',
#   'heart_rate-2017-05-30.json',
#   'heart_rate-2018-12-08.json',
#   'heart_rate-2017-08-28.json',
#   'heart_rate-2018-02-08.json',
#   'heart_rate-2018-11-18.json',
#   'heart_rate-2018-03-25.json',
#   'heart_rate-2018-01-18.json',
#   'heart_rate-2017-09-05.json',
#   'heart_rate-2018-08-02.json',
#   'heart_rate-2017-12-22.json',
#   'heart_rate-2018-04-21.json',
#   'heart_rate-2018-07-31.json'],
#  ['distance-2018-12-20.json',
#   'distance-2018-05-24.json',
#   'distance-2018-07-23.json',
#   'distance-2019-01-19.json',
#   'distance-2017-06-28.json',
#   'distance-2017-07-28.json',
#   'distance-2018-04-24.json',
#   'distance-2017-03-30.json',
#   'distance-2018-06-23.json',
#   'distance-2017-04-29.json',
#   'distance-2018-09-21.json',
#   'distance-2018-11-20.json',
#   'distance-2018-10-21.json',
#   'distance-2019-02-18.json',
#   'distance-2017-10-26.json',
#   'distance-2017-08-27.json',
#   'distance-2017-05-29.json',
#   'distance-2017-09-26.json',
#   'distance-2018-08-22.json',
#   'distance-2018-03-25.json',
#   'distance-2019-03-20.json',
#   'distance-2017-11-25.json',
#   'distance-2016-12-30.json',
#   'distance-2017-01-29.json',
#   'distance-2018-01-24.json',
#   'distance-2017-02-28.json',
#   'distance-2018-02-23.json',
#   'distance-2017-12-25.json'],
#  ['height-2016-12-30.json'],
#  ['run_vo2_max-2016-12-30.json'],
#  ['exercise-1100.json',
#   'exercise-200.json',
#   'exercise-1300.json',
#   'exercise-400.json',
#   'exercise-800.json',
#   'exercise-1700.json',
#   'exercise-1500.json',
#   'exercise-600.json',
#   'exercise-300.json',
#   'exercise-1000.json',
#   'exercise-1200.json',
#   'exercise-0.json',
#   'exercise-100.json',
#   'exercise-1600.json',
#   'exercise-500.json',
#   'exercise-900.json',
#   'exercise-700.json',
#   'exercise-1400.json',
#   'exercise-1800.json'],
#  ['altitude-2019-02-18.json',
#   'altitude-2017-10-26.json',
#   'altitude-2017-08-27.json',
#   'altitude-2017-05-29.json',
#   'altitude-2017-09-26.json',
#   'altitude-2017-04-29.json',
#   'altitude-2018-09-21.json',
#   'altitude-2018-11-20.json',
#   'altitude-2018-10-21.json',
#   'altitude-2017-07-28.json',
#   'altitude-2018-04-24.json',
#   'altitude-2017-03-30.json',
#   'altitude-2018-06-23.json',
#   'altitude-2018-12-20.json',
#   'altitude-2018-05-24.json',
#   'altitude-2018-07-23.json',
#   'altitude-2019-01-19.json',
#   'altitude-2017-06-28.json',
#   'altitude-2018-02-23.json',
#   'altitude-2017-12-25.json',
#   'altitude-2018-01-24.json',
#   'altitude-2017-02-28.json',
#   'altitude-2017-11-25.json',
#   'altitude-2016-12-30.json',
#   'altitude-2017-01-29.json',
#   'altitude-2018-08-22.json',
#   'altitude-2018-03-25.json',
#   'altitude-2019-03-20.json'],
#  ['steps-2018-03-25.json',
#   'steps-2019-03-20.json',
#   'steps-2018-08-22.json',
#   'steps-2017-01-29.json',
#   'steps-2017-11-25.json',
#   'steps-2016-12-30.json',
#   'steps-2017-02-28.json',
#   'steps-2018-01-24.json',
#   'steps-2018-02-23.json',
#   'steps-2017-12-25.json',
#   'steps-2017-06-28.json',
#   'steps-2018-12-20.json',
#   'steps-2018-05-24.json',
#   'steps-2019-01-19.json',
#   'steps-2018-07-23.json',
#   'steps-2018-04-24.json',
#   'steps-2017-03-30.json',
#   'steps-2018-06-23.json',
#   'steps-2017-07-28.json',
#   'steps-2018-11-20.json',
#   'steps-2018-10-21.json',
#   'steps-2017-04-29.json',
#   'steps-2018-09-21.json',
#   'steps-2017-08-27.json',
#   'steps-2017-05-29.json',
#   'steps-2017-09-26.json',
#   'steps-2019-02-18.json',
#   'steps-2017-10-26.json'],
#  ['weight-2016-12-30.json'],
#  ['demographic_vo2_max-2018-12-30.json',
#   'demographic_vo2_max-2017-12-30.json',
#   'demographic_vo2_max-2016-12-30.json'],
#  ['very_active_minutes-2017-06-28.json',
#   'very_active_minutes-2019-01-19.json',
#   'very_active_minutes-2018-07-23.json',
#   'very_active_minutes-2018-05-24.json',
#   'very_active_minutes-2018-12-20.json',
#   'very_active_minutes-2017-03-30.json',
#   'very_active_minutes-2018-06-23.json',
#   'very_active_minutes-2018-04-24.json',
#   'very_active_minutes-2017-07-28.json',
#   'very_active_minutes-2018-10-21.json',
#   'very_active_minutes-2018-11-20.json',
#   'very_active_minutes-2018-09-21.json',
#   'very_active_minutes-2017-04-29.json',
#   'very_active_minutes-2017-09-26.json',
#   'very_active_minutes-2017-08-27.json',
#   'very_active_minutes-2017-05-29.json',
#   'very_active_minutes-2017-10-26.json',
#   'very_active_minutes-2019-02-18.json',
#   'very_active_minutes-2019-03-20.json',
#   'very_active_minutes-2018-03-25.json',
#   'very_active_minutes-2018-08-22.json',
#   'very_active_minutes-2017-01-29.json',
#   'very_active_minutes-2016-12-30.json',
#   'very_active_minutes-2017-11-25.json',
#   'very_active_minutes-2017-02-28.json',
#   'very_active_minutes-2018-01-24.json',
#   'very_active_minutes-2017-12-25.json',
#   'very_active_minutes-2018-02-23.json'],
#  ['resting_heart_rate-2016-12-30.json',
#   'resting_heart_rate-2018-12-30.json',
#   'resting_heart_rate-2017-12-30.json'],
#  ['lightly_active_minutes-2018-12-20.json',
#   'lightly_active_minutes-2018-05-24.json',
#   'lightly_active_minutes-2019-01-19.json',
#   'lightly_active_minutes-2018-07-23.json',
#   'lightly_active_minutes-2017-06-28.json',
#   'lightly_active_minutes-2017-07-28.json',
#   'lightly_active_minutes-2018-04-24.json',
#   'lightly_active_minutes-2018-06-23.json',
#   'lightly_active_minutes-2017-03-30.json',
#   'lightly_active_minutes-2017-04-29.json',
#   'lightly_active_minutes-2018-09-21.json',
#   'lightly_active_minutes-2018-11-20.json',
#   'lightly_active_minutes-2018-10-21.json',
#   'lightly_active_minutes-2019-02-18.json',
#   'lightly_active_minutes-2017-10-26.json',
#   'lightly_active_minutes-2017-05-29.json',
#   'lightly_active_minutes-2017-08-27.json',
#   'lightly_active_minutes-2017-09-26.json',
#   'lightly_active_minutes-2018-08-22.json',
#   'lightly_active_minutes-2019-03-20.json',
#   'lightly_active_minutes-2018-03-25.json',
#   'lightly_active_minutes-2016-12-30.json',
#   'lightly_active_minutes-2017-11-25.json',
#   'lightly_active_minutes-2017-01-29.json',
#   'lightly_active_minutes-2018-01-24.json',
#   'lightly_active_minutes-2017-02-28.json',
#   'lightly_active_minutes-2018-02-23.json',
#   'lightly_active_minutes-2017-12-25.json'],
#  ['calories-2017-02-28.json',
#   'calories-2018-01-24.json',
#   'calories-2017-12-25.json',
#   'calories-2018-02-23.json',
#   'calories-2019-03-20.json',
#   'calories-2018-03-25.json',
#   'calories-2018-08-22.json',
#   'calories-2017-01-29.json',
#   'calories-2016-12-30.json',
#   'calories-2017-11-25.json',
#   'calories-2018-10-21.json',
#   'calories-2018-11-20.json',
#   'calories-2018-09-21.json',
#   'calories-2017-04-29.json',
#   'calories-2017-09-26.json',
#   'calories-2017-08-27.json',
#   'calories-2017-05-29.json',
#   'calories-2017-10-26.json',
#   'calories-2019-02-18.json',
#   'calories-2017-06-28.json',
#   'calories-2018-07-23.json',
#   'calories-2019-01-19.json',
#   'calories-2018-05-24.json',
#   'calories-2018-12-20.json',
#   'calories-2017-03-30.json',
#   'calories-2018-06-23.json',
#   'calories-2018-04-24.json',
#   'calories-2017-07-28.json'],
#  ['sleep-2017-11-25.json',
#   'sleep-2016-12-30.json',
#   'sleep-2017-01-29.json',
#   'sleep-2018-08-22.json',
#   'sleep-2018-03-25.json',
#   'sleep-2019-03-20.json',
#   'sleep-2018-02-23.json',
#   'sleep-2017-12-25.json',
#   'sleep-2018-01-24.json',
#   'sleep-2017-02-28.json',
#   'sleep-2017-07-28.json',
#   'sleep-2018-04-24.json',
#   'sleep-2017-03-30.json',
#   'sleep-2018-06-23.json',
#   'sleep-2018-12-20.json',
#   'sleep-2018-05-24.json',
#   'sleep-2018-07-23.json',
#   'sleep-2019-01-19.json',
#   'sleep-2017-06-28.json',
#   'sleep-2019-02-18.json',
#   'sleep-2017-10-26.json',
#   'sleep-2017-08-27.json',
#   'sleep-2017-05-29.json',
#   'sleep-2017-09-26.json',
#   'sleep-2017-04-29.json',
#   'sleep-2018-09-21.json',
#   'sleep-2018-11-20.json',
#   'sleep-2018-10-21.json']]

# %%
path_to_json
# Out:
# 'Adele_files/'

# %%
#path_to_json is hardcoded to the folder name. Will need to address this issue later so that we can upload the 
#fitbit data from any folder regardless of folder name.


#Takes in a list of lists where the files are grouped according to its content. For instance, each nested list will 
#have the name of files that have the same column names. Merges the files within each nested list. Returns the merged
#files as dataframes that are stored within a list.

def form_dataframes(grouped_list):
    dataframes = [[] for i in range(len(grouped_list))]
    final_dfs = []      
    
    #converts the filenames to dataframes
    for i in range(len(grouped_list)):
        with open(path_to_json + grouped_list[i][0], 'r') as first:
            first_filename = json.load(first)
            df1 = pd.DataFrame(first_filename)
            dataframes[i].append(df1)
        for j in range(1, len(grouped_list[i])):
            with open(path_to_json + grouped_list[i][j], 'r') as f:
                data = json.load(f)
                df = pd.DataFrame(data)
                dataframes[i].append(df)
    
    #combines all similar dataframes
    for i in range(len(dataframes)):
        final_dfs.append(pd.concat(dataframes[i], sort=True))
    
    return final_dfs

# %%
#list of all dataframes
all_dfs = form_dataframes(grouped)

# %%
test = all_dfs[0]
date1 = test.iloc[0,0]
date1
# Out:
# '06/06/18 00:00:00'

# %%
#separate
test.head()
# Out:
#             dateTime                                              value
# 0  06/06/18 00:00:00  {'valuesInZones': {'BELOW_DEFAULT_ZONE_1': 120...
# 0  10/05/17 00:00:00  {'valuesInZones': {'IN_DEFAULT_ZONE_1': 54.0, ...
# 0  08/18/18 00:00:00  {'valuesInZones': {'BELOW_DEFAULT_ZONE_1': 110...
# 0  02/01/19 00:00:00  {'valuesInZones': {'IN_DEFAULT_ZONE_2': 0.0, '...
# 0  11/28/17 00:00:00  {'valuesInZones': {'IN_DEFAULT_ZONE_1': 80.0, ...

# %%
#input is a date as a string. returns a datetime object
def separate_datetime(date):
    return datetime.datetime.strptime(date, '%m/%d/%y %H:%M:%S')

#returns day of week as integer for reference --> {0: Sunday,...., 6:Saturday}
def weekday(date):
    return datetime.datetime.strptime(date, '%m/%d/%y %H:%M:%S').weekday()

#inputs day of week as integer. 
def is_weekend(day):
    if day == 0 or day == 6:
        return True
    else:
        return False

def month(date):
    return datetime.datetime.strptime(date, '%m/%d/%y %H:%M:%S').month

def day_of_month(date):
    return datetime.datetime.strptime(date, '%m/%d/%y %H:%M:%S').day
    
def year(date):
    return datetime.datetime.strptime(date, '%m/%d/%y %H:%M:%S').year
    
def hour(date):
    return datetime.datetime.strptime(date, '%m/%d/%y %H:%M:%S').hour
    
def minute(date):
    return datetime.datetime.strptime(date, '%m/%d/%y %H:%M:%S').minute

def second(date):
    return datetime.datetime.strptime(date, '%m/%d/%y %H:%M:%S').second



#input dataframe with 'dateTime' column, adds date features to dataframe
def add_date_features(dataframe):
    
    series = dataframe['dateTime']
        
    dataframe['Day of Week'] = series.apply(weekday)
    dataframe['Is Weekend'] = dataframe['Day of Week'].apply(is_weekend)
    dataframe['Month'] = series.apply(month)
    dataframe['Day'] = series.apply(day_of_month)
    dataframe['Year'] = series.apply(year)
    dataframe['Hour'] = series.apply(hour)
    dataframe['Minute'] = series.apply(minute)
    dataframe['Second'] = series.apply(second)
    return dataframe

# %%
add_date_features(test)
# Out:
#              dateTime                                              value  \
# 0   06/06/18 00:00:00  {'valuesInZones': {'BELOW_DEFAULT_ZONE_1': 120...
# 0   10/05/17 00:00:00  {'valuesInZones': {'IN_DEFAULT_ZONE_1': 54.0, ...
# 0   08/18/18 00:00:00  {'valuesInZones': {'BELOW_DEFAULT_ZONE_1': 110...
# 0   02/01/19 00:00:00  {'valuesInZones': {'IN_DEFAULT_ZONE_2': 0.0, '...
# 0   11/28/17 00:00:00  {'valuesInZones': {'IN_DEFAULT_ZONE_1': 80.0, ...
# 0   05/16/18 00:00:00  {'valuesInZones': {'IN_DEFAULT_ZONE_2': 30.0, ...
# 0   01/11/19 00:00:00  {'valuesInZones': {'BELOW_DEFAULT_ZONE_1': 126...
# 0   02/12/18 00:00:00  {'valuesInZones': {'IN_DEFAULT_ZONE_3': 2.0, '...
# 0   12/12/18 00:00:00  {'valuesInZones': {'IN_DEFAULT_ZONE_3': 0.0, '...
# 0   01/02/18 00:00:00  {'valuesInZones': {'BELOW_DEFAULT_ZONE_1': 109...
# 0   11/02/18 00:00:00  {'valuesInZones': {'IN_DEFAULT_ZONE_3': 5.0, '...
# 0   07/01/17 00:00:00  {'valuesInZones': {'IN_DEFAULT_ZONE_3': 4.0, '...
# 0   12/04/18 00:00:00  {'valuesInZones': {'BELOW_DEFAULT_ZONE_1': 129...
# 0   08/24/17 00:00:00  {'valuesInZones': {'IN_DEFAULT_ZONE_2': 23.0, ...
# 0   02/04/18 00:00:00  {'valuesInZones': {'BELOW_DEFAULT_ZONE_1': 132...
# 0   07/17/17 00:00:00  {'valuesInZones': {'BELOW_DEFAULT_ZONE_1': 129...
# 0   11/14/18 00:00:00  {'valuesInZones': {'BELOW_DEFAULT_ZONE_1': 126...
# 0   03/29/18 00:00:00  {'valuesInZones': {'BELOW_DEFAULT_ZONE_1': 125...
# 0   01/14/18 00:00:00  {'valuesInZones': {'BELOW_DEFAULT_ZONE_1': 136...
# 0   09/09/17 00:00:00  {'valuesInZones': {'BELOW_DEFAULT_ZONE_1': 128...
# 0   10/13/17 00:00:00  {'valuesInZones': {'IN_DEFAULT_ZONE_3': 1.0, '...
# 0   06/10/18 00:00:00  {'valuesInZones': {'BELOW_DEFAULT_ZONE_1': 778...
# 0   02/17/19 00:00:00  {'valuesInZones': {'IN_DEFAULT_ZONE_2': 20.0, ...
# 0   09/23/18 00:00:00  {'valuesInZones': {'BELOW_DEFAULT_ZONE_1': 134...
# 0   01/07/19 00:00:00  {'valuesInZones': {'IN_DEFAULT_ZONE_3': 0.0, '...
# 0   02/28/18 00:00:00  {'valuesInZones': {'IN_DEFAULT_ZONE_1': 129.0,...
# 0   08/08/17 00:00:00  {'valuesInZones': {'BELOW_DEFAULT_ZONE_1': 124...
# 0   06/16/17 00:00:00  {'valuesInZones': {'BELOW_DEFAULT_ZONE_1': 125...
# 0   12/28/18 00:00:00  {'valuesInZones': {'IN_DEFAULT_ZONE_1': 158.0,...
# 0   10/15/18 00:00:00  {'valuesInZones': {'IN_DEFAULT_ZONE_3': 0.0, '...
# ..                ...                                                ...
# 0   12/07/18 00:00:00  {'valuesInZones': {'BELOW_DEFAULT_ZONE_1': 116...
# 0   01/17/18 00:00:00  {'valuesInZones': {'IN_DEFAULT_ZONE_1': 83.0, ...
# 0   07/14/17 00:00:00  {'valuesInZones': {'BELOW_DEFAULT_ZONE_1': 125...
# 0   11/17/18 00:00:00  {'valuesInZones': {'BELOW_DEFAULT_ZONE_1': 119...
# 0   02/14/19 00:00:00  {'valuesInZones': {'IN_DEFAULT_ZONE_3': 7.0, '...
# 0   10/10/17 00:00:00  {'valuesInZones': {'BELOW_DEFAULT_ZONE_1': 123...
# 0   06/13/18 00:00:00  {'valuesInZones': {'BELOW_DEFAULT_ZONE_1': 103...
# 0   01/04/19 00:00:00  {'valuesInZones': {'IN_DEFAULT_ZONE_1': 129.0,...
# 0   05/03/18 00:00:00  {'valuesInZones': {'BELOW_DEFAULT_ZONE_1': 128...
# 0   09/20/18 00:00:00  {'valuesInZones': {'BELOW_DEFAULT_ZONE_1': 137...
# 0   06/15/17 00:00:00  {'valuesInZones': {'IN_DEFAULT_ZONE_1': 41.0, ...
# 0   10/16/18 00:00:00  {'valuesInZones': {'IN_DEFAULT_ZONE_3': 0.0, '...
# 0   09/26/17 00:00:00  {'valuesInZones': {'BELOW_DEFAULT_ZONE_1': 138...
# 0   03/06/18 00:00:00  {'valuesInZones': {'IN_DEFAULT_ZONE_3': 0.0, '...
# 0   08/21/18 00:00:00  {'valuesInZones': {'IN_DEFAULT_ZONE_3': 0.0, '...
# 0   04/02/18 00:00:00  {'valuesInZones': {'BELOW_DEFAULT_ZONE_1': 134...
# 0   12/01/17 00:00:00  {'valuesInZones': {'IN_DEFAULT_ZONE_1': 61.0, ...
# 0   11/11/17 00:00:00  {'valuesInZones': {'BELOW_DEFAULT_ZONE_1': 126...
# 0   07/12/18 00:00:00  {'valuesInZones': {'IN_DEFAULT_ZONE_2': 2.0, '...
# 0   03/15/19 00:00:00  {'valuesInZones': {'BELOW_DEFAULT_ZONE_1': 120...
# 0   01/28/19 00:00:00  {'valuesInZones': {'IN_DEFAULT_ZONE_3': 24.0, ...
# 0   12/17/17 00:00:00  {'valuesInZones': {'BELOW_DEFAULT_ZONE_1': 125...
# 0   06/29/18 00:00:00  {'valuesInZones': {'BELOW_DEFAULT_ZONE_1': 106...
# 0   04/14/18 00:00:00  {'valuesInZones': {'BELOW_DEFAULT_ZONE_1': 100...
# 0   07/04/18 00:00:00  {'valuesInZones': {'IN_DEFAULT_ZONE_3': 0.0, '...
# 0   11/07/17 00:00:00  {'valuesInZones': {'BELOW_DEFAULT_ZONE_1': 125...
# 0   03/03/19 00:00:00  {'valuesInZones': {'IN_DEFAULT_ZONE_2': 0.0, '...
# 0   06/03/17 00:00:00  {'valuesInZones': {'IN_DEFAULT_ZONE_2': 25.0, ...
# 0   03/10/18 00:00:00  {'valuesInZones': {'BELOW_DEFAULT_ZONE_1': 131...
# 0   09/30/17 00:00:00  {'valuesInZones': {'IN_DEFAULT_ZONE_3': 0.0, '...
#
#     Day of Week  Is Weekend  Month  Day  Year  Hour  Minute  Second
# 0             2       False      6    6  2018     0       0       0
# 0             3       False     10    5  2017     0       0       0
# 0             5       False      8   18  2018     0       0       0
# 0             4       False      2    1  2019     0       0       0
# 0             1       False     11   28  2017     0       0       0
# 0             2       False      5   16  2018     0       0       0
# 0             4       False      1   11  2019     0       0       0
# 0             0        True      2   12  2018     0       0       0
# 0             2       False     12   12  2018     0       0       0
# 0             1       False      1    2  2018     0       0       0
# 0             4       False     11    2  2018     0       0       0
# 0             5       False      7    1  2017     0       0       0
# 0             1       False     12    4  2018     0       0       0
# 0             3       False      8   24  2017     0       0       0
# 0             6        True      2    4  2018     0       0       0
# 0             0        True      7   17  2017     0       0       0
# 0             2       False     11   14  2018     0       0       0
# 0             3       False      3   29  2018     0       0       0
# 0             6        True      1   14  2018     0       0       0
# 0             5       False      9    9  2017     0       0       0
# 0             4       False     10   13  2017     0       0       0
# 0             6        True      6   10  2018     0       0       0
# 0             6        True      2   17  2019     0       0       0
# 0             6        True      9   23  2018     0       0       0
# 0             0        True      1    7  2019     0       0       0
# 0             2       False      2   28  2018     0       0       0
# 0             1       False      8    8  2017     0       0       0
# 0             4       False      6   16  2017     0       0       0
# 0             4       False     12   28  2018     0       0       0
# 0             0        True     10   15  2018     0       0       0
# ..          ...         ...    ...  ...   ...   ...     ...     ...
# 0             4       False     12    7  2018     0       0       0
# 0             2       False      1   17  2018     0       0       0
# 0             4       False      7   14  2017     0       0       0
# 0             5       False     11   17  2018     0       0       0
# 0             3       False      2   14  2019     0       0       0
# 0             1       False     10   10  2017     0       0       0
# 0             2       False      6   13  2018     0       0       0
# 0             4       False      1    4  2019     0       0       0
# 0             3       False      5    3  2018     0       0       0
# 0             3       False      9   20  2018     0       0       0
# 0             3       False      6   15  2017     0       0       0
# 0             1       False     10   16  2018     0       0       0
# 0             1       False      9   26  2017     0       0       0
# 0             1       False      3    6  2018     0       0       0
# 0             1       False      8   21  2018     0       0       0
# 0             0        True      4    2  2018     0       0       0
# 0             4       False     12    1  2017     0       0       0
# 0             5       False     11   11  2017     0       0       0
# 0             3       False      7   12  2018     0       0       0
# 0             4       False      3   15  2019     0       0       0
# 0             0        True      1   28  2019     0       0       0
# 0             6        True     12   17  2017     0       0       0
# 0             4       False      6   29  2018     0       0       0
# 0             5       False      4   14  2018     0       0       0
# 0             2       False      7    4  2018     0       0       0
# 0             1       False     11    7  2017     0       0       0
# 0             6        True      3    3  2019     0       0       0
# 0             5       False      6    3  2017     0       0       0
# 0             5       False      3   10  2018     0       0       0
# 0             5       False      9   30  2017     0       0       0
#
# [672 rows x 10 columns]

# %%
test['dateTime'].apply(separate_datetime).reset_index().drop(columns=['index']).iloc[0,0]
# Out:
# Timestamp('2018-06-06 00:00:00')

# %%
all_dfs[0].head(5)
# Out:
#             dateTime                         value
# 0  06/19/17 04:00:01  {'bpm': 55, 'confidence': 3}
# 1  06/19/17 04:00:06  {'bpm': 56, 'confidence': 3}
# 2  06/19/17 04:00:21  {'bpm': 59, 'confidence': 3}
# 3  06/19/17 04:00:36  {'bpm': 59, 'confidence': 3}
# 4  06/19/17 04:00:51  {'bpm': 61, 'confidence': 3}

# %%
all_dfs[1].head(5)
# Out:
#             dateTime value
# 0  12/31/16 00:00:00  1650

# %%
all_dfs[2].head(5)
# Out:
#    activeDuration                                      activityLevel  \
# 0         1843000  [{'minutes': 0, 'name': 'sedentary'}, {'minute...
# 1         3942000  [{'minutes': 5, 'name': 'sedentary'}, {'minute...
# 2         3072000  [{'minutes': 5, 'name': 'sedentary'}, {'minute...
# 3         2304000  [{'minutes': 0, 'name': 'sedentary'}, {'minute...
# 4         2151000  [{'minutes': 1, 'name': 'sedentary'}, {'minute...
#
#   activityName  activityTypeId  averageHeartRate  calories  distance  \
# 0         Walk           90013             103.0       123       NaN
# 1         Walk           90013             102.0       287       NaN
# 2         Walk           90013             100.0       184       NaN
# 3         Walk           90013             110.0       165       NaN
# 4         Walk           90013             105.0       148       NaN
#
#   distanceUnit  duration  elevationGain   ...    originalDuration  \
# 0          NaN   1843000            0.0   ...             1843000
# 1          NaN   3942000           20.0   ...             3942000
# 2          NaN   3072000            0.0   ...             3072000
# 3          NaN   2304000           10.0   ...             2304000
# 4          NaN   2151000           50.0   ...             2151000
#
#    originalStartTime pace shouldFetchDetails  source speed          startTime  \
# 0  06/11/18 18:15:57  NaN              False     NaN   NaN  06/11/18 18:15:57
# 1  06/11/18 19:29:20  NaN              False     NaN   NaN  06/11/18 19:29:20
# 2  06/12/18 08:42:05  NaN              False     NaN   NaN  06/12/18 08:42:05
# 3  06/12/18 11:48:07  NaN              False     NaN   NaN  06/12/18 11:48:07
# 4  06/12/18 12:58:05  NaN              False     NaN   NaN  06/12/18 12:58:05
#
#     steps tcxLink  vo2Max
# 0  2190.0     NaN     NaN
# 1  5299.0     NaN     NaN
# 2  3022.0     NaN     NaN
# 3  2931.0     NaN     NaN
# 4  2585.0     NaN     NaN
#
# [5 rows x 27 columns]

# %%
all_dfs[3].head(5)
# Out:
#             dateTime                                              value
# 0  05/31/17 17:02:39  {'exerciseId': 7994735916, 'runVO2Max': 36.914...
# 1  06/01/17 16:09:10  {'exerciseId': 8011597564, 'runVO2Max': 44.166...
# 2  06/03/17 15:17:25  {'exerciseId': 8050497515, 'runVO2Max': 41.221...
# 3  06/04/17 14:02:24  {'exerciseId': 8067986438, 'runVO2Max': 45.485...

# %%
all_dfs[4].head(5)
# Out:
#             dateTime value
# 0  12/20/18 08:00:00     0
# 1  12/20/18 08:01:00     0
# 2  12/20/18 08:02:00     0
# 3  12/20/18 08:03:00     0
# 4  12/20/18 08:04:00     0

# %%
all_dfs[5].head(5)
# Out:
#             dateTime value
# 0  03/25/18 07:00:00     0
# 1  03/25/18 07:01:00     0
# 2  03/25/18 07:02:00     0
# 3  03/25/18 07:03:00     0
# 4  03/25/18 07:04:00     0

# %%
all_dfs[6].head(5)
# Out:
#      bmi      date          logId source      time  weight
# 0  19.83  12/31/16  1483228799000    API  23:59:59   118.9

# %%
all_dfs[7].head(5)
# Out:
#             dateTime value
# 0  12/20/18 00:00:00   226
# 1  12/21/18 00:00:00   240
# 2  12/22/18 00:00:00   317
# 3  12/23/18 00:00:00   277
# 4  12/24/18 00:00:00   377

# %%
all_dfs[8].head(5)
# Out:
#             dateTime                                              value
# 0  12/30/18 00:00:00  {'demographicVO2Max': 40.60488, 'demographicVO...
# 1  12/31/18 00:00:00  {'demographicVO2Max': 40.14795, 'demographicVO...
# 2  01/01/19 00:00:00  {'demographicVO2Max': 39.344620000000006, 'dem...
# 3  01/02/19 00:00:00  {'demographicVO2Max': 39.24459, 'demographicVO...
# 4  01/03/19 00:00:00  {'demographicVO2Max': 40.299080000000004, 'dem...

# %%
all_dfs[9].head(5)
# Out:
#   dateOfSleep  duration  efficiency                  endTime  infoCode  \
# 0  2017-12-25  29820000          97  2017-12-25T06:26:00.000         0
# 1  2017-12-24   3900000          88  2017-12-24T18:42:30.000         2
# 2  2017-12-24  24480000          95  2017-12-24T06:55:30.000         0
# 3  2017-12-23   7980000          96  2017-12-23T16:28:00.000         2
# 4  2017-12-22  32400000          94  2017-12-22T20:25:30.000         0
#
#                                               levels        logId  \
# 0  {'summary': {'deep': {'count': 5, 'minutes': 7...  16683423534
# 1  {'summary': {'restless': {'count': 3, 'minutes...  16683423533
# 2  {'summary': {'deep': {'count': 3, 'minutes': 4...  16669911385
# 3  {'summary': {'restless': {'count': 2, 'minutes...  16666065337
# 4  {'summary': {'deep': {'count': 7, 'minutes': 8...  16661798489
#
#    minutesAfterWakeup  minutesAsleep  minutesAwake  minutesToFallAsleep  \
# 0                   0            442            55                    0
# 1                   0             57             8                    0
# 2                   0            357            51                    0
# 3                   0            128             5                    0
# 4                   0            448            92                    0
#
#                  startTime  timeInBed     type
# 0  2017-12-24T22:08:30.000        497   stages
# 1  2017-12-24T17:37:00.000         65  classic
# 2  2017-12-24T00:07:00.000        408   stages
# 3  2017-12-23T14:15:00.000        133  classic
# 4  2017-12-22T11:25:30.000        540   stages

# %%
all_dfs[10].head(5)
# Out:
#             dateTime value
# 0  02/28/17 00:00:00  0.92
# 1  02/28/17 00:01:00  0.92
# 2  02/28/17 00:02:00   2.2
# 3  02/28/17 00:03:00  0.92
# 4  02/28/17 00:04:00  0.92

# %%
all_dfs[11].head(5)
# Out:
#             dateTime value
# 0  06/28/17 00:00:00    94
# 1  06/29/17 00:00:00    37
# 2  06/30/17 00:00:00    15
# 3  07/01/17 00:00:00    98
# 4  07/02/17 00:00:00    26

# %%
all_dfs[12].head(5)
# Out:
#             dateTime value
# 0  04/24/18 00:00:00   603
# 1  04/25/18 00:00:00   568
# 2  04/26/18 00:00:00  1049
# 3  04/27/18 00:00:00   566
# 4  04/28/18 00:00:00   590

# %%
all_dfs[13].head(5)
# Out:
#             dateTime                                       value
# 0  12/30/16 00:00:00  {'date': None, 'value': 0.0, 'error': 0.0}
# 1  12/31/16 00:00:00  {'date': None, 'value': 0.0, 'error': 0.0}
# 2  01/01/17 00:00:00  {'date': None, 'value': 0.0, 'error': 0.0}
# 3  01/02/17 00:00:00  {'date': None, 'value': 0.0, 'error': 0.0}
# 4  01/03/17 00:00:00  {'date': None, 'value': 0.0, 'error': 0.0}

# %%
all_dfs[14].head(5)
# Out:
#             dateTime value
# 0  02/18/19 00:31:00    20
# 1  02/18/19 00:36:00    10
# 2  02/18/19 11:31:00    10
# 3  02/18/19 11:38:00    10
# 4  02/18/19 12:38:00    10

# %%
all_dfs[15].head(5)
# Out:
#             dateTime value
# 0  02/18/19 00:00:00    28
# 1  02/19/19 00:00:00    53
# 2  02/20/19 00:00:00    52
# 3  02/21/19 00:00:00    36
# 4  02/22/19 00:00:00    37

# %%
all_dfs[16].head(5)
# Out:
#             dateTime                                              value
# 0  06/06/18 00:00:00  {'valuesInZones': {'BELOW_DEFAULT_ZONE_1': 120...
# 0  10/05/17 00:00:00  {'valuesInZones': {'IN_DEFAULT_ZONE_1': 54.0, ...
# 0  08/18/18 00:00:00  {'valuesInZones': {'BELOW_DEFAULT_ZONE_1': 110...
# 0  02/01/19 00:00:00  {'valuesInZones': {'IN_DEFAULT_ZONE_2': 0.0, '...
# 0  11/28/17 00:00:00  {'valuesInZones': {'IN_DEFAULT_ZONE_1': 80.0, ...

# %%
'''1. need to create a fxn that separates dateTime
2. make a way that aranges nested lists alphabeticaly
3. extract values from tuples from certain tables (include way to relabel values)'''
# Out:
# '1. need to create a fxn that separates dateTime\n2. make a way that aranges nested lists alphabeticaly\n3. extract values from tuples from certain tables (include way to relabel values)'

# %%
# #for testing
# def date_to_day_of_week(date): 
#     born = datetime.datetime.strptime(date, '%m-%d-%Y').weekday() #returns day of week as a number
#     return calendar.day_name[born] <-- returns day of week as word
#for reference --> {0: Sunday,...., 6:Saturday}
